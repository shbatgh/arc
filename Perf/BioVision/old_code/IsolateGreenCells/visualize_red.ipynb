# %%
import numpy as np
from cellpose import plot, utils, io
import matplotlib.pyplot as plt

# Load segmentation data and image
dat = np.load('tifsmall/5_seg.npy', allow_pickle=True).item()
img = io.imread('tifsmall/5.tif')

# Create an overlay image with colored masks
mask_RGB = plot.mask_overlay(img, dat['masks'])

# Plot the image with the filled masks overlaid
plt.figure(figsize=(8, 8))
plt.imshow(mask_RGB)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from cellpose import io

# -------------------------------
# Part 1: Build the dictionary
# -------------------------------

# Load segmentation data and image
dat = np.load('tifsmall/5_seg.npy', allow_pickle=True).item()
img = io.imread('tifsmall/5.tif')

# Ensure the image is in RGB (if grayscale, convert it)
if img.ndim == 2 or (img.ndim == 3 and img.shape[2] == 1):
    img = np.stack([img.squeeze()] * 3, axis=-1)

masks = dat['masks']

# Create a dictionary: key -> tuple of (y,x) coordinates for the mask pixels,
# value -> average RGB value (will be used only for visualization, if desired)
mask_dict = {}
labels = np.unique(masks)
for label in labels:
    if label == 0:  # Skip background
        continue
    cell_mask = masks == label
    coords = np.argwhere(cell_mask)
    coords_tuple = tuple(map(tuple, coords))
    avg_rgb = np.mean(img[cell_mask], axis=0)
    mask_dict[coords_tuple] = avg_rgb

# -------------------------------
# Part 2: Filter cells using HSV thresholds
# -------------------------------

# Convert the image from RGB to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

# Define HSV boundaries for green (tweak these values as needed)
lower_green = np.array([0, 150, 50])
upper_green = np.array([12, 255, 255])

# Create a binary mask for green regions using cv2.inRange
hsv_green_mask = cv2.inRange(hsv, lower_green, upper_green)
# Note: pixels within the green range will have value 255 in hsv_green_mask

# Define the minimum ratio of green pixels for a cell to be considered "green"
green_pixel_ratio_threshold = 0.5  # 50% or more pixels must be green

# Filter the dictionary based on the percentage of green pixels in each cell
filtered_dict = {}
for coords, avg_rgb in mask_dict.items():
    coords_array = np.array(coords)  # shape (N, 2)
    # Extract the green mask values for the cell's pixels
    green_vals = hsv_green_mask[coords_array[:, 0], coords_array[:, 1]]
    ratio_green = np.sum(green_vals == 255) / len(green_vals)
    if ratio_green >= green_pixel_ratio_threshold:
        filtered_dict[coords] = avg_rgb

# -------------------------------
# Part 3: Create an overlay mask and plot the filtered cells
# -------------------------------

# Create an empty boolean array to hold the overlay for filtered cells
overlay_mask = np.zeros(masks.shape, dtype=bool)
for coords in filtered_dict.keys():
    for (y, x) in coords:
        overlay_mask[y, x] = True

# Plot the original image and overlay the filtered cells in red
plt.figure(figsize=(10, 10))
plt.imshow(img)
masked_overlay = np.ma.masked_where(~overlay_mask, overlay_mask)
plt.imshow(masked_overlay, cmap='Reds', alpha=0.5)
plt.title(f'Cells with ≥ {int(green_pixel_ratio_threshold*100)}% Green Pixels')
plt.axis('off')
plt.show()

# %%
import os
import glob
import numpy as np
import cv2
from cellpose import models, io

# -------------------------------
# Cellpose Segmentation Setup with Gaussian Blurring
# -------------------------------
base_folder = 'A1-raw-data-2'  # Folder containing subfolders (e.g., t1, t2, ... t46)
model_type = 'cyto3'          # Use 'cyto' for whole cell segmentation or 'nuclei' for nuclear segmentation
use_gpu = True               # Set to False if a GPU is not available

# Instantiate the Cellpose model
model = models.Cellpose(model_type=model_type, gpu=use_gpu)

# Get all subfolders in the base folder
subfolders = [os.path.join(base_folder, d) for d in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, d))]

# Process each subfolder
for subfolder in subfolders:
    # Get list of all TIFF images in the subfolder
    image_files = glob.glob(os.path.join(subfolder, '*.tif'))
    
    for img_file in image_files:
        # Read the image using cellpose's io.imread (supports many image formats)
        img = io.imread(img_file)
    
        # Convert grayscale images to RGB if needed
        if img.ndim == 2:
            img = np.stack([img] * 3, axis=-1)
        elif img.ndim == 3 and img.shape[2] == 1:
            img = np.concatenate([img] * 3, axis=2)
    
        # Apply Gaussian blurring to the image before segmentation
        # Adjust the kernel size (5,5) and sigma value (0) as needed
        img_blurred = cv2.GaussianBlur(img, (5, 5), 0)
    
        # For RGB images, using channels=[0,0] tells Cellpose to use the entire image
        channels = [0, 0]
    
        # Run the segmentation using Cellpose on the blurred image
        masks, flows, styles, diams = model.eval(img_blurred, channels=channels)
    
        # Save the segmentation results in a dictionary (the 'masks' key is used by the filtering cell)
        seg_data = {'masks': masks, 'flows': flows, 'styles': styles, 'diams': diams}
    
        # Construct the segmentation file name (e.g., 'image_seg.npy')
        base_name = os.path.splitext(os.path.basename(img_file))[0]
        seg_file = os.path.join(subfolder, base_name + '_seg.npy')
    
        np.save(seg_file, seg_data)
        print(f"Segmented {base_name} in folder {os.path.basename(subfolder)} and saved to {seg_file}.")
# Out:
# Segmented 15 in folder t16 and saved to A1-raw-data-2/t16/15_seg.npy.
# Segmented 1 in folder t16 and saved to A1-raw-data-2/t16/1_seg.npy.
# Segmented 5 in folder t16 and saved to A1-raw-data-2/t16/5_seg.npy.
# Segmented 6 in folder t16 and saved to A1-raw-data-2/t16/6_seg.npy.
# Segmented 4 in folder t16 and saved to A1-raw-data-2/t16/4_seg.npy.
# Segmented 9 in folder t16 and saved to A1-raw-data-2/t16/9_seg.npy.
# Segmented 10 in folder t16 and saved to A1-raw-data-2/t16/10_seg.npy.
# Segmented 8 in folder t16 and saved to A1-raw-data-2/t16/8_seg.npy.
# Segmented 14 in folder t16 and saved to A1-raw-data-2/t16/14_seg.npy.
# Segmented 3 in folder t16 and saved to A1-raw-data-2/t16/3_seg.npy.
# Segmented 12 in folder t16 and saved to A1-raw-data-2/t16/12_seg.npy.
# Segmented 11 in folder t16 and saved to A1-raw-data-2/t16/11_seg.npy.
# Segmented 13 in folder t16 and saved to A1-raw-data-2/t16/13_seg.npy.
# Segmented 7 in folder t16 and saved to A1-raw-data-2/t16/7_seg.npy.
# Segmented 2 in folder t16 and saved to A1-raw-data-2/t16/2_seg.npy.
# Segmented 15 in folder t34 and saved to A1-raw-data-2/t34/15_seg.npy.
# Segmented 1 in folder t34 and saved to A1-raw-data-2/t34/1_seg.npy.
# Segmented 5 in folder t34 and saved to A1-raw-data-2/t34/5_seg.npy.
# Segmented 6 in folder t34 and saved to A1-raw-data-2/t34/6_seg.npy.
# Segmented 4 in folder t34 and saved to A1-raw-data-2/t34/4_seg.npy.
# Segmented 9 in folder t34 and saved to A1-raw-data-2/t34/9_seg.npy.
# Segmented 10 in folder t34 and saved to A1-raw-data-2/t34/10_seg.npy.
# Segmented 8 in folder t34 and saved to A1-raw-data-2/t34/8_seg.npy.
# Segmented 14 in folder t34 and saved to A1-raw-data-2/t34/14_seg.npy.
# Segmented 3 in folder t34 and saved to A1-raw-data-2/t34/3_seg.npy.
# Segmented 12 in folder t34 and saved to A1-raw-data-2/t34/12_seg.npy.
# Segmented 11 in folder t34 and saved to A1-raw-data-2/t34/11_seg.npy.
# Segmented 13 in folder t34 and saved to A1-raw-data-2/t34/13_seg.npy.
# Segmented 7 in folder t34 and saved to A1-raw-data-2/t34/7_seg.npy.
# Segmented 2 in folder t34 and saved to A1-raw-data-2/t34/2_seg.npy.
# Segmented 15 in folder t22 and saved to A1-raw-data-2/t22/15_seg.npy.
# Segmented 1 in folder t22 and saved to A1-raw-data-2/t22/1_seg.npy.
# Segmented 5 in folder t22 and saved to A1-raw-data-2/t22/5_seg.npy.
# Segmented 6 in folder t22 and saved to A1-raw-data-2/t22/6_seg.npy.
# Segmented 4 in folder t22 and saved to A1-raw-data-2/t22/4_seg.npy.
# Segmented 9 in folder t22 and saved to A1-raw-data-2/t22/9_seg.npy.
# Segmented 10 in folder t22 and saved to A1-raw-data-2/t22/10_seg.npy.
# Segmented 8 in folder t22 and saved to A1-raw-data-2/t22/8_seg.npy.
# Segmented 14 in folder t22 and saved to A1-raw-data-2/t22/14_seg.npy.
# Segmented 3 in folder t22 and saved to A1-raw-data-2/t22/3_seg.npy.
# Segmented 12 in folder t22 and saved to A1-raw-data-2/t22/12_seg.npy.
# Segmented 11 in folder t22 and saved to A1-raw-data-2/t22/11_seg.npy.
# Segmented 13 in folder t22 and saved to A1-raw-data-2/t22/13_seg.npy.
# Segmented 7 in folder t22 and saved to A1-raw-data-2/t22/7_seg.npy.
# Segmented 2 in folder t22 and saved to A1-raw-data-2/t22/2_seg.npy.
# Segmented 15 in folder t20 and saved to A1-raw-data-2/t20/15_seg.npy.
# Segmented 1 in folder t20 and saved to A1-raw-data-2/t20/1_seg.npy.
# Segmented 5 in folder t20 and saved to A1-raw-data-2/t20/5_seg.npy.
# Segmented 6 in folder t20 and saved to A1-raw-data-2/t20/6_seg.npy.
# Segmented 4 in folder t20 and saved to A1-raw-data-2/t20/4_seg.npy.
# Segmented 9 in folder t20 and saved to A1-raw-data-2/t20/9_seg.npy.
# Segmented 10 in folder t20 and saved to A1-raw-data-2/t20/10_seg.npy.
# Segmented 8 in folder t20 and saved to A1-raw-data-2/t20/8_seg.npy.
# Segmented 14 in folder t20 and saved to A1-raw-data-2/t20/14_seg.npy.
# Segmented 3 in folder t20 and saved to A1-raw-data-2/t20/3_seg.npy.
# Segmented 12 in folder t20 and saved to A1-raw-data-2/t20/12_seg.npy.
# Segmented 11 in folder t20 and saved to A1-raw-data-2/t20/11_seg.npy.
# Segmented 13 in folder t20 and saved to A1-raw-data-2/t20/13_seg.npy.
# Segmented 7 in folder t20 and saved to A1-raw-data-2/t20/7_seg.npy.
# Segmented 2 in folder t20 and saved to A1-raw-data-2/t20/2_seg.npy.
# Segmented 15 in folder t43 and saved to A1-raw-data-2/t43/15_seg.npy.
# Segmented 1 in folder t43 and saved to A1-raw-data-2/t43/1_seg.npy.
# Segmented 5 in folder t43 and saved to A1-raw-data-2/t43/5_seg.npy.
# Segmented 6 in folder t43 and saved to A1-raw-data-2/t43/6_seg.npy.
# Segmented 4 in folder t43 and saved to A1-raw-data-2/t43/4_seg.npy.
# Segmented 9 in folder t43 and saved to A1-raw-data-2/t43/9_seg.npy.
# Segmented 10 in folder t43 and saved to A1-raw-data-2/t43/10_seg.npy.
# Segmented 8 in folder t43 and saved to A1-raw-data-2/t43/8_seg.npy.
# Segmented 14 in folder t43 and saved to A1-raw-data-2/t43/14_seg.npy.
# Segmented 3 in folder t43 and saved to A1-raw-data-2/t43/3_seg.npy.
# Segmented 12 in folder t43 and saved to A1-raw-data-2/t43/12_seg.npy.
# Segmented 11 in folder t43 and saved to A1-raw-data-2/t43/11_seg.npy.
# Segmented 13 in folder t43 and saved to A1-raw-data-2/t43/13_seg.npy.
# Segmented 7 in folder t43 and saved to A1-raw-data-2/t43/7_seg.npy.
# Segmented 2 in folder t43 and saved to A1-raw-data-2/t43/2_seg.npy.
# Segmented 15 in folder t33 and saved to A1-raw-data-2/t33/15_seg.npy.
# Segmented 1 in folder t33 and saved to A1-raw-data-2/t33/1_seg.npy.
# Segmented 5 in folder t33 and saved to A1-raw-data-2/t33/5_seg.npy.
# Segmented 6 in folder t33 and saved to A1-raw-data-2/t33/6_seg.npy.
# Segmented 4 in folder t33 and saved to A1-raw-data-2/t33/4_seg.npy.
# Segmented 9 in folder t33 and saved to A1-raw-data-2/t33/9_seg.npy.
# Segmented 10 in folder t33 and saved to A1-raw-data-2/t33/10_seg.npy.
# Segmented 8 in folder t33 and saved to A1-raw-data-2/t33/8_seg.npy.
# Segmented 14 in folder t33 and saved to A1-raw-data-2/t33/14_seg.npy.
# Segmented 3 in folder t33 and saved to A1-raw-data-2/t33/3_seg.npy.
# Segmented 12 in folder t33 and saved to A1-raw-data-2/t33/12_seg.npy.
# Segmented 11 in folder t33 and saved to A1-raw-data-2/t33/11_seg.npy.
# Segmented 13 in folder t33 and saved to A1-raw-data-2/t33/13_seg.npy.
# Segmented 7 in folder t33 and saved to A1-raw-data-2/t33/7_seg.npy.
# Segmented 2 in folder t33 and saved to A1-raw-data-2/t33/2_seg.npy.
# Segmented 15 in folder t42 and saved to A1-raw-data-2/t42/15_seg.npy.
# Segmented 1 in folder t42 and saved to A1-raw-data-2/t42/1_seg.npy.
# Segmented 5 in folder t42 and saved to A1-raw-data-2/t42/5_seg.npy.
# Segmented 6 in folder t42 and saved to A1-raw-data-2/t42/6_seg.npy.
# Segmented 4 in folder t42 and saved to A1-raw-data-2/t42/4_seg.npy.
# Segmented 9 in folder t42 and saved to A1-raw-data-2/t42/9_seg.npy.
# Segmented 10 in folder t42 and saved to A1-raw-data-2/t42/10_seg.npy.
# Segmented 8 in folder t42 and saved to A1-raw-data-2/t42/8_seg.npy.
# Segmented 14 in folder t42 and saved to A1-raw-data-2/t42/14_seg.npy.
# Segmented 3 in folder t42 and saved to A1-raw-data-2/t42/3_seg.npy.
# Segmented 12 in folder t42 and saved to A1-raw-data-2/t42/12_seg.npy.
# Segmented 11 in folder t42 and saved to A1-raw-data-2/t42/11_seg.npy.
# Segmented 13 in folder t42 and saved to A1-raw-data-2/t42/13_seg.npy.
# Segmented 7 in folder t42 and saved to A1-raw-data-2/t42/7_seg.npy.
# Segmented 2 in folder t42 and saved to A1-raw-data-2/t42/2_seg.npy.
# Segmented 15 in folder t27 and saved to A1-raw-data-2/t27/15_seg.npy.
# Segmented 1 in folder t27 and saved to A1-raw-data-2/t27/1_seg.npy.
# Segmented 5 in folder t27 and saved to A1-raw-data-2/t27/5_seg.npy.
# Segmented 6 in folder t27 and saved to A1-raw-data-2/t27/6_seg.npy.
# Segmented 4 in folder t27 and saved to A1-raw-data-2/t27/4_seg.npy.
# Segmented 9 in folder t27 and saved to A1-raw-data-2/t27/9_seg.npy.
# Segmented 10 in folder t27 and saved to A1-raw-data-2/t27/10_seg.npy.
# Segmented 8 in folder t27 and saved to A1-raw-data-2/t27/8_seg.npy.
# Segmented 14 in folder t27 and saved to A1-raw-data-2/t27/14_seg.npy.
# Segmented 3 in folder t27 and saved to A1-raw-data-2/t27/3_seg.npy.
# Segmented 12 in folder t27 and saved to A1-raw-data-2/t27/12_seg.npy.
# Segmented 11 in folder t27 and saved to A1-raw-data-2/t27/11_seg.npy.
# Segmented 13 in folder t27 and saved to A1-raw-data-2/t27/13_seg.npy.
# Segmented 7 in folder t27 and saved to A1-raw-data-2/t27/7_seg.npy.
# Segmented 2 in folder t27 and saved to A1-raw-data-2/t27/2_seg.npy.
# Segmented 15 in folder t13 and saved to A1-raw-data-2/t13/15_seg.npy.
# Segmented 1 in folder t13 and saved to A1-raw-data-2/t13/1_seg.npy.
# Segmented 5 in folder t13 and saved to A1-raw-data-2/t13/5_seg.npy.
# Segmented 6 in folder t13 and saved to A1-raw-data-2/t13/6_seg.npy.
# Segmented 4 in folder t13 and saved to A1-raw-data-2/t13/4_seg.npy.
# Segmented 9 in folder t13 and saved to A1-raw-data-2/t13/9_seg.npy.
# Segmented 10 in folder t13 and saved to A1-raw-data-2/t13/10_seg.npy.
# Segmented 8 in folder t13 and saved to A1-raw-data-2/t13/8_seg.npy.
# Segmented 14 in folder t13 and saved to A1-raw-data-2/t13/14_seg.npy.
# Segmented 3 in folder t13 and saved to A1-raw-data-2/t13/3_seg.npy.
# Segmented 12 in folder t13 and saved to A1-raw-data-2/t13/12_seg.npy.
# Segmented 11 in folder t13 and saved to A1-raw-data-2/t13/11_seg.npy.
# Segmented 13 in folder t13 and saved to A1-raw-data-2/t13/13_seg.npy.
# Segmented 7 in folder t13 and saved to A1-raw-data-2/t13/7_seg.npy.
# Segmented 2 in folder t13 and saved to A1-raw-data-2/t13/2_seg.npy.
# Segmented 15 in folder t25 and saved to A1-raw-data-2/t25/15_seg.npy.
# Segmented 1 in folder t25 and saved to A1-raw-data-2/t25/1_seg.npy.
# Segmented 5 in folder t25 and saved to A1-raw-data-2/t25/5_seg.npy.
# Segmented 6 in folder t25 and saved to A1-raw-data-2/t25/6_seg.npy.
# Segmented 4 in folder t25 and saved to A1-raw-data-2/t25/4_seg.npy.
# Segmented 9 in folder t25 and saved to A1-raw-data-2/t25/9_seg.npy.
# Segmented 10 in folder t25 and saved to A1-raw-data-2/t25/10_seg.npy.
# Segmented 8 in folder t25 and saved to A1-raw-data-2/t25/8_seg.npy.
# Segmented 14 in folder t25 and saved to A1-raw-data-2/t25/14_seg.npy.
# Segmented 3 in folder t25 and saved to A1-raw-data-2/t25/3_seg.npy.
# Segmented 12 in folder t25 and saved to A1-raw-data-2/t25/12_seg.npy.
# Segmented 11 in folder t25 and saved to A1-raw-data-2/t25/11_seg.npy.
# Segmented 13 in folder t25 and saved to A1-raw-data-2/t25/13_seg.npy.
# Segmented 7 in folder t25 and saved to A1-raw-data-2/t25/7_seg.npy.
# Segmented 2 in folder t25 and saved to A1-raw-data-2/t25/2_seg.npy.
# Segmented 15 in folder t29 and saved to A1-raw-data-2/t29/15_seg.npy.
# Segmented 1 in folder t29 and saved to A1-raw-data-2/t29/1_seg.npy.
# Segmented 5 in folder t29 and saved to A1-raw-data-2/t29/5_seg.npy.
# Segmented 6 in folder t29 and saved to A1-raw-data-2/t29/6_seg.npy.
# Segmented 4 in folder t29 and saved to A1-raw-data-2/t29/4_seg.npy.
# Segmented 9 in folder t29 and saved to A1-raw-data-2/t29/9_seg.npy.
# Segmented 10 in folder t29 and saved to A1-raw-data-2/t29/10_seg.npy.
# Segmented 8 in folder t29 and saved to A1-raw-data-2/t29/8_seg.npy.
# Segmented 14 in folder t29 and saved to A1-raw-data-2/t29/14_seg.npy.
# Segmented 3 in folder t29 and saved to A1-raw-data-2/t29/3_seg.npy.
# Segmented 12 in folder t29 and saved to A1-raw-data-2/t29/12_seg.npy.
# Segmented 11 in folder t29 and saved to A1-raw-data-2/t29/11_seg.npy.
# Segmented 13 in folder t29 and saved to A1-raw-data-2/t29/13_seg.npy.
# Segmented 7 in folder t29 and saved to A1-raw-data-2/t29/7_seg.npy.
# Segmented 2 in folder t29 and saved to A1-raw-data-2/t29/2_seg.npy.
# Segmented 15 in folder t17 and saved to A1-raw-data-2/t17/15_seg.npy.
# Segmented 1 in folder t17 and saved to A1-raw-data-2/t17/1_seg.npy.
# Segmented 5 in folder t17 and saved to A1-raw-data-2/t17/5_seg.npy.
# Segmented 6 in folder t17 and saved to A1-raw-data-2/t17/6_seg.npy.
# Segmented 4 in folder t17 and saved to A1-raw-data-2/t17/4_seg.npy.
# Segmented 9 in folder t17 and saved to A1-raw-data-2/t17/9_seg.npy.
# Segmented 10 in folder t17 and saved to A1-raw-data-2/t17/10_seg.npy.
# Segmented 8 in folder t17 and saved to A1-raw-data-2/t17/8_seg.npy.
# Segmented 14 in folder t17 and saved to A1-raw-data-2/t17/14_seg.npy.
# Segmented 3 in folder t17 and saved to A1-raw-data-2/t17/3_seg.npy.
# Segmented 12 in folder t17 and saved to A1-raw-data-2/t17/12_seg.npy.
# Segmented 11 in folder t17 and saved to A1-raw-data-2/t17/11_seg.npy.
# Segmented 13 in folder t17 and saved to A1-raw-data-2/t17/13_seg.npy.
# Segmented 7 in folder t17 and saved to A1-raw-data-2/t17/7_seg.npy.
# Segmented 2 in folder t17 and saved to A1-raw-data-2/t17/2_seg.npy.
# Segmented 15 in folder t3 and saved to A1-raw-data-2/t3/15_seg.npy.
# Segmented 1 in folder t3 and saved to A1-raw-data-2/t3/1_seg.npy.
# Segmented 5 in folder t3 and saved to A1-raw-data-2/t3/5_seg.npy.
# Segmented 6 in folder t3 and saved to A1-raw-data-2/t3/6_seg.npy.
# Segmented 4 in folder t3 and saved to A1-raw-data-2/t3/4_seg.npy.
# Segmented 9 in folder t3 and saved to A1-raw-data-2/t3/9_seg.npy.
# Segmented 10 in folder t3 and saved to A1-raw-data-2/t3/10_seg.npy.
# Segmented 8 in folder t3 and saved to A1-raw-data-2/t3/8_seg.npy.
# Segmented 14 in folder t3 and saved to A1-raw-data-2/t3/14_seg.npy.
# Segmented 3 in folder t3 and saved to A1-raw-data-2/t3/3_seg.npy.
# Segmented 12 in folder t3 and saved to A1-raw-data-2/t3/12_seg.npy.
# Segmented 11 in folder t3 and saved to A1-raw-data-2/t3/11_seg.npy.
# Segmented 13 in folder t3 and saved to A1-raw-data-2/t3/13_seg.npy.
# Segmented 7 in folder t3 and saved to A1-raw-data-2/t3/7_seg.npy.
# Segmented 2 in folder t3 and saved to A1-raw-data-2/t3/2_seg.npy.
# Segmented 15 in folder t32 and saved to A1-raw-data-2/t32/15_seg.npy.
# Segmented 1 in folder t32 and saved to A1-raw-data-2/t32/1_seg.npy.
# Segmented 5 in folder t32 and saved to A1-raw-data-2/t32/5_seg.npy.
# Segmented 6 in folder t32 and saved to A1-raw-data-2/t32/6_seg.npy.
# Segmented 4 in folder t32 and saved to A1-raw-data-2/t32/4_seg.npy.
# Segmented 9 in folder t32 and saved to A1-raw-data-2/t32/9_seg.npy.
# Segmented 10 in folder t32 and saved to A1-raw-data-2/t32/10_seg.npy.
# Segmented 8 in folder t32 and saved to A1-raw-data-2/t32/8_seg.npy.
# Segmented 14 in folder t32 and saved to A1-raw-data-2/t32/14_seg.npy.
# Segmented 3 in folder t32 and saved to A1-raw-data-2/t32/3_seg.npy.
# Segmented 12 in folder t32 and saved to A1-raw-data-2/t32/12_seg.npy.
# Segmented 11 in folder t32 and saved to A1-raw-data-2/t32/11_seg.npy.
# Segmented 13 in folder t32 and saved to A1-raw-data-2/t32/13_seg.npy.
# Segmented 7 in folder t32 and saved to A1-raw-data-2/t32/7_seg.npy.
# Segmented 2 in folder t32 and saved to A1-raw-data-2/t32/2_seg.npy.
# Segmented 15 in folder t7 and saved to A1-raw-data-2/t7/15_seg.npy.
# Segmented 1 in folder t7 and saved to A1-raw-data-2/t7/1_seg.npy.
# Segmented 5 in folder t7 and saved to A1-raw-data-2/t7/5_seg.npy.
# Segmented 6 in folder t7 and saved to A1-raw-data-2/t7/6_seg.npy.
# Segmented 4 in folder t7 and saved to A1-raw-data-2/t7/4_seg.npy.
# Segmented 9 in folder t7 and saved to A1-raw-data-2/t7/9_seg.npy.
# Segmented 10 in folder t7 and saved to A1-raw-data-2/t7/10_seg.npy.
# Segmented 8 in folder t7 and saved to A1-raw-data-2/t7/8_seg.npy.
# Segmented 14 in folder t7 and saved to A1-raw-data-2/t7/14_seg.npy.
# Segmented 3 in folder t7 and saved to A1-raw-data-2/t7/3_seg.npy.
# Segmented 12 in folder t7 and saved to A1-raw-data-2/t7/12_seg.npy.
# Segmented 11 in folder t7 and saved to A1-raw-data-2/t7/11_seg.npy.
# Segmented 13 in folder t7 and saved to A1-raw-data-2/t7/13_seg.npy.
# Segmented 7 in folder t7 and saved to A1-raw-data-2/t7/7_seg.npy.
# Segmented 2 in folder t7 and saved to A1-raw-data-2/t7/2_seg.npy.
# Segmented 15 in folder t1 and saved to A1-raw-data-2/t1/15_seg.npy.
# Segmented 1 in folder t1 and saved to A1-raw-data-2/t1/1_seg.npy.
# Segmented 5 in folder t1 and saved to A1-raw-data-2/t1/5_seg.npy.
# Segmented 6 in folder t1 and saved to A1-raw-data-2/t1/6_seg.npy.
# Segmented 4 in folder t1 and saved to A1-raw-data-2/t1/4_seg.npy.
# Segmented 9 in folder t1 and saved to A1-raw-data-2/t1/9_seg.npy.
# Segmented 10 in folder t1 and saved to A1-raw-data-2/t1/10_seg.npy.
# Segmented 8 in folder t1 and saved to A1-raw-data-2/t1/8_seg.npy.
# Segmented 14 in folder t1 and saved to A1-raw-data-2/t1/14_seg.npy.
# Segmented 3 in folder t1 and saved to A1-raw-data-2/t1/3_seg.npy.
# Segmented 12 in folder t1 and saved to A1-raw-data-2/t1/12_seg.npy.
# Segmented 11 in folder t1 and saved to A1-raw-data-2/t1/11_seg.npy.
# Segmented 13 in folder t1 and saved to A1-raw-data-2/t1/13_seg.npy.
# Segmented 7 in folder t1 and saved to A1-raw-data-2/t1/7_seg.npy.
# Segmented 2 in folder t1 and saved to A1-raw-data-2/t1/2_seg.npy.
# Segmented 15 in folder t46 and saved to A1-raw-data-2/t46/15_seg.npy.
# Segmented 1 in folder t46 and saved to A1-raw-data-2/t46/1_seg.npy.
# Segmented 5 in folder t46 and saved to A1-raw-data-2/t46/5_seg.npy.
# Segmented 6 in folder t46 and saved to A1-raw-data-2/t46/6_seg.npy.
# Segmented 4 in folder t46 and saved to A1-raw-data-2/t46/4_seg.npy.
# Segmented 9 in folder t46 and saved to A1-raw-data-2/t46/9_seg.npy.
# Segmented 10 in folder t46 and saved to A1-raw-data-2/t46/10_seg.npy.
# Segmented 8 in folder t46 and saved to A1-raw-data-2/t46/8_seg.npy.
# Segmented 14 in folder t46 and saved to A1-raw-data-2/t46/14_seg.npy.
# Segmented 3 in folder t46 and saved to A1-raw-data-2/t46/3_seg.npy.
# Segmented 12 in folder t46 and saved to A1-raw-data-2/t46/12_seg.npy.
# Segmented 11 in folder t46 and saved to A1-raw-data-2/t46/11_seg.npy.
# Segmented 13 in folder t46 and saved to A1-raw-data-2/t46/13_seg.npy.
# Segmented 7 in folder t46 and saved to A1-raw-data-2/t46/7_seg.npy.
# Segmented 2 in folder t46 and saved to A1-raw-data-2/t46/2_seg.npy.
# Segmented 15 in folder t18 and saved to A1-raw-data-2/t18/15_seg.npy.
# Segmented 1 in folder t18 and saved to A1-raw-data-2/t18/1_seg.npy.
# Segmented 5 in folder t18 and saved to A1-raw-data-2/t18/5_seg.npy.
# Segmented 6 in folder t18 and saved to A1-raw-data-2/t18/6_seg.npy.
# Segmented 4 in folder t18 and saved to A1-raw-data-2/t18/4_seg.npy.
# Segmented 9 in folder t18 and saved to A1-raw-data-2/t18/9_seg.npy.
# Segmented 10 in folder t18 and saved to A1-raw-data-2/t18/10_seg.npy.
# Segmented 8 in folder t18 and saved to A1-raw-data-2/t18/8_seg.npy.
# Segmented 14 in folder t18 and saved to A1-raw-data-2/t18/14_seg.npy.
# Segmented 3 in folder t18 and saved to A1-raw-data-2/t18/3_seg.npy.
# Segmented 12 in folder t18 and saved to A1-raw-data-2/t18/12_seg.npy.
# Segmented 11 in folder t18 and saved to A1-raw-data-2/t18/11_seg.npy.
# Segmented 13 in folder t18 and saved to A1-raw-data-2/t18/13_seg.npy.
# Segmented 7 in folder t18 and saved to A1-raw-data-2/t18/7_seg.npy.
# Segmented 2 in folder t18 and saved to A1-raw-data-2/t18/2_seg.npy.
# Segmented 15 in folder t2 and saved to A1-raw-data-2/t2/15_seg.npy.
# Segmented 1 in folder t2 and saved to A1-raw-data-2/t2/1_seg.npy.
# Segmented 5 in folder t2 and saved to A1-raw-data-2/t2/5_seg.npy.
# Segmented 6 in folder t2 and saved to A1-raw-data-2/t2/6_seg.npy.
# Segmented 4 in folder t2 and saved to A1-raw-data-2/t2/4_seg.npy.
# Segmented 9 in folder t2 and saved to A1-raw-data-2/t2/9_seg.npy.
# Segmented 10 in folder t2 and saved to A1-raw-data-2/t2/10_seg.npy.
# Segmented 8 in folder t2 and saved to A1-raw-data-2/t2/8_seg.npy.
# Segmented 14 in folder t2 and saved to A1-raw-data-2/t2/14_seg.npy.
# Segmented 3 in folder t2 and saved to A1-raw-data-2/t2/3_seg.npy.
# Segmented 12 in folder t2 and saved to A1-raw-data-2/t2/12_seg.npy.
# Segmented 11 in folder t2 and saved to A1-raw-data-2/t2/11_seg.npy.
# Segmented 13 in folder t2 and saved to A1-raw-data-2/t2/13_seg.npy.
# Segmented 7 in folder t2 and saved to A1-raw-data-2/t2/7_seg.npy.
# Segmented 2 in folder t2 and saved to A1-raw-data-2/t2/2_seg.npy.
# Segmented 15 in folder t36 and saved to A1-raw-data-2/t36/15_seg.npy.
# Segmented 1 in folder t36 and saved to A1-raw-data-2/t36/1_seg.npy.
# Segmented 5 in folder t36 and saved to A1-raw-data-2/t36/5_seg.npy.
# Segmented 6 in folder t36 and saved to A1-raw-data-2/t36/6_seg.npy.
# Segmented 4 in folder t36 and saved to A1-raw-data-2/t36/4_seg.npy.
# Segmented 9 in folder t36 and saved to A1-raw-data-2/t36/9_seg.npy.
# Segmented 10 in folder t36 and saved to A1-raw-data-2/t36/10_seg.npy.
# Segmented 8 in folder t36 and saved to A1-raw-data-2/t36/8_seg.npy.
# Segmented 14 in folder t36 and saved to A1-raw-data-2/t36/14_seg.npy.
# Segmented 3 in folder t36 and saved to A1-raw-data-2/t36/3_seg.npy.
# Segmented 12 in folder t36 and saved to A1-raw-data-2/t36/12_seg.npy.
# Segmented 11 in folder t36 and saved to A1-raw-data-2/t36/11_seg.npy.
# Segmented 13 in folder t36 and saved to A1-raw-data-2/t36/13_seg.npy.
# Segmented 7 in folder t36 and saved to A1-raw-data-2/t36/7_seg.npy.
# Segmented 2 in folder t36 and saved to A1-raw-data-2/t36/2_seg.npy.
# Segmented 15 in folder t24 and saved to A1-raw-data-2/t24/15_seg.npy.
# Segmented 1 in folder t24 and saved to A1-raw-data-2/t24/1_seg.npy.
# Segmented 5 in folder t24 and saved to A1-raw-data-2/t24/5_seg.npy.
# Segmented 6 in folder t24 and saved to A1-raw-data-2/t24/6_seg.npy.
# Segmented 4 in folder t24 and saved to A1-raw-data-2/t24/4_seg.npy.
# Segmented 9 in folder t24 and saved to A1-raw-data-2/t24/9_seg.npy.
# Segmented 10 in folder t24 and saved to A1-raw-data-2/t24/10_seg.npy.
# Segmented 8 in folder t24 and saved to A1-raw-data-2/t24/8_seg.npy.
# Segmented 14 in folder t24 and saved to A1-raw-data-2/t24/14_seg.npy.
# Segmented 3 in folder t24 and saved to A1-raw-data-2/t24/3_seg.npy.
# Segmented 12 in folder t24 and saved to A1-raw-data-2/t24/12_seg.npy.
# Segmented 11 in folder t24 and saved to A1-raw-data-2/t24/11_seg.npy.
# Segmented 13 in folder t24 and saved to A1-raw-data-2/t24/13_seg.npy.
# Segmented 7 in folder t24 and saved to A1-raw-data-2/t24/7_seg.npy.
# Segmented 2 in folder t24 and saved to A1-raw-data-2/t24/2_seg.npy.
# Segmented 15 in folder t39 and saved to A1-raw-data-2/t39/15_seg.npy.
# Segmented 1 in folder t39 and saved to A1-raw-data-2/t39/1_seg.npy.
# Segmented 5 in folder t39 and saved to A1-raw-data-2/t39/5_seg.npy.
# Segmented 6 in folder t39 and saved to A1-raw-data-2/t39/6_seg.npy.
# Segmented 4 in folder t39 and saved to A1-raw-data-2/t39/4_seg.npy.
# Segmented 9 in folder t39 and saved to A1-raw-data-2/t39/9_seg.npy.
# Segmented 10 in folder t39 and saved to A1-raw-data-2/t39/10_seg.npy.
# Segmented 8 in folder t39 and saved to A1-raw-data-2/t39/8_seg.npy.
# Segmented 14 in folder t39 and saved to A1-raw-data-2/t39/14_seg.npy.
# Segmented 3 in folder t39 and saved to A1-raw-data-2/t39/3_seg.npy.
# Segmented 12 in folder t39 and saved to A1-raw-data-2/t39/12_seg.npy.
# Segmented 11 in folder t39 and saved to A1-raw-data-2/t39/11_seg.npy.
# Segmented 13 in folder t39 and saved to A1-raw-data-2/t39/13_seg.npy.
# Segmented 7 in folder t39 and saved to A1-raw-data-2/t39/7_seg.npy.
# Segmented 2 in folder t39 and saved to A1-raw-data-2/t39/2_seg.npy.
# Segmented 15 in folder t28 and saved to A1-raw-data-2/t28/15_seg.npy.
# Segmented 1 in folder t28 and saved to A1-raw-data-2/t28/1_seg.npy.
# Segmented 5 in folder t28 and saved to A1-raw-data-2/t28/5_seg.npy.
# Segmented 6 in folder t28 and saved to A1-raw-data-2/t28/6_seg.npy.
# Segmented 4 in folder t28 and saved to A1-raw-data-2/t28/4_seg.npy.
# Segmented 9 in folder t28 and saved to A1-raw-data-2/t28/9_seg.npy.
# Segmented 10 in folder t28 and saved to A1-raw-data-2/t28/10_seg.npy.
# Segmented 8 in folder t28 and saved to A1-raw-data-2/t28/8_seg.npy.
# Segmented 14 in folder t28 and saved to A1-raw-data-2/t28/14_seg.npy.
# Segmented 3 in folder t28 and saved to A1-raw-data-2/t28/3_seg.npy.
# Segmented 12 in folder t28 and saved to A1-raw-data-2/t28/12_seg.npy.
# Segmented 11 in folder t28 and saved to A1-raw-data-2/t28/11_seg.npy.
# Segmented 13 in folder t28 and saved to A1-raw-data-2/t28/13_seg.npy.
# Segmented 7 in folder t28 and saved to A1-raw-data-2/t28/7_seg.npy.
# Segmented 2 in folder t28 and saved to A1-raw-data-2/t28/2_seg.npy.
# Segmented 15 in folder t8 and saved to A1-raw-data-2/t8/15_seg.npy.
# Segmented 1 in folder t8 and saved to A1-raw-data-2/t8/1_seg.npy.
# Segmented 5 in folder t8 and saved to A1-raw-data-2/t8/5_seg.npy.
# Segmented 6 in folder t8 and saved to A1-raw-data-2/t8/6_seg.npy.
# Segmented 4 in folder t8 and saved to A1-raw-data-2/t8/4_seg.npy.
# Segmented 9 in folder t8 and saved to A1-raw-data-2/t8/9_seg.npy.
# Segmented 10 in folder t8 and saved to A1-raw-data-2/t8/10_seg.npy.
# Segmented 8 in folder t8 and saved to A1-raw-data-2/t8/8_seg.npy.
# Segmented 14 in folder t8 and saved to A1-raw-data-2/t8/14_seg.npy.
# Segmented 3 in folder t8 and saved to A1-raw-data-2/t8/3_seg.npy.
# Segmented 12 in folder t8 and saved to A1-raw-data-2/t8/12_seg.npy.
# Segmented 11 in folder t8 and saved to A1-raw-data-2/t8/11_seg.npy.
# Segmented 13 in folder t8 and saved to A1-raw-data-2/t8/13_seg.npy.
# Segmented 7 in folder t8 and saved to A1-raw-data-2/t8/7_seg.npy.
# Segmented 2 in folder t8 and saved to A1-raw-data-2/t8/2_seg.npy.
# Segmented 15 in folder t38 and saved to A1-raw-data-2/t38/15_seg.npy.
# Segmented 1 in folder t38 and saved to A1-raw-data-2/t38/1_seg.npy.
# Segmented 5 in folder t38 and saved to A1-raw-data-2/t38/5_seg.npy.
# Segmented 6 in folder t38 and saved to A1-raw-data-2/t38/6_seg.npy.
# Segmented 4 in folder t38 and saved to A1-raw-data-2/t38/4_seg.npy.
# Segmented 9 in folder t38 and saved to A1-raw-data-2/t38/9_seg.npy.
# Segmented 10 in folder t38 and saved to A1-raw-data-2/t38/10_seg.npy.
# Segmented 8 in folder t38 and saved to A1-raw-data-2/t38/8_seg.npy.
# Segmented 14 in folder t38 and saved to A1-raw-data-2/t38/14_seg.npy.
# Segmented 3 in folder t38 and saved to A1-raw-data-2/t38/3_seg.npy.
# Segmented 12 in folder t38 and saved to A1-raw-data-2/t38/12_seg.npy.
# Segmented 11 in folder t38 and saved to A1-raw-data-2/t38/11_seg.npy.
# Segmented 13 in folder t38 and saved to A1-raw-data-2/t38/13_seg.npy.
# Segmented 7 in folder t38 and saved to A1-raw-data-2/t38/7_seg.npy.
# Segmented 2 in folder t38 and saved to A1-raw-data-2/t38/2_seg.npy.
# Segmented 15 in folder t15 and saved to A1-raw-data-2/t15/15_seg.npy.
# Segmented 1 in folder t15 and saved to A1-raw-data-2/t15/1_seg.npy.
# Segmented 5 in folder t15 and saved to A1-raw-data-2/t15/5_seg.npy.
# Segmented 6 in folder t15 and saved to A1-raw-data-2/t15/6_seg.npy.
# Segmented 4 in folder t15 and saved to A1-raw-data-2/t15/4_seg.npy.
# Segmented 9 in folder t15 and saved to A1-raw-data-2/t15/9_seg.npy.
# Segmented 10 in folder t15 and saved to A1-raw-data-2/t15/10_seg.npy.
# Segmented 8 in folder t15 and saved to A1-raw-data-2/t15/8_seg.npy.
# Segmented 14 in folder t15 and saved to A1-raw-data-2/t15/14_seg.npy.
# Segmented 3 in folder t15 and saved to A1-raw-data-2/t15/3_seg.npy.
# Segmented 12 in folder t15 and saved to A1-raw-data-2/t15/12_seg.npy.
# Segmented 11 in folder t15 and saved to A1-raw-data-2/t15/11_seg.npy.
# Segmented 13 in folder t15 and saved to A1-raw-data-2/t15/13_seg.npy.
# Segmented 7 in folder t15 and saved to A1-raw-data-2/t15/7_seg.npy.
# Segmented 2 in folder t15 and saved to A1-raw-data-2/t15/2_seg.npy.
# Segmented 15 in folder t19 and saved to A1-raw-data-2/t19/15_seg.npy.
# Segmented 1 in folder t19 and saved to A1-raw-data-2/t19/1_seg.npy.
# Segmented 5 in folder t19 and saved to A1-raw-data-2/t19/5_seg.npy.
# Segmented 6 in folder t19 and saved to A1-raw-data-2/t19/6_seg.npy.
# Segmented 4 in folder t19 and saved to A1-raw-data-2/t19/4_seg.npy.
# Segmented 9 in folder t19 and saved to A1-raw-data-2/t19/9_seg.npy.
# Segmented 10 in folder t19 and saved to A1-raw-data-2/t19/10_seg.npy.
# Segmented 8 in folder t19 and saved to A1-raw-data-2/t19/8_seg.npy.
# Segmented 14 in folder t19 and saved to A1-raw-data-2/t19/14_seg.npy.
# Segmented 3 in folder t19 and saved to A1-raw-data-2/t19/3_seg.npy.
# Segmented 12 in folder t19 and saved to A1-raw-data-2/t19/12_seg.npy.
# Segmented 11 in folder t19 and saved to A1-raw-data-2/t19/11_seg.npy.
# Segmented 13 in folder t19 and saved to A1-raw-data-2/t19/13_seg.npy.
# Segmented 7 in folder t19 and saved to A1-raw-data-2/t19/7_seg.npy.
# Segmented 2 in folder t19 and saved to A1-raw-data-2/t19/2_seg.npy.
# Segmented 15 in folder t10 and saved to A1-raw-data-2/t10/15_seg.npy.
# Segmented 1 in folder t10 and saved to A1-raw-data-2/t10/1_seg.npy.
# Segmented 5 in folder t10 and saved to A1-raw-data-2/t10/5_seg.npy.
# Segmented 6 in folder t10 and saved to A1-raw-data-2/t10/6_seg.npy.
# Segmented 4 in folder t10 and saved to A1-raw-data-2/t10/4_seg.npy.
# Segmented 9 in folder t10 and saved to A1-raw-data-2/t10/9_seg.npy.
# Segmented 10 in folder t10 and saved to A1-raw-data-2/t10/10_seg.npy.
# Segmented 8 in folder t10 and saved to A1-raw-data-2/t10/8_seg.npy.
# Segmented 14 in folder t10 and saved to A1-raw-data-2/t10/14_seg.npy.
# Segmented 3 in folder t10 and saved to A1-raw-data-2/t10/3_seg.npy.
# Segmented 12 in folder t10 and saved to A1-raw-data-2/t10/12_seg.npy.
# Segmented 11 in folder t10 and saved to A1-raw-data-2/t10/11_seg.npy.
# Segmented 13 in folder t10 and saved to A1-raw-data-2/t10/13_seg.npy.
# Segmented 7 in folder t10 and saved to A1-raw-data-2/t10/7_seg.npy.
# Segmented 2 in folder t10 and saved to A1-raw-data-2/t10/2_seg.npy.
# Segmented 15 in folder t23 and saved to A1-raw-data-2/t23/15_seg.npy.
# Segmented 1 in folder t23 and saved to A1-raw-data-2/t23/1_seg.npy.
# Segmented 5 in folder t23 and saved to A1-raw-data-2/t23/5_seg.npy.
# Segmented 6 in folder t23 and saved to A1-raw-data-2/t23/6_seg.npy.
# Segmented 4 in folder t23 and saved to A1-raw-data-2/t23/4_seg.npy.
# Segmented 9 in folder t23 and saved to A1-raw-data-2/t23/9_seg.npy.
# Segmented 10 in folder t23 and saved to A1-raw-data-2/t23/10_seg.npy.
# Segmented 8 in folder t23 and saved to A1-raw-data-2/t23/8_seg.npy.
# Segmented 14 in folder t23 and saved to A1-raw-data-2/t23/14_seg.npy.
# Segmented 3 in folder t23 and saved to A1-raw-data-2/t23/3_seg.npy.
# Segmented 12 in folder t23 and saved to A1-raw-data-2/t23/12_seg.npy.
# Segmented 11 in folder t23 and saved to A1-raw-data-2/t23/11_seg.npy.
# Segmented 13 in folder t23 and saved to A1-raw-data-2/t23/13_seg.npy.
# Segmented 7 in folder t23 and saved to A1-raw-data-2/t23/7_seg.npy.
# Segmented 2 in folder t23 and saved to A1-raw-data-2/t23/2_seg.npy.
# Segmented 15 in folder t5 and saved to A1-raw-data-2/t5/15_seg.npy.
# Segmented 1 in folder t5 and saved to A1-raw-data-2/t5/1_seg.npy.
# Segmented 5 in folder t5 and saved to A1-raw-data-2/t5/5_seg.npy.
# Segmented 6 in folder t5 and saved to A1-raw-data-2/t5/6_seg.npy.
# Segmented 4 in folder t5 and saved to A1-raw-data-2/t5/4_seg.npy.
# Segmented 9 in folder t5 and saved to A1-raw-data-2/t5/9_seg.npy.
# Segmented 10 in folder t5 and saved to A1-raw-data-2/t5/10_seg.npy.
# Segmented 8 in folder t5 and saved to A1-raw-data-2/t5/8_seg.npy.
# Segmented 14 in folder t5 and saved to A1-raw-data-2/t5/14_seg.npy.
# Segmented 3 in folder t5 and saved to A1-raw-data-2/t5/3_seg.npy.
# Segmented 12 in folder t5 and saved to A1-raw-data-2/t5/12_seg.npy.
# Segmented 11 in folder t5 and saved to A1-raw-data-2/t5/11_seg.npy.
# Segmented 13 in folder t5 and saved to A1-raw-data-2/t5/13_seg.npy.
# Segmented 7 in folder t5 and saved to A1-raw-data-2/t5/7_seg.npy.
# Segmented 2 in folder t5 and saved to A1-raw-data-2/t5/2_seg.npy.
# Segmented 15 in folder t14 and saved to A1-raw-data-2/t14/15_seg.npy.
# Segmented 1 in folder t14 and saved to A1-raw-data-2/t14/1_seg.npy.
# Segmented 5 in folder t14 and saved to A1-raw-data-2/t14/5_seg.npy.
# Segmented 6 in folder t14 and saved to A1-raw-data-2/t14/6_seg.npy.
# Segmented 4 in folder t14 and saved to A1-raw-data-2/t14/4_seg.npy.
# Segmented 9 in folder t14 and saved to A1-raw-data-2/t14/9_seg.npy.
# Segmented 10 in folder t14 and saved to A1-raw-data-2/t14/10_seg.npy.
# Segmented 8 in folder t14 and saved to A1-raw-data-2/t14/8_seg.npy.
# Segmented 14 in folder t14 and saved to A1-raw-data-2/t14/14_seg.npy.
# Segmented 3 in folder t14 and saved to A1-raw-data-2/t14/3_seg.npy.
# Segmented 12 in folder t14 and saved to A1-raw-data-2/t14/12_seg.npy.
# Segmented 11 in folder t14 and saved to A1-raw-data-2/t14/11_seg.npy.
# Segmented 13 in folder t14 and saved to A1-raw-data-2/t14/13_seg.npy.
# Segmented 7 in folder t14 and saved to A1-raw-data-2/t14/7_seg.npy.
# Segmented 2 in folder t14 and saved to A1-raw-data-2/t14/2_seg.npy.
# Segmented 15 in folder t44 and saved to A1-raw-data-2/t44/15_seg.npy.
# Segmented 1 in folder t44 and saved to A1-raw-data-2/t44/1_seg.npy.
# Segmented 5 in folder t44 and saved to A1-raw-data-2/t44/5_seg.npy.
# Segmented 6 in folder t44 and saved to A1-raw-data-2/t44/6_seg.npy.
# Segmented 4 in folder t44 and saved to A1-raw-data-2/t44/4_seg.npy.
# Segmented 9 in folder t44 and saved to A1-raw-data-2/t44/9_seg.npy.
# Segmented 10 in folder t44 and saved to A1-raw-data-2/t44/10_seg.npy.
# Segmented 8 in folder t44 and saved to A1-raw-data-2/t44/8_seg.npy.
# Segmented 14 in folder t44 and saved to A1-raw-data-2/t44/14_seg.npy.
# Segmented 3 in folder t44 and saved to A1-raw-data-2/t44/3_seg.npy.
# Segmented 12 in folder t44 and saved to A1-raw-data-2/t44/12_seg.npy.
# Segmented 11 in folder t44 and saved to A1-raw-data-2/t44/11_seg.npy.
# Segmented 13 in folder t44 and saved to A1-raw-data-2/t44/13_seg.npy.
# Segmented 7 in folder t44 and saved to A1-raw-data-2/t44/7_seg.npy.
# Segmented 2 in folder t44 and saved to A1-raw-data-2/t44/2_seg.npy.
# Segmented 15 in folder t45 and saved to A1-raw-data-2/t45/15_seg.npy.
# Segmented 1 in folder t45 and saved to A1-raw-data-2/t45/1_seg.npy.
# Segmented 5 in folder t45 and saved to A1-raw-data-2/t45/5_seg.npy.
# Segmented 6 in folder t45 and saved to A1-raw-data-2/t45/6_seg.npy.
# Segmented 4 in folder t45 and saved to A1-raw-data-2/t45/4_seg.npy.
# Segmented 9 in folder t45 and saved to A1-raw-data-2/t45/9_seg.npy.
# Segmented 10 in folder t45 and saved to A1-raw-data-2/t45/10_seg.npy.
# Segmented 8 in folder t45 and saved to A1-raw-data-2/t45/8_seg.npy.
# Segmented 14 in folder t45 and saved to A1-raw-data-2/t45/14_seg.npy.
# Segmented 3 in folder t45 and saved to A1-raw-data-2/t45/3_seg.npy.
# Segmented 12 in folder t45 and saved to A1-raw-data-2/t45/12_seg.npy.
# Segmented 11 in folder t45 and saved to A1-raw-data-2/t45/11_seg.npy.
# Segmented 13 in folder t45 and saved to A1-raw-data-2/t45/13_seg.npy.
# Segmented 7 in folder t45 and saved to A1-raw-data-2/t45/7_seg.npy.
# Segmented 2 in folder t45 and saved to A1-raw-data-2/t45/2_seg.npy.
# Segmented 15 in folder t11 and saved to A1-raw-data-2/t11/15_seg.npy.
# Segmented 1 in folder t11 and saved to A1-raw-data-2/t11/1_seg.npy.
# Segmented 5 in folder t11 and saved to A1-raw-data-2/t11/5_seg.npy.
# Segmented 6 in folder t11 and saved to A1-raw-data-2/t11/6_seg.npy.
# Segmented 4 in folder t11 and saved to A1-raw-data-2/t11/4_seg.npy.
# Segmented 9 in folder t11 and saved to A1-raw-data-2/t11/9_seg.npy.
# Segmented 10 in folder t11 and saved to A1-raw-data-2/t11/10_seg.npy.
# Segmented 8 in folder t11 and saved to A1-raw-data-2/t11/8_seg.npy.
# Segmented 14 in folder t11 and saved to A1-raw-data-2/t11/14_seg.npy.
# Segmented 3 in folder t11 and saved to A1-raw-data-2/t11/3_seg.npy.
# Segmented 12 in folder t11 and saved to A1-raw-data-2/t11/12_seg.npy.
# Segmented 11 in folder t11 and saved to A1-raw-data-2/t11/11_seg.npy.
# Segmented 13 in folder t11 and saved to A1-raw-data-2/t11/13_seg.npy.
# Segmented 7 in folder t11 and saved to A1-raw-data-2/t11/7_seg.npy.
# no seeds found in get_masks_torch - no masks found.
# Segmented 2 in folder t11 and saved to A1-raw-data-2/t11/2_seg.npy.
# Segmented 15 in folder t4 and saved to A1-raw-data-2/t4/15_seg.npy.
# Segmented 1 in folder t4 and saved to A1-raw-data-2/t4/1_seg.npy.
# Segmented 5 in folder t4 and saved to A1-raw-data-2/t4/5_seg.npy.
# Segmented 6 in folder t4 and saved to A1-raw-data-2/t4/6_seg.npy.
# Segmented 4 in folder t4 and saved to A1-raw-data-2/t4/4_seg.npy.
# Segmented 9 in folder t4 and saved to A1-raw-data-2/t4/9_seg.npy.
# Segmented 10 in folder t4 and saved to A1-raw-data-2/t4/10_seg.npy.
# Segmented 8 in folder t4 and saved to A1-raw-data-2/t4/8_seg.npy.
# Segmented 14 in folder t4 and saved to A1-raw-data-2/t4/14_seg.npy.
# Segmented 3 in folder t4 and saved to A1-raw-data-2/t4/3_seg.npy.
# Segmented 12 in folder t4 and saved to A1-raw-data-2/t4/12_seg.npy.
# Segmented 11 in folder t4 and saved to A1-raw-data-2/t4/11_seg.npy.
# Segmented 13 in folder t4 and saved to A1-raw-data-2/t4/13_seg.npy.
# Segmented 7 in folder t4 and saved to A1-raw-data-2/t4/7_seg.npy.
# Segmented 2 in folder t4 and saved to A1-raw-data-2/t4/2_seg.npy.
# Segmented 15 in folder t26 and saved to A1-raw-data-2/t26/15_seg.npy.
# Segmented 1 in folder t26 and saved to A1-raw-data-2/t26/1_seg.npy.
# Segmented 5 in folder t26 and saved to A1-raw-data-2/t26/5_seg.npy.
# Segmented 6 in folder t26 and saved to A1-raw-data-2/t26/6_seg.npy.
# Segmented 4 in folder t26 and saved to A1-raw-data-2/t26/4_seg.npy.
# Segmented 9 in folder t26 and saved to A1-raw-data-2/t26/9_seg.npy.
# Segmented 10 in folder t26 and saved to A1-raw-data-2/t26/10_seg.npy.
# Segmented 8 in folder t26 and saved to A1-raw-data-2/t26/8_seg.npy.
# Segmented 14 in folder t26 and saved to A1-raw-data-2/t26/14_seg.npy.
# Segmented 3 in folder t26 and saved to A1-raw-data-2/t26/3_seg.npy.
# Segmented 12 in folder t26 and saved to A1-raw-data-2/t26/12_seg.npy.
# Segmented 11 in folder t26 and saved to A1-raw-data-2/t26/11_seg.npy.
# Segmented 13 in folder t26 and saved to A1-raw-data-2/t26/13_seg.npy.
# Segmented 7 in folder t26 and saved to A1-raw-data-2/t26/7_seg.npy.
# Segmented 2 in folder t26 and saved to A1-raw-data-2/t26/2_seg.npy.
# Segmented 15 in folder t30 and saved to A1-raw-data-2/t30/15_seg.npy.
# Segmented 1 in folder t30 and saved to A1-raw-data-2/t30/1_seg.npy.
# Segmented 5 in folder t30 and saved to A1-raw-data-2/t30/5_seg.npy.
# Segmented 6 in folder t30 and saved to A1-raw-data-2/t30/6_seg.npy.
# Segmented 4 in folder t30 and saved to A1-raw-data-2/t30/4_seg.npy.
# Segmented 9 in folder t30 and saved to A1-raw-data-2/t30/9_seg.npy.
# Segmented 10 in folder t30 and saved to A1-raw-data-2/t30/10_seg.npy.
# Segmented 8 in folder t30 and saved to A1-raw-data-2/t30/8_seg.npy.
# Segmented 14 in folder t30 and saved to A1-raw-data-2/t30/14_seg.npy.
# Segmented 3 in folder t30 and saved to A1-raw-data-2/t30/3_seg.npy.
# Segmented 12 in folder t30 and saved to A1-raw-data-2/t30/12_seg.npy.
# Segmented 11 in folder t30 and saved to A1-raw-data-2/t30/11_seg.npy.
# Segmented 13 in folder t30 and saved to A1-raw-data-2/t30/13_seg.npy.
# Segmented 7 in folder t30 and saved to A1-raw-data-2/t30/7_seg.npy.
# Segmented 2 in folder t30 and saved to A1-raw-data-2/t30/2_seg.npy.
# Segmented 15 in folder t6 and saved to A1-raw-data-2/t6/15_seg.npy.
# Segmented 1 in folder t6 and saved to A1-raw-data-2/t6/1_seg.npy.
# Segmented 5 in folder t6 and saved to A1-raw-data-2/t6/5_seg.npy.
# Segmented 6 in folder t6 and saved to A1-raw-data-2/t6/6_seg.npy.
# Segmented 4 in folder t6 and saved to A1-raw-data-2/t6/4_seg.npy.
# Segmented 9 in folder t6 and saved to A1-raw-data-2/t6/9_seg.npy.
# Segmented 10 in folder t6 and saved to A1-raw-data-2/t6/10_seg.npy.
# Segmented 8 in folder t6 and saved to A1-raw-data-2/t6/8_seg.npy.
# Segmented 14 in folder t6 and saved to A1-raw-data-2/t6/14_seg.npy.
# Segmented 3 in folder t6 and saved to A1-raw-data-2/t6/3_seg.npy.
# Segmented 12 in folder t6 and saved to A1-raw-data-2/t6/12_seg.npy.
# Segmented 11 in folder t6 and saved to A1-raw-data-2/t6/11_seg.npy.
# Segmented 13 in folder t6 and saved to A1-raw-data-2/t6/13_seg.npy.
# Segmented 7 in folder t6 and saved to A1-raw-data-2/t6/7_seg.npy.
# Segmented 2 in folder t6 and saved to A1-raw-data-2/t6/2_seg.npy.
# Segmented 15 in folder t12 and saved to A1-raw-data-2/t12/15_seg.npy.
# Segmented 1 in folder t12 and saved to A1-raw-data-2/t12/1_seg.npy.
# Segmented 5 in folder t12 and saved to A1-raw-data-2/t12/5_seg.npy.
# Segmented 6 in folder t12 and saved to A1-raw-data-2/t12/6_seg.npy.
# Segmented 4 in folder t12 and saved to A1-raw-data-2/t12/4_seg.npy.
# Segmented 9 in folder t12 and saved to A1-raw-data-2/t12/9_seg.npy.
# Segmented 10 in folder t12 and saved to A1-raw-data-2/t12/10_seg.npy.
# Segmented 8 in folder t12 and saved to A1-raw-data-2/t12/8_seg.npy.
# Segmented 14 in folder t12 and saved to A1-raw-data-2/t12/14_seg.npy.
# Segmented 3 in folder t12 and saved to A1-raw-data-2/t12/3_seg.npy.
# Segmented 12 in folder t12 and saved to A1-raw-data-2/t12/12_seg.npy.
# Segmented 11 in folder t12 and saved to A1-raw-data-2/t12/11_seg.npy.
# Segmented 13 in folder t12 and saved to A1-raw-data-2/t12/13_seg.npy.
# Segmented 7 in folder t12 and saved to A1-raw-data-2/t12/7_seg.npy.
# Segmented 2 in folder t12 and saved to A1-raw-data-2/t12/2_seg.npy.
# Segmented 15 in folder t35 and saved to A1-raw-data-2/t35/15_seg.npy.
# Segmented 1 in folder t35 and saved to A1-raw-data-2/t35/1_seg.npy.
# Segmented 5 in folder t35 and saved to A1-raw-data-2/t35/5_seg.npy.
# Segmented 6 in folder t35 and saved to A1-raw-data-2/t35/6_seg.npy.
# Segmented 4 in folder t35 and saved to A1-raw-data-2/t35/4_seg.npy.
# Segmented 9 in folder t35 and saved to A1-raw-data-2/t35/9_seg.npy.
# Segmented 10 in folder t35 and saved to A1-raw-data-2/t35/10_seg.npy.
# Segmented 8 in folder t35 and saved to A1-raw-data-2/t35/8_seg.npy.
# Segmented 14 in folder t35 and saved to A1-raw-data-2/t35/14_seg.npy.
# Segmented 3 in folder t35 and saved to A1-raw-data-2/t35/3_seg.npy.
# Segmented 12 in folder t35 and saved to A1-raw-data-2/t35/12_seg.npy.
# Segmented 11 in folder t35 and saved to A1-raw-data-2/t35/11_seg.npy.
# Segmented 13 in folder t35 and saved to A1-raw-data-2/t35/13_seg.npy.
# Segmented 7 in folder t35 and saved to A1-raw-data-2/t35/7_seg.npy.
# Segmented 2 in folder t35 and saved to A1-raw-data-2/t35/2_seg.npy.
# Segmented 15 in folder t21 and saved to A1-raw-data-2/t21/15_seg.npy.
# Segmented 1 in folder t21 and saved to A1-raw-data-2/t21/1_seg.npy.
# Segmented 5 in folder t21 and saved to A1-raw-data-2/t21/5_seg.npy.
# Segmented 6 in folder t21 and saved to A1-raw-data-2/t21/6_seg.npy.
# Segmented 4 in folder t21 and saved to A1-raw-data-2/t21/4_seg.npy.
# Segmented 9 in folder t21 and saved to A1-raw-data-2/t21/9_seg.npy.
# Segmented 10 in folder t21 and saved to A1-raw-data-2/t21/10_seg.npy.
# Segmented 8 in folder t21 and saved to A1-raw-data-2/t21/8_seg.npy.
# Segmented 14 in folder t21 and saved to A1-raw-data-2/t21/14_seg.npy.
# Segmented 3 in folder t21 and saved to A1-raw-data-2/t21/3_seg.npy.
# Segmented 12 in folder t21 and saved to A1-raw-data-2/t21/12_seg.npy.
# Segmented 11 in folder t21 and saved to A1-raw-data-2/t21/11_seg.npy.
# Segmented 13 in folder t21 and saved to A1-raw-data-2/t21/13_seg.npy.
# Segmented 7 in folder t21 and saved to A1-raw-data-2/t21/7_seg.npy.
# Segmented 2 in folder t21 and saved to A1-raw-data-2/t21/2_seg.npy.
# Segmented 15 in folder t41 and saved to A1-raw-data-2/t41/15_seg.npy.
# Segmented 1 in folder t41 and saved to A1-raw-data-2/t41/1_seg.npy.
# Segmented 5 in folder t41 and saved to A1-raw-data-2/t41/5_seg.npy.
# Segmented 6 in folder t41 and saved to A1-raw-data-2/t41/6_seg.npy.
# Segmented 4 in folder t41 and saved to A1-raw-data-2/t41/4_seg.npy.
# Segmented 9 in folder t41 and saved to A1-raw-data-2/t41/9_seg.npy.
# Segmented 10 in folder t41 and saved to A1-raw-data-2/t41/10_seg.npy.
# Segmented 8 in folder t41 and saved to A1-raw-data-2/t41/8_seg.npy.
# Segmented 14 in folder t41 and saved to A1-raw-data-2/t41/14_seg.npy.
# Segmented 3 in folder t41 and saved to A1-raw-data-2/t41/3_seg.npy.
# Segmented 12 in folder t41 and saved to A1-raw-data-2/t41/12_seg.npy.
# Segmented 11 in folder t41 and saved to A1-raw-data-2/t41/11_seg.npy.
# Segmented 13 in folder t41 and saved to A1-raw-data-2/t41/13_seg.npy.
# Segmented 7 in folder t41 and saved to A1-raw-data-2/t41/7_seg.npy.
# Segmented 2 in folder t41 and saved to A1-raw-data-2/t41/2_seg.npy.
# Segmented 15 in folder t40 and saved to A1-raw-data-2/t40/15_seg.npy.
# Segmented 1 in folder t40 and saved to A1-raw-data-2/t40/1_seg.npy.
# Segmented 5 in folder t40 and saved to A1-raw-data-2/t40/5_seg.npy.
# Segmented 6 in folder t40 and saved to A1-raw-data-2/t40/6_seg.npy.
# Segmented 4 in folder t40 and saved to A1-raw-data-2/t40/4_seg.npy.
# Segmented 9 in folder t40 and saved to A1-raw-data-2/t40/9_seg.npy.
# Segmented 10 in folder t40 and saved to A1-raw-data-2/t40/10_seg.npy.
# Segmented 8 in folder t40 and saved to A1-raw-data-2/t40/8_seg.npy.
# Segmented 14 in folder t40 and saved to A1-raw-data-2/t40/14_seg.npy.
# Segmented 3 in folder t40 and saved to A1-raw-data-2/t40/3_seg.npy.
# Segmented 12 in folder t40 and saved to A1-raw-data-2/t40/12_seg.npy.
# Segmented 11 in folder t40 and saved to A1-raw-data-2/t40/11_seg.npy.
# Segmented 13 in folder t40 and saved to A1-raw-data-2/t40/13_seg.npy.
# Segmented 7 in folder t40 and saved to A1-raw-data-2/t40/7_seg.npy.
# Segmented 2 in folder t40 and saved to A1-raw-data-2/t40/2_seg.npy.
# Segmented 15 in folder t31 and saved to A1-raw-data-2/t31/15_seg.npy.
# Segmented 1 in folder t31 and saved to A1-raw-data-2/t31/1_seg.npy.
# Segmented 5 in folder t31 and saved to A1-raw-data-2/t31/5_seg.npy.
# Segmented 6 in folder t31 and saved to A1-raw-data-2/t31/6_seg.npy.
# Segmented 4 in folder t31 and saved to A1-raw-data-2/t31/4_seg.npy.
# Segmented 9 in folder t31 and saved to A1-raw-data-2/t31/9_seg.npy.
# Segmented 10 in folder t31 and saved to A1-raw-data-2/t31/10_seg.npy.
# Segmented 8 in folder t31 and saved to A1-raw-data-2/t31/8_seg.npy.
# Segmented 14 in folder t31 and saved to A1-raw-data-2/t31/14_seg.npy.
# Segmented 3 in folder t31 and saved to A1-raw-data-2/t31/3_seg.npy.
# Segmented 12 in folder t31 and saved to A1-raw-data-2/t31/12_seg.npy.
# Segmented 11 in folder t31 and saved to A1-raw-data-2/t31/11_seg.npy.
# Segmented 13 in folder t31 and saved to A1-raw-data-2/t31/13_seg.npy.
# Segmented 7 in folder t31 and saved to A1-raw-data-2/t31/7_seg.npy.
# Segmented 2 in folder t31 and saved to A1-raw-data-2/t31/2_seg.npy.
# Segmented 15 in folder t37 and saved to A1-raw-data-2/t37/15_seg.npy.
# Segmented 1 in folder t37 and saved to A1-raw-data-2/t37/1_seg.npy.
# Segmented 5 in folder t37 and saved to A1-raw-data-2/t37/5_seg.npy.
# Segmented 6 in folder t37 and saved to A1-raw-data-2/t37/6_seg.npy.
# Segmented 4 in folder t37 and saved to A1-raw-data-2/t37/4_seg.npy.
# Segmented 9 in folder t37 and saved to A1-raw-data-2/t37/9_seg.npy.
# Segmented 10 in folder t37 and saved to A1-raw-data-2/t37/10_seg.npy.
# Segmented 8 in folder t37 and saved to A1-raw-data-2/t37/8_seg.npy.
# Segmented 14 in folder t37 and saved to A1-raw-data-2/t37/14_seg.npy.
# Segmented 3 in folder t37 and saved to A1-raw-data-2/t37/3_seg.npy.
# Segmented 12 in folder t37 and saved to A1-raw-data-2/t37/12_seg.npy.
# Segmented 11 in folder t37 and saved to A1-raw-data-2/t37/11_seg.npy.
# Segmented 13 in folder t37 and saved to A1-raw-data-2/t37/13_seg.npy.
# Segmented 7 in folder t37 and saved to A1-raw-data-2/t37/7_seg.npy.
# Segmented 2 in folder t37 and saved to A1-raw-data-2/t37/2_seg.npy.
# Segmented 15 in folder t9 and saved to A1-raw-data-2/t9/15_seg.npy.
# Segmented 1 in folder t9 and saved to A1-raw-data-2/t9/1_seg.npy.
# Segmented 5 in folder t9 and saved to A1-raw-data-2/t9/5_seg.npy.
# Segmented 6 in folder t9 and saved to A1-raw-data-2/t9/6_seg.npy.
# Segmented 4 in folder t9 and saved to A1-raw-data-2/t9/4_seg.npy.
# Segmented 9 in folder t9 and saved to A1-raw-data-2/t9/9_seg.npy.
# Segmented 10 in folder t9 and saved to A1-raw-data-2/t9/10_seg.npy.
# Segmented 8 in folder t9 and saved to A1-raw-data-2/t9/8_seg.npy.
# Segmented 14 in folder t9 and saved to A1-raw-data-2/t9/14_seg.npy.
# Segmented 3 in folder t9 and saved to A1-raw-data-2/t9/3_seg.npy.
# Segmented 12 in folder t9 and saved to A1-raw-data-2/t9/12_seg.npy.
# Segmented 11 in folder t9 and saved to A1-raw-data-2/t9/11_seg.npy.
# Segmented 13 in folder t9 and saved to A1-raw-data-2/t9/13_seg.npy.
# Segmented 7 in folder t9 and saved to A1-raw-data-2/t9/7_seg.npy.
# Segmented 2 in folder t9 and saved to A1-raw-data-2/t9/2_seg.npy.

# %%
import os
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
from cellpose import io

# -------------------------------
# Configuration and Setup
# -------------------------------
base_input_folder = 'tifsmall'  # Base folder containing subfolders with images and segmentation files
output_folder_images = 'aoutput-images'       # For saving overlay images
output_folder_outlines = 'aoutput-outlines'    # For saving cell outlines

# Create output directories if they don't exist
os.makedirs(output_folder_images, exist_ok=True)
os.makedirs(output_folder_outlines, exist_ok=True)

# Recursively find all segmentation files (assumed to end with '_seg.npy')
segmentation_files = glob.glob(os.path.join(base_input_folder, '**', '*_seg.npy'), recursive=True)

# Define HSV thresholds and green pixel ratio threshold
lower_green = np.array([0, 150, 50])
upper_green = np.array([12, 255, 255])
green_pixel_ratio_threshold = 0.50  # 50% or more pixels must be green

# -------------------------------
# Process each file pair in the folder tree
# -------------------------------
for seg_file in segmentation_files:
    # Determine the base name (e.g., "image_seg.npy" -> "image")
    base_name = os.path.basename(seg_file).replace('_seg.npy', '')
    
    # The corresponding image is assumed to be in the same folder with a .tif extension
    img_file = os.path.join(os.path.dirname(seg_file), base_name + '.tif')
    
    # Check if the corresponding image file exists
    if not os.path.exists(img_file):
        print(f"Image file {img_file} not found for segmentation file {seg_file}. Skipping.")
        continue

    # Determine subfolder relative to the base_input_folder for output organization
    subfolder = os.path.relpath(os.path.dirname(seg_file), base_input_folder)
    out_img_folder = os.path.join(output_folder_images, subfolder)
    out_outline_folder = os.path.join(output_folder_outlines, subfolder)
    os.makedirs(out_img_folder, exist_ok=True)
    os.makedirs(out_outline_folder, exist_ok=True)
    
    print(f"Processing {base_name} in folder {subfolder}...")

    # -------------------------------
    # Part 1: Load data and build the mask dictionary
    # -------------------------------
    dat = np.load(seg_file, allow_pickle=True).item()
    img = io.imread(img_file)

    # Ensure the image is in RGB (if grayscale, convert it)
    if img.ndim == 2 or (img.ndim == 3 and img.shape[2] == 1):
        img = np.stack([img.squeeze()] * 3, axis=-1)

    masks = dat['masks']

    # Create a dictionary: key -> tuple of (y,x) coordinates for the mask pixels,
    # value -> average RGB value (for visualization if desired)
    mask_dict = {}
    labels = np.unique(masks)
    for label in labels:
        if label == 0:  # Skip background
            continue
        cell_mask = masks == label
        coords = np.argwhere(cell_mask)
        coords_tuple = tuple(map(tuple, coords))
        avg_rgb = np.mean(img[cell_mask], axis=0)
        mask_dict[coords_tuple] = avg_rgb

    # -------------------------------
    # Part 2: Filter cells using HSV thresholds
    # -------------------------------
    # Convert the image from RGB to HSV
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    # Create a binary mask for green regions
    hsv_green_mask = cv2.inRange(hsv, lower_green, upper_green)

    filtered_dict = {}
    for coords, avg_rgb in mask_dict.items():
        coords_array = np.array(coords)  # shape (N, 2)
        # Extract the green mask values for the cell's pixels
        green_vals = hsv_green_mask[coords_array[:, 0], coords_array[:, 1]]
        ratio_green = np.sum(green_vals == 255) / len(green_vals)
        #if ratio_green >= green_pixel_ratio_threshold:
        filtered_dict[coords] = avg_rgb

    # -------------------------------
    # Part 3: Create an overlay mask and save the overlay image
    # -------------------------------
    overlay_mask = np.zeros(masks.shape, dtype=bool)
    for coords in filtered_dict.keys():
        for (y, x) in coords:
            overlay_mask[y, x] = True

    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    masked_overlay = np.ma.masked_where(~overlay_mask, overlay_mask)
    plt.imshow(masked_overlay, cmap='Reds', alpha=0.5)
    plt.title(f'Cells with ≥ {int(green_pixel_ratio_threshold*100)}% Green Pixels')
    plt.axis('off')

    # Save the overlay image to the output folder (preserving subfolder structure)
    output_overlay_file = os.path.join(out_img_folder, base_name + '_overlay.png')
    plt.savefig(output_overlay_file, bbox_inches='tight')
    plt.close()

    # -------------------------------
    # Part 4: Extract cell outlines and write to file
    # -------------------------------
    outline_file = os.path.join(out_outline_folder, base_name + '_outlines.txt')
    with open(outline_file, "w") as f:
        for coords in filtered_dict.keys():
            # Create a binary image for this cell mask
            cell_mask_img = np.zeros(masks.shape, dtype=np.uint8)
            coords_np = np.array(coords)
            cell_mask_img[coords_np[:, 0], coords_np[:, 1]] = 255

            # Find contours; using RETR_EXTERNAL to get only the outer boundary
            contours, _ = cv2.findContours(cell_mask_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            if len(contours) == 0:
                continue

            # Choose the largest contour (in case there are multiple)
            largest_contour = max(contours, key=cv2.contourArea)
            largest_contour = largest_contour.squeeze()
            # Ensure the contour is 2D (in case it's only a single point)
            if largest_contour.ndim == 1:
                largest_contour = np.expand_dims(largest_contour, axis=0)

            # Format the contour as "x,y,x,y,..." (note: OpenCV contours are in (x,y) order)
            coord_pairs = [f"{pt[0]},{pt[1]}" for pt in largest_contour]
            outline_str = ",".join(coord_pairs)
            f.write(outline_str + "\n")

    print(f"Finished processing {base_name} in folder {subfolder}.")
    print(f" - Overlay saved to: {output_overlay_file}")
    print(f" - Outlines saved to: {outline_file}")
# Out:
# Processing 13 in folder ....
# Finished processing 13 in folder ..
#  - Overlay saved to: aoutput-images/./13_overlay.png
#  - Outlines saved to: aoutput-outlines/./13_outlines.txt
# Processing 16 in folder ....
# Finished processing 16 in folder ..
#  - Overlay saved to: aoutput-images/./16_overlay.png
#  - Outlines saved to: aoutput-outlines/./16_outlines.txt
# Processing 9 in folder ....
# Finished processing 9 in folder ..
#  - Overlay saved to: aoutput-images/./9_overlay.png
#  - Outlines saved to: aoutput-outlines/./9_outlines.txt
# Processing 12 in folder ....
# Finished processing 12 in folder ..
#  - Overlay saved to: aoutput-images/./12_overlay.png
#  - Outlines saved to: aoutput-outlines/./12_outlines.txt
# Processing 15 in folder ....
# Finished processing 15 in folder ..
#  - Overlay saved to: aoutput-images/./15_overlay.png
#  - Outlines saved to: aoutput-outlines/./15_outlines.txt
# Processing 5 in folder ....
# Finished processing 5 in folder ..
#  - Overlay saved to: aoutput-images/./5_overlay.png
#  - Outlines saved to: aoutput-outlines/./5_outlines.txt
# Processing 10 in folder ....
# Finished processing 10 in folder ..
#  - Overlay saved to: aoutput-images/./10_overlay.png
#  - Outlines saved to: aoutput-outlines/./10_outlines.txt
# Processing 4 in folder ....
# Finished processing 4 in folder ..
#  - Overlay saved to: aoutput-images/./4_overlay.png
#  - Outlines saved to: aoutput-outlines/./4_outlines.txt
# Processing 8 in folder ....
# Finished processing 8 in folder ..
#  - Overlay saved to: aoutput-images/./8_overlay.png
#  - Outlines saved to: aoutput-outlines/./8_outlines.txt
# Processing 6 in folder ....
# Finished processing 6 in folder ..
#  - Overlay saved to: aoutput-images/./6_overlay.png
#  - Outlines saved to: aoutput-outlines/./6_outlines.txt
# Processing 14 in folder ....
# Finished processing 14 in folder ..
#  - Overlay saved to: aoutput-images/./14_overlay.png
#  - Outlines saved to: aoutput-outlines/./14_outlines.txt
# Processing 3 in folder ....
# Finished processing 3 in folder ..
#  - Overlay saved to: aoutput-images/./3_overlay.png
#  - Outlines saved to: aoutput-outlines/./3_outlines.txt
# Processing 7 in folder ....
# Finished processing 7 in folder ..
#  - Overlay saved to: aoutput-images/./7_overlay.png
#  - Outlines saved to: aoutput-outlines/./7_outlines.txt
# Processing 11 in folder ....
# Finished processing 11 in folder ..
#  - Overlay saved to: aoutput-images/./11_overlay.png
#  - Outlines saved to: aoutput-outlines/./11_outlines.txt

# %%
import os
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
from cellpose import io

# -------------------------------
# Configuration and Setup
# -------------------------------
base_input_folder = 'A1-raw-data-2'  # Base folder containing subfolders with images and segmentation files
output_folder_images = 'output-images-5'       # For saving overlay images
output_folder_outlines = 'output-outlines-5'    # For saving cell outlines

# Create output directories if they don't exist
os.makedirs(output_folder_images, exist_ok=True)
os.makedirs(output_folder_outlines, exist_ok=True)

# Recursively find all segmentation files (assumed to end with '_seg.npy')
segmentation_files = glob.glob(os.path.join(base_input_folder, '**', '*_seg.npy'), recursive=True)

# Define HSV thresholds and green pixel ratio threshold
lower_green = np.array([40, 45, 45])
upper_green = np.array([80, 255, 255])
green_pixel_ratio_threshold = 0.50  # 50% or more pixels must be green

# -------------------------------
# Process each file pair in the folder tree
# -------------------------------
for seg_file in segmentation_files:
    # Determine the base name (e.g., "image_seg.npy" -> "image")
    base_name = os.path.basename(seg_file).replace('_seg.npy', '')
    
    # The corresponding image is assumed to be in the same folder with a .tif extension
    img_file = os.path.join(os.path.dirname(seg_file), base_name + '.tif')
    
    # Check if the corresponding image file exists
    if not os.path.exists(img_file):
        print(f"Image file {img_file} not found for segmentation file {seg_file}. Skipping.")
        continue

    # Determine subfolder relative to the base_input_folder for output organization
    subfolder = os.path.relpath(os.path.dirname(seg_file), base_input_folder)
    out_img_folder = os.path.join(output_folder_images, subfolder)
    out_outline_folder = os.path.join(output_folder_outlines, subfolder)
    os.makedirs(out_img_folder, exist_ok=True)
    os.makedirs(out_outline_folder, exist_ok=True)
    
    print(f"Processing {base_name} in folder {subfolder}...")

    # -------------------------------
    # Part 1: Load data and build the mask dictionary
    # -------------------------------
    dat = np.load(seg_file, allow_pickle=True).item()
    img = io.imread(img_file)

    # Ensure the image is in RGB (if grayscale, convert it)
    if img.ndim == 2 or (img.ndim == 3 and img.shape[2] == 1):
        img = np.stack([img.squeeze()] * 3, axis=-1)

    masks = dat['masks']

    # Create a dictionary: key -> tuple of (y,x) coordinates for the mask pixels,
    # value -> average RGB value (for visualization if desired)
    mask_dict = {}
    labels = np.unique(masks)
    for label in labels:
        if label == 0:  # Skip background
            continue
        cell_mask = masks == label
        coords = np.argwhere(cell_mask)
        coords_tuple = tuple(map(tuple, coords))
        avg_rgb = np.mean(img[cell_mask], axis=0)
        mask_dict[coords_tuple] = avg_rgb

    # -------------------------------
    # Part 2: Filter cells using HSV thresholds
    # -------------------------------
    # Convert the image from RGB to HSV
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    # Create a binary mask for green regions
    hsv_green_mask = cv2.inRange(hsv, lower_green, upper_green)

    filtered_dict = {}
    for coords, avg_rgb in mask_dict.items():
        coords_array = np.array(coords)  # shape (N, 2)
        # Extract the green mask values for the cell's pixels
        green_vals = hsv_green_mask[coords_array[:, 0], coords_array[:, 1]]
        ratio_green = np.sum(green_vals == 255) / len(green_vals)
        if ratio_green >= green_pixel_ratio_threshold:
            filtered_dict[coords] = avg_rgb

    # -------------------------------
    # Part 3: Create a black background with just the green cells and save the image
    # -------------------------------
    # Create a black background image (all zeros)
    green_cells_image = np.zeros(img.shape, dtype=np.uint8)
    
    # Set the green cells to green color (0, 255, 0) on the black background
    for coords in filtered_dict.keys():
        coords_array = np.array(coords)
        # Use a pure green color for all cells
        green_cells_image[coords_array[:, 0], coords_array[:, 1]] = [0, 255, 0]  # RGB for green

    # Save the green cells image to the output folder (preserving subfolder structure)
    output_green_cells_file = os.path.join(out_img_folder, base_name + '_green_cells.png')
    
    # Setup the figure with tight layout and no edge padding
    plt.figure(figsize=(10, 10))
    plt.subplots_adjust(left=0, right=1, top=1, bottom=0)  # Remove internal padding
    plt.imshow(green_cells_image)
    plt.axis('off')  # Turn off axis
    
    # Save with tight bounding box, no padding, and black background
    plt.savefig(output_green_cells_file, 
                bbox_inches='tight',  # Remove any extra whitespace
                pad_inches=0,         # Remove all padding
                facecolor='black',    # Make figure background black
                dpi=300)              # Higher DPI for better quality
    plt.close()

    # -------------------------------
    # Part 4: Extract cell outlines and write to file
    # -------------------------------
    outline_file = os.path.join(out_outline_folder, base_name + '_outlines.txt')
    with open(outline_file, "w") as f:
        for coords in filtered_dict.keys():
            # Create a binary image for this cell mask
            cell_mask_img = np.zeros(masks.shape, dtype=np.uint8)
            coords_np = np.array(coords)
            cell_mask_img[coords_np[:, 0], coords_np[:, 1]] = 255

            # Find contours; using RETR_EXTERNAL to get only the outer boundary
            contours, _ = cv2.findContours(cell_mask_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            if len(contours) == 0:
                continue

            # Choose the largest contour (in case there are multiple)
            largest_contour = max(contours, key=cv2.contourArea)
            largest_contour = largest_contour.squeeze()
            # Ensure the contour is 2D (in case it's only a single point)
            if largest_contour.ndim == 1:
                largest_contour = np.expand_dims(largest_contour, axis=0)

            # Format the contour as "x,y,x,y,..." (note: OpenCV contours are in (x,y) order)
            coord_pairs = [f"{pt[0]},{pt[1]}" for pt in largest_contour]
            outline_str = ",".join(coord_pairs)
            f.write(outline_str + "\n")

    print(f"Finished processing {base_name} in folder {subfolder}.")
    print(f" - Green cells image saved to: {output_green_cells_file}")
    print(f" - Outlines saved to: {outline_file}")
# Out:
# Processing 13 in folder t16...
# Finished processing 13 in folder t16.
#  - Green cells image saved to: output-images-5/t16/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/13_outlines.txt
# Processing 9 in folder t16...
# Finished processing 9 in folder t16.
#  - Green cells image saved to: output-images-5/t16/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/9_outlines.txt
# Processing 1 in folder t16...
# Finished processing 1 in folder t16.
#  - Green cells image saved to: output-images-5/t16/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/1_outlines.txt
# Processing 12 in folder t16...
# Finished processing 12 in folder t16.
#  - Green cells image saved to: output-images-5/t16/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/12_outlines.txt
# Processing 15 in folder t16...
# Finished processing 15 in folder t16.
#  - Green cells image saved to: output-images-5/t16/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/15_outlines.txt
# Processing 5 in folder t16...
# Finished processing 5 in folder t16.
#  - Green cells image saved to: output-images-5/t16/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/5_outlines.txt
# Processing 10 in folder t16...
# Finished processing 10 in folder t16.
#  - Green cells image saved to: output-images-5/t16/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/10_outlines.txt
# Processing 2 in folder t16...
# Finished processing 2 in folder t16.
#  - Green cells image saved to: output-images-5/t16/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/2_outlines.txt
# Processing 4 in folder t16...
# Finished processing 4 in folder t16.
#  - Green cells image saved to: output-images-5/t16/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/4_outlines.txt
# Processing 8 in folder t16...
# Finished processing 8 in folder t16.
#  - Green cells image saved to: output-images-5/t16/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/8_outlines.txt
# Processing 6 in folder t16...
# Finished processing 6 in folder t16.
#  - Green cells image saved to: output-images-5/t16/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/6_outlines.txt
# Processing 14 in folder t16...
# Finished processing 14 in folder t16.
#  - Green cells image saved to: output-images-5/t16/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/14_outlines.txt
# Processing 3 in folder t16...
# Finished processing 3 in folder t16.
#  - Green cells image saved to: output-images-5/t16/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/3_outlines.txt
# Processing 7 in folder t16...
# Finished processing 7 in folder t16.
#  - Green cells image saved to: output-images-5/t16/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/7_outlines.txt
# Processing 11 in folder t16...
# Finished processing 11 in folder t16.
#  - Green cells image saved to: output-images-5/t16/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t16/11_outlines.txt
# Processing 13 in folder t34...
# Finished processing 13 in folder t34.
#  - Green cells image saved to: output-images-5/t34/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/13_outlines.txt
# Processing 9 in folder t34...
# Finished processing 9 in folder t34.
#  - Green cells image saved to: output-images-5/t34/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/9_outlines.txt
# Processing 1 in folder t34...
# Finished processing 1 in folder t34.
#  - Green cells image saved to: output-images-5/t34/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/1_outlines.txt
# Processing 12 in folder t34...
# Finished processing 12 in folder t34.
#  - Green cells image saved to: output-images-5/t34/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/12_outlines.txt
# Processing 15 in folder t34...
# Finished processing 15 in folder t34.
#  - Green cells image saved to: output-images-5/t34/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/15_outlines.txt
# Processing 5 in folder t34...
# Finished processing 5 in folder t34.
#  - Green cells image saved to: output-images-5/t34/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/5_outlines.txt
# Processing 10 in folder t34...
# Finished processing 10 in folder t34.
#  - Green cells image saved to: output-images-5/t34/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/10_outlines.txt
# Processing 2 in folder t34...
# Finished processing 2 in folder t34.
#  - Green cells image saved to: output-images-5/t34/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/2_outlines.txt
# Processing 4 in folder t34...
# Finished processing 4 in folder t34.
#  - Green cells image saved to: output-images-5/t34/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/4_outlines.txt
# Processing 8 in folder t34...
# Finished processing 8 in folder t34.
#  - Green cells image saved to: output-images-5/t34/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/8_outlines.txt
# Processing 6 in folder t34...
# Finished processing 6 in folder t34.
#  - Green cells image saved to: output-images-5/t34/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/6_outlines.txt
# Processing 14 in folder t34...
# Finished processing 14 in folder t34.
#  - Green cells image saved to: output-images-5/t34/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/14_outlines.txt
# Processing 3 in folder t34...
# Finished processing 3 in folder t34.
#  - Green cells image saved to: output-images-5/t34/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/3_outlines.txt
# Processing 7 in folder t34...
# Finished processing 7 in folder t34.
#  - Green cells image saved to: output-images-5/t34/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/7_outlines.txt
# Processing 11 in folder t34...
# Finished processing 11 in folder t34.
#  - Green cells image saved to: output-images-5/t34/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t34/11_outlines.txt
# Processing 13 in folder t22...
# Finished processing 13 in folder t22.
#  - Green cells image saved to: output-images-5/t22/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/13_outlines.txt
# Processing 9 in folder t22...
# Finished processing 9 in folder t22.
#  - Green cells image saved to: output-images-5/t22/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/9_outlines.txt
# Processing 1 in folder t22...
# Finished processing 1 in folder t22.
#  - Green cells image saved to: output-images-5/t22/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/1_outlines.txt
# Processing 12 in folder t22...
# Finished processing 12 in folder t22.
#  - Green cells image saved to: output-images-5/t22/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/12_outlines.txt
# Processing 15 in folder t22...
# Finished processing 15 in folder t22.
#  - Green cells image saved to: output-images-5/t22/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/15_outlines.txt
# Processing 5 in folder t22...
# Finished processing 5 in folder t22.
#  - Green cells image saved to: output-images-5/t22/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/5_outlines.txt
# Processing 10 in folder t22...
# Finished processing 10 in folder t22.
#  - Green cells image saved to: output-images-5/t22/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/10_outlines.txt
# Processing 2 in folder t22...
# Finished processing 2 in folder t22.
#  - Green cells image saved to: output-images-5/t22/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/2_outlines.txt
# Processing 4 in folder t22...
# Finished processing 4 in folder t22.
#  - Green cells image saved to: output-images-5/t22/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/4_outlines.txt
# Processing 8 in folder t22...
# Finished processing 8 in folder t22.
#  - Green cells image saved to: output-images-5/t22/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/8_outlines.txt
# Processing 6 in folder t22...
# Finished processing 6 in folder t22.
#  - Green cells image saved to: output-images-5/t22/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/6_outlines.txt
# Processing 14 in folder t22...
# Finished processing 14 in folder t22.
#  - Green cells image saved to: output-images-5/t22/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/14_outlines.txt
# Processing 3 in folder t22...
# Finished processing 3 in folder t22.
#  - Green cells image saved to: output-images-5/t22/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/3_outlines.txt
# Processing 7 in folder t22...
# Finished processing 7 in folder t22.
#  - Green cells image saved to: output-images-5/t22/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/7_outlines.txt
# Processing 11 in folder t22...
# Finished processing 11 in folder t22.
#  - Green cells image saved to: output-images-5/t22/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t22/11_outlines.txt
# Processing 13 in folder t20...
# Finished processing 13 in folder t20.
#  - Green cells image saved to: output-images-5/t20/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/13_outlines.txt
# Processing 9 in folder t20...
# Finished processing 9 in folder t20.
#  - Green cells image saved to: output-images-5/t20/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/9_outlines.txt
# Processing 1 in folder t20...
# Finished processing 1 in folder t20.
#  - Green cells image saved to: output-images-5/t20/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/1_outlines.txt
# Processing 12 in folder t20...
# Finished processing 12 in folder t20.
#  - Green cells image saved to: output-images-5/t20/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/12_outlines.txt
# Processing 15 in folder t20...
# Finished processing 15 in folder t20.
#  - Green cells image saved to: output-images-5/t20/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/15_outlines.txt
# Processing 5 in folder t20...
# Finished processing 5 in folder t20.
#  - Green cells image saved to: output-images-5/t20/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/5_outlines.txt
# Processing 10 in folder t20...
# Finished processing 10 in folder t20.
#  - Green cells image saved to: output-images-5/t20/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/10_outlines.txt
# Processing 2 in folder t20...
# Finished processing 2 in folder t20.
#  - Green cells image saved to: output-images-5/t20/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/2_outlines.txt
# Processing 4 in folder t20...
# Finished processing 4 in folder t20.
#  - Green cells image saved to: output-images-5/t20/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/4_outlines.txt
# Processing 8 in folder t20...
# Finished processing 8 in folder t20.
#  - Green cells image saved to: output-images-5/t20/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/8_outlines.txt
# Processing 6 in folder t20...
# Finished processing 6 in folder t20.
#  - Green cells image saved to: output-images-5/t20/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/6_outlines.txt
# Processing 14 in folder t20...
# Finished processing 14 in folder t20.
#  - Green cells image saved to: output-images-5/t20/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/14_outlines.txt
# Processing 3 in folder t20...
# Finished processing 3 in folder t20.
#  - Green cells image saved to: output-images-5/t20/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/3_outlines.txt
# Processing 7 in folder t20...
# Finished processing 7 in folder t20.
#  - Green cells image saved to: output-images-5/t20/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/7_outlines.txt
# Processing 11 in folder t20...
# Finished processing 11 in folder t20.
#  - Green cells image saved to: output-images-5/t20/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t20/11_outlines.txt
# Processing 13 in folder t43...
# Finished processing 13 in folder t43.
#  - Green cells image saved to: output-images-5/t43/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/13_outlines.txt
# Processing 9 in folder t43...
# Finished processing 9 in folder t43.
#  - Green cells image saved to: output-images-5/t43/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/9_outlines.txt
# Processing 1 in folder t43...
# Finished processing 1 in folder t43.
#  - Green cells image saved to: output-images-5/t43/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/1_outlines.txt
# Processing 12 in folder t43...
# Finished processing 12 in folder t43.
#  - Green cells image saved to: output-images-5/t43/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/12_outlines.txt
# Processing 15 in folder t43...
# Finished processing 15 in folder t43.
#  - Green cells image saved to: output-images-5/t43/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/15_outlines.txt
# Processing 5 in folder t43...
# Finished processing 5 in folder t43.
#  - Green cells image saved to: output-images-5/t43/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/5_outlines.txt
# Processing 10 in folder t43...
# Finished processing 10 in folder t43.
#  - Green cells image saved to: output-images-5/t43/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/10_outlines.txt
# Processing 2 in folder t43...
# Finished processing 2 in folder t43.
#  - Green cells image saved to: output-images-5/t43/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/2_outlines.txt
# Processing 4 in folder t43...
# Finished processing 4 in folder t43.
#  - Green cells image saved to: output-images-5/t43/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/4_outlines.txt
# Processing 8 in folder t43...
# Finished processing 8 in folder t43.
#  - Green cells image saved to: output-images-5/t43/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/8_outlines.txt
# Processing 6 in folder t43...
# Finished processing 6 in folder t43.
#  - Green cells image saved to: output-images-5/t43/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/6_outlines.txt
# Processing 14 in folder t43...
# Finished processing 14 in folder t43.
#  - Green cells image saved to: output-images-5/t43/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/14_outlines.txt
# Processing 3 in folder t43...
# Finished processing 3 in folder t43.
#  - Green cells image saved to: output-images-5/t43/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/3_outlines.txt
# Processing 7 in folder t43...
# Finished processing 7 in folder t43.
#  - Green cells image saved to: output-images-5/t43/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/7_outlines.txt
# Processing 11 in folder t43...
# Finished processing 11 in folder t43.
#  - Green cells image saved to: output-images-5/t43/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t43/11_outlines.txt
# Processing 13 in folder t33...
# Finished processing 13 in folder t33.
#  - Green cells image saved to: output-images-5/t33/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/13_outlines.txt
# Processing 9 in folder t33...
# Finished processing 9 in folder t33.
#  - Green cells image saved to: output-images-5/t33/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/9_outlines.txt
# Processing 1 in folder t33...
# Finished processing 1 in folder t33.
#  - Green cells image saved to: output-images-5/t33/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/1_outlines.txt
# Processing 12 in folder t33...
# Finished processing 12 in folder t33.
#  - Green cells image saved to: output-images-5/t33/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/12_outlines.txt
# Processing 15 in folder t33...
# Finished processing 15 in folder t33.
#  - Green cells image saved to: output-images-5/t33/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/15_outlines.txt
# Processing 5 in folder t33...
# Finished processing 5 in folder t33.
#  - Green cells image saved to: output-images-5/t33/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/5_outlines.txt
# Processing 10 in folder t33...
# Finished processing 10 in folder t33.
#  - Green cells image saved to: output-images-5/t33/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/10_outlines.txt
# Processing 2 in folder t33...
# Finished processing 2 in folder t33.
#  - Green cells image saved to: output-images-5/t33/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/2_outlines.txt
# Processing 4 in folder t33...
# Finished processing 4 in folder t33.
#  - Green cells image saved to: output-images-5/t33/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/4_outlines.txt
# Processing 8 in folder t33...
# Finished processing 8 in folder t33.
#  - Green cells image saved to: output-images-5/t33/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/8_outlines.txt
# Processing 6 in folder t33...
# Finished processing 6 in folder t33.
#  - Green cells image saved to: output-images-5/t33/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/6_outlines.txt
# Processing 14 in folder t33...
# Finished processing 14 in folder t33.
#  - Green cells image saved to: output-images-5/t33/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/14_outlines.txt
# Processing 3 in folder t33...
# Finished processing 3 in folder t33.
#  - Green cells image saved to: output-images-5/t33/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/3_outlines.txt
# Processing 7 in folder t33...
# Finished processing 7 in folder t33.
#  - Green cells image saved to: output-images-5/t33/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/7_outlines.txt
# Processing 11 in folder t33...
# Finished processing 11 in folder t33.
#  - Green cells image saved to: output-images-5/t33/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t33/11_outlines.txt
# Processing 13 in folder t42...
# Finished processing 13 in folder t42.
#  - Green cells image saved to: output-images-5/t42/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/13_outlines.txt
# Processing 9 in folder t42...
# Finished processing 9 in folder t42.
#  - Green cells image saved to: output-images-5/t42/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/9_outlines.txt
# Processing 1 in folder t42...
# Finished processing 1 in folder t42.
#  - Green cells image saved to: output-images-5/t42/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/1_outlines.txt
# Processing 12 in folder t42...
# Finished processing 12 in folder t42.
#  - Green cells image saved to: output-images-5/t42/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/12_outlines.txt
# Processing 15 in folder t42...
# Finished processing 15 in folder t42.
#  - Green cells image saved to: output-images-5/t42/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/15_outlines.txt
# Processing 5 in folder t42...
# Finished processing 5 in folder t42.
#  - Green cells image saved to: output-images-5/t42/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/5_outlines.txt
# Processing 10 in folder t42...
# Finished processing 10 in folder t42.
#  - Green cells image saved to: output-images-5/t42/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/10_outlines.txt
# Processing 2 in folder t42...
# Finished processing 2 in folder t42.
#  - Green cells image saved to: output-images-5/t42/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/2_outlines.txt
# Processing 4 in folder t42...
# Finished processing 4 in folder t42.
#  - Green cells image saved to: output-images-5/t42/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/4_outlines.txt
# Processing 8 in folder t42...
# Finished processing 8 in folder t42.
#  - Green cells image saved to: output-images-5/t42/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/8_outlines.txt
# Processing 6 in folder t42...
# Finished processing 6 in folder t42.
#  - Green cells image saved to: output-images-5/t42/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/6_outlines.txt
# Processing 14 in folder t42...
# Finished processing 14 in folder t42.
#  - Green cells image saved to: output-images-5/t42/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/14_outlines.txt
# Processing 3 in folder t42...
# Finished processing 3 in folder t42.
#  - Green cells image saved to: output-images-5/t42/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/3_outlines.txt
# Processing 7 in folder t42...
# Finished processing 7 in folder t42.
#  - Green cells image saved to: output-images-5/t42/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/7_outlines.txt
# Processing 11 in folder t42...
# Finished processing 11 in folder t42.
#  - Green cells image saved to: output-images-5/t42/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t42/11_outlines.txt
# Processing 13 in folder t27...
# Finished processing 13 in folder t27.
#  - Green cells image saved to: output-images-5/t27/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/13_outlines.txt
# Processing 9 in folder t27...
# Finished processing 9 in folder t27.
#  - Green cells image saved to: output-images-5/t27/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/9_outlines.txt
# Processing 1 in folder t27...
# Finished processing 1 in folder t27.
#  - Green cells image saved to: output-images-5/t27/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/1_outlines.txt
# Processing 12 in folder t27...
# Finished processing 12 in folder t27.
#  - Green cells image saved to: output-images-5/t27/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/12_outlines.txt
# Processing 15 in folder t27...
# Finished processing 15 in folder t27.
#  - Green cells image saved to: output-images-5/t27/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/15_outlines.txt
# Processing 5 in folder t27...
# Finished processing 5 in folder t27.
#  - Green cells image saved to: output-images-5/t27/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/5_outlines.txt
# Processing 10 in folder t27...
# Finished processing 10 in folder t27.
#  - Green cells image saved to: output-images-5/t27/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/10_outlines.txt
# Processing 2 in folder t27...
# Finished processing 2 in folder t27.
#  - Green cells image saved to: output-images-5/t27/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/2_outlines.txt
# Processing 4 in folder t27...
# Finished processing 4 in folder t27.
#  - Green cells image saved to: output-images-5/t27/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/4_outlines.txt
# Processing 8 in folder t27...
# Finished processing 8 in folder t27.
#  - Green cells image saved to: output-images-5/t27/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/8_outlines.txt
# Processing 6 in folder t27...
# Finished processing 6 in folder t27.
#  - Green cells image saved to: output-images-5/t27/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/6_outlines.txt
# Processing 14 in folder t27...
# Finished processing 14 in folder t27.
#  - Green cells image saved to: output-images-5/t27/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/14_outlines.txt
# Processing 3 in folder t27...
# Finished processing 3 in folder t27.
#  - Green cells image saved to: output-images-5/t27/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/3_outlines.txt
# Processing 7 in folder t27...
# Finished processing 7 in folder t27.
#  - Green cells image saved to: output-images-5/t27/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/7_outlines.txt
# Processing 11 in folder t27...
# Finished processing 11 in folder t27.
#  - Green cells image saved to: output-images-5/t27/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t27/11_outlines.txt
# Processing 13 in folder t13...
# Finished processing 13 in folder t13.
#  - Green cells image saved to: output-images-5/t13/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/13_outlines.txt
# Processing 9 in folder t13...
# Finished processing 9 in folder t13.
#  - Green cells image saved to: output-images-5/t13/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/9_outlines.txt
# Processing 1 in folder t13...
# Finished processing 1 in folder t13.
#  - Green cells image saved to: output-images-5/t13/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/1_outlines.txt
# Processing 12 in folder t13...
# Finished processing 12 in folder t13.
#  - Green cells image saved to: output-images-5/t13/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/12_outlines.txt
# Processing 15 in folder t13...
# Finished processing 15 in folder t13.
#  - Green cells image saved to: output-images-5/t13/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/15_outlines.txt
# Processing 5 in folder t13...
# Finished processing 5 in folder t13.
#  - Green cells image saved to: output-images-5/t13/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/5_outlines.txt
# Processing 10 in folder t13...
# Finished processing 10 in folder t13.
#  - Green cells image saved to: output-images-5/t13/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/10_outlines.txt
# Processing 2 in folder t13...
# Finished processing 2 in folder t13.
#  - Green cells image saved to: output-images-5/t13/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/2_outlines.txt
# Processing 4 in folder t13...
# Finished processing 4 in folder t13.
#  - Green cells image saved to: output-images-5/t13/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/4_outlines.txt
# Processing 8 in folder t13...
# Finished processing 8 in folder t13.
#  - Green cells image saved to: output-images-5/t13/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/8_outlines.txt
# Processing 6 in folder t13...
# Finished processing 6 in folder t13.
#  - Green cells image saved to: output-images-5/t13/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/6_outlines.txt
# Processing 14 in folder t13...
# Finished processing 14 in folder t13.
#  - Green cells image saved to: output-images-5/t13/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/14_outlines.txt
# Processing 3 in folder t13...
# Finished processing 3 in folder t13.
#  - Green cells image saved to: output-images-5/t13/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/3_outlines.txt
# Processing 7 in folder t13...
# Finished processing 7 in folder t13.
#  - Green cells image saved to: output-images-5/t13/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/7_outlines.txt
# Processing 11 in folder t13...
# Finished processing 11 in folder t13.
#  - Green cells image saved to: output-images-5/t13/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t13/11_outlines.txt
# Processing 13 in folder t25...
# Finished processing 13 in folder t25.
#  - Green cells image saved to: output-images-5/t25/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/13_outlines.txt
# Processing 9 in folder t25...
# Finished processing 9 in folder t25.
#  - Green cells image saved to: output-images-5/t25/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/9_outlines.txt
# Processing 1 in folder t25...
# Finished processing 1 in folder t25.
#  - Green cells image saved to: output-images-5/t25/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/1_outlines.txt
# Processing 12 in folder t25...
# Finished processing 12 in folder t25.
#  - Green cells image saved to: output-images-5/t25/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/12_outlines.txt
# Processing 15 in folder t25...
# Finished processing 15 in folder t25.
#  - Green cells image saved to: output-images-5/t25/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/15_outlines.txt
# Processing 5 in folder t25...
# Finished processing 5 in folder t25.
#  - Green cells image saved to: output-images-5/t25/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/5_outlines.txt
# Processing 10 in folder t25...
# Finished processing 10 in folder t25.
#  - Green cells image saved to: output-images-5/t25/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/10_outlines.txt
# Processing 2 in folder t25...
# Finished processing 2 in folder t25.
#  - Green cells image saved to: output-images-5/t25/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/2_outlines.txt
# Processing 4 in folder t25...
# Finished processing 4 in folder t25.
#  - Green cells image saved to: output-images-5/t25/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/4_outlines.txt
# Processing 8 in folder t25...
# Finished processing 8 in folder t25.
#  - Green cells image saved to: output-images-5/t25/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/8_outlines.txt
# Processing 6 in folder t25...
# Finished processing 6 in folder t25.
#  - Green cells image saved to: output-images-5/t25/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/6_outlines.txt
# Processing 14 in folder t25...
# Finished processing 14 in folder t25.
#  - Green cells image saved to: output-images-5/t25/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/14_outlines.txt
# Processing 3 in folder t25...
# Finished processing 3 in folder t25.
#  - Green cells image saved to: output-images-5/t25/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/3_outlines.txt
# Processing 7 in folder t25...
# Finished processing 7 in folder t25.
#  - Green cells image saved to: output-images-5/t25/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/7_outlines.txt
# Processing 11 in folder t25...
# Finished processing 11 in folder t25.
#  - Green cells image saved to: output-images-5/t25/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t25/11_outlines.txt
# Processing 13 in folder t29...
# Finished processing 13 in folder t29.
#  - Green cells image saved to: output-images-5/t29/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/13_outlines.txt
# Processing 9 in folder t29...
# Finished processing 9 in folder t29.
#  - Green cells image saved to: output-images-5/t29/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/9_outlines.txt
# Processing 1 in folder t29...
# Finished processing 1 in folder t29.
#  - Green cells image saved to: output-images-5/t29/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/1_outlines.txt
# Processing 12 in folder t29...
# Finished processing 12 in folder t29.
#  - Green cells image saved to: output-images-5/t29/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/12_outlines.txt
# Processing 15 in folder t29...
# Finished processing 15 in folder t29.
#  - Green cells image saved to: output-images-5/t29/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/15_outlines.txt
# Processing 5 in folder t29...
# Finished processing 5 in folder t29.
#  - Green cells image saved to: output-images-5/t29/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/5_outlines.txt
# Processing 10 in folder t29...
# Finished processing 10 in folder t29.
#  - Green cells image saved to: output-images-5/t29/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/10_outlines.txt
# Processing 2 in folder t29...
# Finished processing 2 in folder t29.
#  - Green cells image saved to: output-images-5/t29/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/2_outlines.txt
# Processing 4 in folder t29...
# Finished processing 4 in folder t29.
#  - Green cells image saved to: output-images-5/t29/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/4_outlines.txt
# Processing 8 in folder t29...
# Finished processing 8 in folder t29.
#  - Green cells image saved to: output-images-5/t29/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/8_outlines.txt
# Processing 6 in folder t29...
# Finished processing 6 in folder t29.
#  - Green cells image saved to: output-images-5/t29/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/6_outlines.txt
# Processing 14 in folder t29...
# Finished processing 14 in folder t29.
#  - Green cells image saved to: output-images-5/t29/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/14_outlines.txt
# Processing 3 in folder t29...
# Finished processing 3 in folder t29.
#  - Green cells image saved to: output-images-5/t29/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/3_outlines.txt
# Processing 7 in folder t29...
# Finished processing 7 in folder t29.
#  - Green cells image saved to: output-images-5/t29/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/7_outlines.txt
# Processing 11 in folder t29...
# Finished processing 11 in folder t29.
#  - Green cells image saved to: output-images-5/t29/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t29/11_outlines.txt
# Processing 13 in folder t17...
# Finished processing 13 in folder t17.
#  - Green cells image saved to: output-images-5/t17/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/13_outlines.txt
# Processing 9 in folder t17...
# Finished processing 9 in folder t17.
#  - Green cells image saved to: output-images-5/t17/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/9_outlines.txt
# Processing 1 in folder t17...
# Finished processing 1 in folder t17.
#  - Green cells image saved to: output-images-5/t17/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/1_outlines.txt
# Processing 12 in folder t17...
# Finished processing 12 in folder t17.
#  - Green cells image saved to: output-images-5/t17/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/12_outlines.txt
# Processing 15 in folder t17...
# Finished processing 15 in folder t17.
#  - Green cells image saved to: output-images-5/t17/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/15_outlines.txt
# Processing 5 in folder t17...
# Finished processing 5 in folder t17.
#  - Green cells image saved to: output-images-5/t17/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/5_outlines.txt
# Processing 10 in folder t17...
# Finished processing 10 in folder t17.
#  - Green cells image saved to: output-images-5/t17/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/10_outlines.txt
# Processing 2 in folder t17...
# Finished processing 2 in folder t17.
#  - Green cells image saved to: output-images-5/t17/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/2_outlines.txt
# Processing 4 in folder t17...
# Finished processing 4 in folder t17.
#  - Green cells image saved to: output-images-5/t17/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/4_outlines.txt
# Processing 8 in folder t17...
# Finished processing 8 in folder t17.
#  - Green cells image saved to: output-images-5/t17/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/8_outlines.txt
# Processing 6 in folder t17...
# Finished processing 6 in folder t17.
#  - Green cells image saved to: output-images-5/t17/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/6_outlines.txt
# Processing 14 in folder t17...
# Finished processing 14 in folder t17.
#  - Green cells image saved to: output-images-5/t17/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/14_outlines.txt
# Processing 3 in folder t17...
# Finished processing 3 in folder t17.
#  - Green cells image saved to: output-images-5/t17/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/3_outlines.txt
# Processing 7 in folder t17...
# Finished processing 7 in folder t17.
#  - Green cells image saved to: output-images-5/t17/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/7_outlines.txt
# Processing 11 in folder t17...
# Finished processing 11 in folder t17.
#  - Green cells image saved to: output-images-5/t17/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t17/11_outlines.txt
# Processing 13 in folder t3...
# Finished processing 13 in folder t3.
#  - Green cells image saved to: output-images-5/t3/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/13_outlines.txt
# Processing 9 in folder t3...
# Finished processing 9 in folder t3.
#  - Green cells image saved to: output-images-5/t3/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/9_outlines.txt
# Processing 1 in folder t3...
# Finished processing 1 in folder t3.
#  - Green cells image saved to: output-images-5/t3/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/1_outlines.txt
# Processing 12 in folder t3...
# Finished processing 12 in folder t3.
#  - Green cells image saved to: output-images-5/t3/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/12_outlines.txt
# Processing 15 in folder t3...
# Finished processing 15 in folder t3.
#  - Green cells image saved to: output-images-5/t3/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/15_outlines.txt
# Processing 5 in folder t3...
# Finished processing 5 in folder t3.
#  - Green cells image saved to: output-images-5/t3/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/5_outlines.txt
# Processing 10 in folder t3...
# Finished processing 10 in folder t3.
#  - Green cells image saved to: output-images-5/t3/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/10_outlines.txt
# Processing 2 in folder t3...
# Finished processing 2 in folder t3.
#  - Green cells image saved to: output-images-5/t3/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/2_outlines.txt
# Processing 4 in folder t3...
# Finished processing 4 in folder t3.
#  - Green cells image saved to: output-images-5/t3/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/4_outlines.txt
# Processing 8 in folder t3...
# Finished processing 8 in folder t3.
#  - Green cells image saved to: output-images-5/t3/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/8_outlines.txt
# Processing 6 in folder t3...
# Finished processing 6 in folder t3.
#  - Green cells image saved to: output-images-5/t3/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/6_outlines.txt
# Processing 14 in folder t3...
# Finished processing 14 in folder t3.
#  - Green cells image saved to: output-images-5/t3/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/14_outlines.txt
# Processing 3 in folder t3...
# Finished processing 3 in folder t3.
#  - Green cells image saved to: output-images-5/t3/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/3_outlines.txt
# Processing 7 in folder t3...
# Finished processing 7 in folder t3.
#  - Green cells image saved to: output-images-5/t3/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/7_outlines.txt
# Processing 11 in folder t3...
# Finished processing 11 in folder t3.
#  - Green cells image saved to: output-images-5/t3/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t3/11_outlines.txt
# Processing 13 in folder t32...
# Finished processing 13 in folder t32.
#  - Green cells image saved to: output-images-5/t32/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/13_outlines.txt
# Processing 9 in folder t32...
# Finished processing 9 in folder t32.
#  - Green cells image saved to: output-images-5/t32/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/9_outlines.txt
# Processing 1 in folder t32...
# Finished processing 1 in folder t32.
#  - Green cells image saved to: output-images-5/t32/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/1_outlines.txt
# Processing 12 in folder t32...
# Finished processing 12 in folder t32.
#  - Green cells image saved to: output-images-5/t32/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/12_outlines.txt
# Processing 15 in folder t32...
# Finished processing 15 in folder t32.
#  - Green cells image saved to: output-images-5/t32/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/15_outlines.txt
# Processing 5 in folder t32...
# Finished processing 5 in folder t32.
#  - Green cells image saved to: output-images-5/t32/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/5_outlines.txt
# Processing 10 in folder t32...
# Finished processing 10 in folder t32.
#  - Green cells image saved to: output-images-5/t32/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/10_outlines.txt
# Processing 2 in folder t32...
# Finished processing 2 in folder t32.
#  - Green cells image saved to: output-images-5/t32/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/2_outlines.txt
# Processing 4 in folder t32...
# Finished processing 4 in folder t32.
#  - Green cells image saved to: output-images-5/t32/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/4_outlines.txt
# Processing 8 in folder t32...
# Finished processing 8 in folder t32.
#  - Green cells image saved to: output-images-5/t32/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/8_outlines.txt
# Processing 6 in folder t32...
# Finished processing 6 in folder t32.
#  - Green cells image saved to: output-images-5/t32/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/6_outlines.txt
# Processing 14 in folder t32...
# Finished processing 14 in folder t32.
#  - Green cells image saved to: output-images-5/t32/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/14_outlines.txt
# Processing 3 in folder t32...
# Finished processing 3 in folder t32.
#  - Green cells image saved to: output-images-5/t32/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/3_outlines.txt
# Processing 7 in folder t32...
# Finished processing 7 in folder t32.
#  - Green cells image saved to: output-images-5/t32/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/7_outlines.txt
# Processing 11 in folder t32...
# Finished processing 11 in folder t32.
#  - Green cells image saved to: output-images-5/t32/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t32/11_outlines.txt
# Processing 13 in folder t7...
# Finished processing 13 in folder t7.
#  - Green cells image saved to: output-images-5/t7/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/13_outlines.txt
# Processing 9 in folder t7...
# Finished processing 9 in folder t7.
#  - Green cells image saved to: output-images-5/t7/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/9_outlines.txt
# Processing 1 in folder t7...
# Finished processing 1 in folder t7.
#  - Green cells image saved to: output-images-5/t7/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/1_outlines.txt
# Processing 12 in folder t7...
# Finished processing 12 in folder t7.
#  - Green cells image saved to: output-images-5/t7/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/12_outlines.txt
# Processing 15 in folder t7...
# Finished processing 15 in folder t7.
#  - Green cells image saved to: output-images-5/t7/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/15_outlines.txt
# Processing 5 in folder t7...
# Finished processing 5 in folder t7.
#  - Green cells image saved to: output-images-5/t7/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/5_outlines.txt
# Processing 10 in folder t7...
# Finished processing 10 in folder t7.
#  - Green cells image saved to: output-images-5/t7/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/10_outlines.txt
# Processing 2 in folder t7...
# Finished processing 2 in folder t7.
#  - Green cells image saved to: output-images-5/t7/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/2_outlines.txt
# Processing 4 in folder t7...
# Finished processing 4 in folder t7.
#  - Green cells image saved to: output-images-5/t7/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/4_outlines.txt
# Processing 8 in folder t7...
# Finished processing 8 in folder t7.
#  - Green cells image saved to: output-images-5/t7/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/8_outlines.txt
# Processing 6 in folder t7...
# Finished processing 6 in folder t7.
#  - Green cells image saved to: output-images-5/t7/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/6_outlines.txt
# Processing 14 in folder t7...
# Finished processing 14 in folder t7.
#  - Green cells image saved to: output-images-5/t7/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/14_outlines.txt
# Processing 3 in folder t7...
# Finished processing 3 in folder t7.
#  - Green cells image saved to: output-images-5/t7/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/3_outlines.txt
# Processing 7 in folder t7...
# Finished processing 7 in folder t7.
#  - Green cells image saved to: output-images-5/t7/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/7_outlines.txt
# Processing 11 in folder t7...
# Finished processing 11 in folder t7.
#  - Green cells image saved to: output-images-5/t7/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t7/11_outlines.txt
# Processing 13 in folder t1...
# Finished processing 13 in folder t1.
#  - Green cells image saved to: output-images-5/t1/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/13_outlines.txt
# Processing 9 in folder t1...
# Finished processing 9 in folder t1.
#  - Green cells image saved to: output-images-5/t1/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/9_outlines.txt
# Processing 1 in folder t1...
# Finished processing 1 in folder t1.
#  - Green cells image saved to: output-images-5/t1/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/1_outlines.txt
# Processing 12 in folder t1...
# Finished processing 12 in folder t1.
#  - Green cells image saved to: output-images-5/t1/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/12_outlines.txt
# Processing 15 in folder t1...
# Finished processing 15 in folder t1.
#  - Green cells image saved to: output-images-5/t1/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/15_outlines.txt
# Processing 5 in folder t1...
# Finished processing 5 in folder t1.
#  - Green cells image saved to: output-images-5/t1/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/5_outlines.txt
# Processing 10 in folder t1...
# Finished processing 10 in folder t1.
#  - Green cells image saved to: output-images-5/t1/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/10_outlines.txt
# Processing 2 in folder t1...
# Finished processing 2 in folder t1.
#  - Green cells image saved to: output-images-5/t1/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/2_outlines.txt
# Processing 4 in folder t1...
# Finished processing 4 in folder t1.
#  - Green cells image saved to: output-images-5/t1/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/4_outlines.txt
# Processing 8 in folder t1...
# Finished processing 8 in folder t1.
#  - Green cells image saved to: output-images-5/t1/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/8_outlines.txt
# Processing 6 in folder t1...
# Finished processing 6 in folder t1.
#  - Green cells image saved to: output-images-5/t1/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/6_outlines.txt
# Processing 14 in folder t1...
# Finished processing 14 in folder t1.
#  - Green cells image saved to: output-images-5/t1/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/14_outlines.txt
# Processing 3 in folder t1...
# Finished processing 3 in folder t1.
#  - Green cells image saved to: output-images-5/t1/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/3_outlines.txt
# Processing 7 in folder t1...
# Finished processing 7 in folder t1.
#  - Green cells image saved to: output-images-5/t1/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/7_outlines.txt
# Processing 11 in folder t1...
# Finished processing 11 in folder t1.
#  - Green cells image saved to: output-images-5/t1/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t1/11_outlines.txt
# Processing 13 in folder t46...
# Finished processing 13 in folder t46.
#  - Green cells image saved to: output-images-5/t46/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t46/13_outlines.txt
# Processing 9 in folder t46...
# Finished processing 9 in folder t46.
#  - Green cells image saved to: output-images-5/t46/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t46/9_outlines.txt
# Processing 1 in folder t46...
# Finished processing 1 in folder t46.
#  - Green cells image saved to: output-images-5/t46/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t46/1_outlines.txt
# Processing 12 in folder t46...
# Finished processing 12 in folder t46.
#  - Green cells image saved to: output-images-5/t46/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t46/12_outlines.txt
# Processing 15 in folder t46...
# Finished processing 15 in folder t46.
#  - Green cells image saved to: output-images-5/t46/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t46/15_outlines.txt
# ...
#  - Green cells image saved to: output-images-5/t21/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t21/4_outlines.txt
# Processing 8 in folder t21...
# Finished processing 8 in folder t21.
#  - Green cells image saved to: output-images-5/t21/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t21/8_outlines.txt
# Processing 6 in folder t21...
# Finished processing 6 in folder t21.
#  - Green cells image saved to: output-images-5/t21/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t21/6_outlines.txt
# Processing 14 in folder t21...
# Finished processing 14 in folder t21.
#  - Green cells image saved to: output-images-5/t21/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t21/14_outlines.txt
# Processing 3 in folder t21...
# Finished processing 3 in folder t21.
#  - Green cells image saved to: output-images-5/t21/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t21/3_outlines.txt
# Processing 7 in folder t21...
# Finished processing 7 in folder t21.
#  - Green cells image saved to: output-images-5/t21/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t21/7_outlines.txt
# Processing 11 in folder t21...
# Finished processing 11 in folder t21.
#  - Green cells image saved to: output-images-5/t21/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t21/11_outlines.txt
# Processing 13 in folder t41...
# Finished processing 13 in folder t41.
#  - Green cells image saved to: output-images-5/t41/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/13_outlines.txt
# Processing 9 in folder t41...
# Finished processing 9 in folder t41.
#  - Green cells image saved to: output-images-5/t41/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/9_outlines.txt
# Processing 1 in folder t41...
# Finished processing 1 in folder t41.
#  - Green cells image saved to: output-images-5/t41/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/1_outlines.txt
# Processing 12 in folder t41...
# Finished processing 12 in folder t41.
#  - Green cells image saved to: output-images-5/t41/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/12_outlines.txt
# Processing 15 in folder t41...
# Finished processing 15 in folder t41.
#  - Green cells image saved to: output-images-5/t41/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/15_outlines.txt
# Processing 5 in folder t41...
# Finished processing 5 in folder t41.
#  - Green cells image saved to: output-images-5/t41/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/5_outlines.txt
# Processing 10 in folder t41...
# Finished processing 10 in folder t41.
#  - Green cells image saved to: output-images-5/t41/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/10_outlines.txt
# Processing 2 in folder t41...
# Finished processing 2 in folder t41.
#  - Green cells image saved to: output-images-5/t41/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/2_outlines.txt
# Processing 4 in folder t41...
# Finished processing 4 in folder t41.
#  - Green cells image saved to: output-images-5/t41/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/4_outlines.txt
# Processing 8 in folder t41...
# Finished processing 8 in folder t41.
#  - Green cells image saved to: output-images-5/t41/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/8_outlines.txt
# Processing 6 in folder t41...
# Finished processing 6 in folder t41.
#  - Green cells image saved to: output-images-5/t41/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/6_outlines.txt
# Processing 14 in folder t41...
# Finished processing 14 in folder t41.
#  - Green cells image saved to: output-images-5/t41/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/14_outlines.txt
# Processing 3 in folder t41...
# Finished processing 3 in folder t41.
#  - Green cells image saved to: output-images-5/t41/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/3_outlines.txt
# Processing 7 in folder t41...
# Finished processing 7 in folder t41.
#  - Green cells image saved to: output-images-5/t41/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/7_outlines.txt
# Processing 11 in folder t41...
# Finished processing 11 in folder t41.
#  - Green cells image saved to: output-images-5/t41/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t41/11_outlines.txt
# Processing 13 in folder t40...
# Finished processing 13 in folder t40.
#  - Green cells image saved to: output-images-5/t40/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/13_outlines.txt
# Processing 9 in folder t40...
# Finished processing 9 in folder t40.
#  - Green cells image saved to: output-images-5/t40/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/9_outlines.txt
# Processing 1 in folder t40...
# Finished processing 1 in folder t40.
#  - Green cells image saved to: output-images-5/t40/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/1_outlines.txt
# Processing 12 in folder t40...
# Finished processing 12 in folder t40.
#  - Green cells image saved to: output-images-5/t40/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/12_outlines.txt
# Processing 15 in folder t40...
# Finished processing 15 in folder t40.
#  - Green cells image saved to: output-images-5/t40/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/15_outlines.txt
# Processing 5 in folder t40...
# Finished processing 5 in folder t40.
#  - Green cells image saved to: output-images-5/t40/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/5_outlines.txt
# Processing 10 in folder t40...
# Finished processing 10 in folder t40.
#  - Green cells image saved to: output-images-5/t40/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/10_outlines.txt
# Processing 2 in folder t40...
# Finished processing 2 in folder t40.
#  - Green cells image saved to: output-images-5/t40/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/2_outlines.txt
# Processing 4 in folder t40...
# Finished processing 4 in folder t40.
#  - Green cells image saved to: output-images-5/t40/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/4_outlines.txt
# Processing 8 in folder t40...
# Finished processing 8 in folder t40.
#  - Green cells image saved to: output-images-5/t40/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/8_outlines.txt
# Processing 6 in folder t40...
# Finished processing 6 in folder t40.
#  - Green cells image saved to: output-images-5/t40/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/6_outlines.txt
# Processing 14 in folder t40...
# Finished processing 14 in folder t40.
#  - Green cells image saved to: output-images-5/t40/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/14_outlines.txt
# Processing 3 in folder t40...
# Finished processing 3 in folder t40.
#  - Green cells image saved to: output-images-5/t40/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/3_outlines.txt
# Processing 7 in folder t40...
# Finished processing 7 in folder t40.
#  - Green cells image saved to: output-images-5/t40/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/7_outlines.txt
# Processing 11 in folder t40...
# Finished processing 11 in folder t40.
#  - Green cells image saved to: output-images-5/t40/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t40/11_outlines.txt
# Processing 13 in folder t31...
# Finished processing 13 in folder t31.
#  - Green cells image saved to: output-images-5/t31/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/13_outlines.txt
# Processing 9 in folder t31...
# Finished processing 9 in folder t31.
#  - Green cells image saved to: output-images-5/t31/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/9_outlines.txt
# Processing 1 in folder t31...
# Finished processing 1 in folder t31.
#  - Green cells image saved to: output-images-5/t31/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/1_outlines.txt
# Processing 12 in folder t31...
# Finished processing 12 in folder t31.
#  - Green cells image saved to: output-images-5/t31/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/12_outlines.txt
# Processing 15 in folder t31...
# Finished processing 15 in folder t31.
#  - Green cells image saved to: output-images-5/t31/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/15_outlines.txt
# Processing 5 in folder t31...
# Finished processing 5 in folder t31.
#  - Green cells image saved to: output-images-5/t31/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/5_outlines.txt
# Processing 10 in folder t31...
# Finished processing 10 in folder t31.
#  - Green cells image saved to: output-images-5/t31/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/10_outlines.txt
# Processing 2 in folder t31...
# Finished processing 2 in folder t31.
#  - Green cells image saved to: output-images-5/t31/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/2_outlines.txt
# Processing 4 in folder t31...
# Finished processing 4 in folder t31.
#  - Green cells image saved to: output-images-5/t31/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/4_outlines.txt
# Processing 8 in folder t31...
# Finished processing 8 in folder t31.
#  - Green cells image saved to: output-images-5/t31/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/8_outlines.txt
# Processing 6 in folder t31...
# Finished processing 6 in folder t31.
#  - Green cells image saved to: output-images-5/t31/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/6_outlines.txt
# Processing 14 in folder t31...
# Finished processing 14 in folder t31.
#  - Green cells image saved to: output-images-5/t31/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/14_outlines.txt
# Processing 3 in folder t31...
# Finished processing 3 in folder t31.
#  - Green cells image saved to: output-images-5/t31/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/3_outlines.txt
# Processing 7 in folder t31...
# Finished processing 7 in folder t31.
#  - Green cells image saved to: output-images-5/t31/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/7_outlines.txt
# Processing 11 in folder t31...
# Finished processing 11 in folder t31.
#  - Green cells image saved to: output-images-5/t31/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t31/11_outlines.txt
# Processing 13 in folder t37...
# Finished processing 13 in folder t37.
#  - Green cells image saved to: output-images-5/t37/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/13_outlines.txt
# Processing 9 in folder t37...
# Finished processing 9 in folder t37.
#  - Green cells image saved to: output-images-5/t37/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/9_outlines.txt
# Processing 1 in folder t37...
# Finished processing 1 in folder t37.
#  - Green cells image saved to: output-images-5/t37/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/1_outlines.txt
# Processing 12 in folder t37...
# Finished processing 12 in folder t37.
#  - Green cells image saved to: output-images-5/t37/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/12_outlines.txt
# Processing 15 in folder t37...
# Finished processing 15 in folder t37.
#  - Green cells image saved to: output-images-5/t37/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/15_outlines.txt
# Processing 5 in folder t37...
# Finished processing 5 in folder t37.
#  - Green cells image saved to: output-images-5/t37/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/5_outlines.txt
# Processing 10 in folder t37...
# Finished processing 10 in folder t37.
#  - Green cells image saved to: output-images-5/t37/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/10_outlines.txt
# Processing 2 in folder t37...
# Finished processing 2 in folder t37.
#  - Green cells image saved to: output-images-5/t37/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/2_outlines.txt
# Processing 4 in folder t37...
# Finished processing 4 in folder t37.
#  - Green cells image saved to: output-images-5/t37/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/4_outlines.txt
# Processing 8 in folder t37...
# Finished processing 8 in folder t37.
#  - Green cells image saved to: output-images-5/t37/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/8_outlines.txt
# Processing 6 in folder t37...
# Finished processing 6 in folder t37.
#  - Green cells image saved to: output-images-5/t37/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/6_outlines.txt
# Processing 14 in folder t37...
# Finished processing 14 in folder t37.
#  - Green cells image saved to: output-images-5/t37/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/14_outlines.txt
# Processing 3 in folder t37...
# Finished processing 3 in folder t37.
#  - Green cells image saved to: output-images-5/t37/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/3_outlines.txt
# Processing 7 in folder t37...
# Finished processing 7 in folder t37.
#  - Green cells image saved to: output-images-5/t37/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/7_outlines.txt
# Processing 11 in folder t37...
# Finished processing 11 in folder t37.
#  - Green cells image saved to: output-images-5/t37/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t37/11_outlines.txt
# Processing 13 in folder t9...
# Finished processing 13 in folder t9.
#  - Green cells image saved to: output-images-5/t9/13_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/13_outlines.txt
# Processing 9 in folder t9...
# Finished processing 9 in folder t9.
#  - Green cells image saved to: output-images-5/t9/9_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/9_outlines.txt
# Processing 1 in folder t9...
# Finished processing 1 in folder t9.
#  - Green cells image saved to: output-images-5/t9/1_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/1_outlines.txt
# Processing 12 in folder t9...
# Finished processing 12 in folder t9.
#  - Green cells image saved to: output-images-5/t9/12_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/12_outlines.txt
# Processing 15 in folder t9...
# Finished processing 15 in folder t9.
#  - Green cells image saved to: output-images-5/t9/15_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/15_outlines.txt
# Processing 5 in folder t9...
# Finished processing 5 in folder t9.
#  - Green cells image saved to: output-images-5/t9/5_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/5_outlines.txt
# Processing 10 in folder t9...
# Finished processing 10 in folder t9.
#  - Green cells image saved to: output-images-5/t9/10_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/10_outlines.txt
# Processing 2 in folder t9...
# Finished processing 2 in folder t9.
#  - Green cells image saved to: output-images-5/t9/2_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/2_outlines.txt
# Processing 4 in folder t9...
# Finished processing 4 in folder t9.
#  - Green cells image saved to: output-images-5/t9/4_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/4_outlines.txt
# Processing 8 in folder t9...
# Finished processing 8 in folder t9.
#  - Green cells image saved to: output-images-5/t9/8_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/8_outlines.txt
# Processing 6 in folder t9...
# Finished processing 6 in folder t9.
#  - Green cells image saved to: output-images-5/t9/6_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/6_outlines.txt
# Processing 14 in folder t9...
# Finished processing 14 in folder t9.
#  - Green cells image saved to: output-images-5/t9/14_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/14_outlines.txt
# Processing 3 in folder t9...
# Finished processing 3 in folder t9.
#  - Green cells image saved to: output-images-5/t9/3_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/3_outlines.txt
# Processing 7 in folder t9...
# Finished processing 7 in folder t9.
#  - Green cells image saved to: output-images-5/t9/7_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/7_outlines.txt
# Processing 11 in folder t9...
# Finished processing 11 in folder t9.
#  - Green cells image saved to: output-images-5/t9/11_green_cells.png
#  - Outlines saved to: output-outlines-5/t9/11_outlines.txt

# %%
import os
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
from cellpose import io

# -------------------------------
# Configuration and Setup
# -------------------------------
base_input_folder = 'A1-raw-data-2'  # Base folder containing subfolders with images and segmentation files
output_folder_images = 'output-images-2'       # For saving overlay images
output_folder_outlines = 'output-outlines-2'    # For saving cell outlines
output_folder_masks = 'output-masks-2'          # For saving filtered mask files

# Create output directories if they don't exist
os.makedirs(output_folder_images, exist_ok=True)
os.makedirs(output_folder_outlines, exist_ok=True)
os.makedirs(output_folder_masks, exist_ok=True)

# Recursively find all segmentation files (assumed to end with '_seg.npy')
segmentation_files = glob.glob(os.path.join(base_input_folder, '**', '*_seg.npy'), recursive=True)

# Define HSV thresholds and green pixel ratio threshold
lower_green = np.array([40, 45, 45])
upper_green = np.array([80, 255, 255])
green_pixel_ratio_threshold = 0.50  # 50% or more pixels must be green

# -------------------------------
# Process each file pair in the folder tree
# -------------------------------
for seg_file in segmentation_files:
    # Determine the base name (e.g., "image_seg.npy" -> "image")
    base_name = os.path.basename(seg_file).replace('_seg.npy', '')
    
    # The corresponding image is assumed to be in the same folder with a .tif extension
    img_file = os.path.join(os.path.dirname(seg_file), base_name + '.tif')
    
    # Check if the corresponding image file exists
    if not os.path.exists(img_file):
        print(f"Image file {img_file} not found for segmentation file {seg_file}. Skipping.")
        continue

    # Determine subfolder relative to the base_input_folder for output organization
    subfolder = os.path.relpath(os.path.dirname(seg_file), base_input_folder)
    out_img_folder = os.path.join(output_folder_images, subfolder)
    out_outline_folder = os.path.join(output_folder_outlines, subfolder)
    out_mask_folder = os.path.join(output_folder_masks, subfolder)
    os.makedirs(out_img_folder, exist_ok=True)
    os.makedirs(out_outline_folder, exist_ok=True)
    os.makedirs(out_mask_folder, exist_ok=True)
    
    print(f"Processing {base_name} in folder {subfolder}...")

    # -------------------------------
    # Part 1: Load data and build the mask dictionary
    # -------------------------------
    dat = np.load(seg_file, allow_pickle=True).item()
    img = io.imread(img_file)

    # Ensure the image is in RGB (if grayscale, convert it)
    if img.ndim == 2 or (img.ndim == 3 and img.shape[2] == 1):
        img = np.stack([img.squeeze()] * 3, axis=-1)

    masks = dat['masks']

    # Create a dictionary: key -> tuple of (y,x) coordinates for the mask pixels,
    # value -> average RGB value (for visualization if desired)
    mask_dict = {}
    labels = np.unique(masks)
    for label in labels:
        if label == 0:  # Skip background
            continue
        cell_mask = masks == label
        coords = np.argwhere(cell_mask)
        coords_tuple = tuple(map(tuple, coords))
        avg_rgb = np.mean(img[cell_mask], axis=0)
        mask_dict[coords_tuple] = avg_rgb

    # -------------------------------
    # Part 2: Filter cells using HSV thresholds
    # -------------------------------
    # Convert the image from RGB to HSV
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    # Create a binary mask for green regions
    hsv_green_mask = cv2.inRange(hsv, lower_green, upper_green)

    filtered_dict = {}
    filtered_labels = []  # Keep track of which cell labels pass the filter
    
    for coords, avg_rgb in mask_dict.items():
        coords_array = np.array(coords)  # shape (N, 2)
        # Extract the green mask values for the cell's pixels
        green_vals = hsv_green_mask[coords_array[:, 0], coords_array[:, 1]]
        ratio_green = np.sum(green_vals == 255) / len(green_vals)
        
        # Find the original label for this cell
        y, x = coords_array[0]  # Get coordinates of first pixel
        label = masks[y, x]
        
        if ratio_green >= green_pixel_ratio_threshold:
            filtered_dict[coords] = avg_rgb
            filtered_labels.append(label)

    # -------------------------------
    # Part 3: Create an overlay mask and save the overlay image
    # -------------------------------
    overlay_mask = np.zeros(masks.shape, dtype=bool)
    for coords in filtered_dict.keys():
        for (y, x) in coords:
            overlay_mask[y, x] = True

    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    masked_overlay = np.ma.masked_where(~overlay_mask, overlay_mask)
    plt.imshow(masked_overlay, cmap='Reds', alpha=0.5)
    plt.title(f'Cells with ≥ {int(green_pixel_ratio_threshold*100)}% Green Pixels')
    plt.axis('off')

    # Save the overlay image to the output folder (preserving subfolder structure)
    output_overlay_file = os.path.join(out_img_folder, base_name + '_overlay.png')
    plt.savefig(output_overlay_file, bbox_inches='tight')
    plt.close()

    # -------------------------------
    # Part 4: Extract cell outlines and write to file
    # -------------------------------
    outline_file = os.path.join(out_outline_folder, base_name + '_outlines.txt')
    with open(outline_file, "w") as f:
        for coords in filtered_dict.keys():
            # Create a binary image for this cell mask
            cell_mask_img = np.zeros(masks.shape, dtype=np.uint8)
            coords_np = np.array(coords)
            cell_mask_img[coords_np[:, 0], coords_np[:, 1]] = 255

            # Find contours; using RETR_EXTERNAL to get only the outer boundary
            contours, _ = cv2.findContours(cell_mask_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            if len(contours) == 0:
                continue

            # Choose the largest contour (in case there are multiple)
            largest_contour = max(contours, key=cv2.contourArea)
            largest_contour = largest_contour.squeeze()
            # Ensure the contour is 2D (in case it's only a single point)
            if largest_contour.ndim == 1:
                largest_contour = np.expand_dims(largest_contour, axis=0)

            # Format the contour as "x,y,x,y,..." (note: OpenCV contours are in (x,y) order)
            coord_pairs = [f"{pt[0]},{pt[1]}" for pt in largest_contour]
            outline_str = ",".join(coord_pairs)
            f.write(outline_str + "\n")
    
    # -------------------------------
    # Part 5: Create and save filtered masks file
    # -------------------------------
    # Create a new masks array with only the filtered cells
    filtered_masks = np.zeros_like(masks)
    for label in filtered_labels:
        filtered_masks[masks == label] = label
    
    # Create a new dictionary with the filtered masks to save
    filtered_dat = dat.copy()  # Copy all original data
    filtered_dat['masks'] = filtered_masks  # Replace with filtered masks
    
    # Save the filtered masks to a new npy file
    output_mask_file = os.path.join(out_mask_folder, base_name + '_filtered_seg.npy')
    np.save(output_mask_file, filtered_dat)

    print(f"Finished processing {base_name} in folder {subfolder}.")
    print(f" - Overlay saved to: {output_overlay_file}")
    print(f" - Outlines saved to: {outline_file}")
    print(f" - Filtered masks saved to: {output_mask_file}")
# Out:
# Processing 13 in folder t16...
# Finished processing 13 in folder t16.
#  - Overlay saved to: output-images-2/t16/13_overlay.png
#  - Outlines saved to: output-outlines-2/t16/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/13_filtered_seg.npy
# Processing 9 in folder t16...
# Finished processing 9 in folder t16.
#  - Overlay saved to: output-images-2/t16/9_overlay.png
#  - Outlines saved to: output-outlines-2/t16/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/9_filtered_seg.npy
# Processing 1 in folder t16...
# Finished processing 1 in folder t16.
#  - Overlay saved to: output-images-2/t16/1_overlay.png
#  - Outlines saved to: output-outlines-2/t16/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/1_filtered_seg.npy
# Processing 12 in folder t16...
# Finished processing 12 in folder t16.
#  - Overlay saved to: output-images-2/t16/12_overlay.png
#  - Outlines saved to: output-outlines-2/t16/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/12_filtered_seg.npy
# Processing 15 in folder t16...
# Finished processing 15 in folder t16.
#  - Overlay saved to: output-images-2/t16/15_overlay.png
#  - Outlines saved to: output-outlines-2/t16/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/15_filtered_seg.npy
# Processing 5 in folder t16...
# Finished processing 5 in folder t16.
#  - Overlay saved to: output-images-2/t16/5_overlay.png
#  - Outlines saved to: output-outlines-2/t16/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/5_filtered_seg.npy
# Processing 10 in folder t16...
# Finished processing 10 in folder t16.
#  - Overlay saved to: output-images-2/t16/10_overlay.png
#  - Outlines saved to: output-outlines-2/t16/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/10_filtered_seg.npy
# Processing 2 in folder t16...
# Finished processing 2 in folder t16.
#  - Overlay saved to: output-images-2/t16/2_overlay.png
#  - Outlines saved to: output-outlines-2/t16/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/2_filtered_seg.npy
# Processing 4 in folder t16...
# Finished processing 4 in folder t16.
#  - Overlay saved to: output-images-2/t16/4_overlay.png
#  - Outlines saved to: output-outlines-2/t16/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/4_filtered_seg.npy
# Processing 8 in folder t16...
# Finished processing 8 in folder t16.
#  - Overlay saved to: output-images-2/t16/8_overlay.png
#  - Outlines saved to: output-outlines-2/t16/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/8_filtered_seg.npy
# Processing 6 in folder t16...
# Finished processing 6 in folder t16.
#  - Overlay saved to: output-images-2/t16/6_overlay.png
#  - Outlines saved to: output-outlines-2/t16/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/6_filtered_seg.npy
# Processing 14 in folder t16...
# Finished processing 14 in folder t16.
#  - Overlay saved to: output-images-2/t16/14_overlay.png
#  - Outlines saved to: output-outlines-2/t16/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/14_filtered_seg.npy
# Processing 3 in folder t16...
# Finished processing 3 in folder t16.
#  - Overlay saved to: output-images-2/t16/3_overlay.png
#  - Outlines saved to: output-outlines-2/t16/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/3_filtered_seg.npy
# Processing 7 in folder t16...
# Finished processing 7 in folder t16.
#  - Overlay saved to: output-images-2/t16/7_overlay.png
#  - Outlines saved to: output-outlines-2/t16/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/7_filtered_seg.npy
# Processing 11 in folder t16...
# Finished processing 11 in folder t16.
#  - Overlay saved to: output-images-2/t16/11_overlay.png
#  - Outlines saved to: output-outlines-2/t16/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/11_filtered_seg.npy
# Processing 13 in folder t34...
# Finished processing 13 in folder t34.
#  - Overlay saved to: output-images-2/t34/13_overlay.png
#  - Outlines saved to: output-outlines-2/t34/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/13_filtered_seg.npy
# Processing 9 in folder t34...
# Finished processing 9 in folder t34.
#  - Overlay saved to: output-images-2/t34/9_overlay.png
#  - Outlines saved to: output-outlines-2/t34/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/9_filtered_seg.npy
# Processing 1 in folder t34...
# Finished processing 1 in folder t34.
#  - Overlay saved to: output-images-2/t34/1_overlay.png
#  - Outlines saved to: output-outlines-2/t34/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/1_filtered_seg.npy
# Processing 12 in folder t34...
# Finished processing 12 in folder t34.
#  - Overlay saved to: output-images-2/t34/12_overlay.png
#  - Outlines saved to: output-outlines-2/t34/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/12_filtered_seg.npy
# Processing 15 in folder t34...
# Finished processing 15 in folder t34.
#  - Overlay saved to: output-images-2/t34/15_overlay.png
#  - Outlines saved to: output-outlines-2/t34/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/15_filtered_seg.npy
# Processing 5 in folder t34...
# Finished processing 5 in folder t34.
#  - Overlay saved to: output-images-2/t34/5_overlay.png
#  - Outlines saved to: output-outlines-2/t34/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/5_filtered_seg.npy
# Processing 10 in folder t34...
# Finished processing 10 in folder t34.
#  - Overlay saved to: output-images-2/t34/10_overlay.png
#  - Outlines saved to: output-outlines-2/t34/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/10_filtered_seg.npy
# Processing 2 in folder t34...
# Finished processing 2 in folder t34.
#  - Overlay saved to: output-images-2/t34/2_overlay.png
#  - Outlines saved to: output-outlines-2/t34/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/2_filtered_seg.npy
# Processing 4 in folder t34...
# Finished processing 4 in folder t34.
#  - Overlay saved to: output-images-2/t34/4_overlay.png
#  - Outlines saved to: output-outlines-2/t34/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/4_filtered_seg.npy
# Processing 8 in folder t34...
# Finished processing 8 in folder t34.
#  - Overlay saved to: output-images-2/t34/8_overlay.png
#  - Outlines saved to: output-outlines-2/t34/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/8_filtered_seg.npy
# Processing 6 in folder t34...
# Finished processing 6 in folder t34.
#  - Overlay saved to: output-images-2/t34/6_overlay.png
#  - Outlines saved to: output-outlines-2/t34/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/6_filtered_seg.npy
# Processing 14 in folder t34...
# Finished processing 14 in folder t34.
#  - Overlay saved to: output-images-2/t34/14_overlay.png
#  - Outlines saved to: output-outlines-2/t34/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/14_filtered_seg.npy
# Processing 3 in folder t34...
# Finished processing 3 in folder t34.
#  - Overlay saved to: output-images-2/t34/3_overlay.png
#  - Outlines saved to: output-outlines-2/t34/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/3_filtered_seg.npy
# Processing 7 in folder t34...
# Finished processing 7 in folder t34.
#  - Overlay saved to: output-images-2/t34/7_overlay.png
#  - Outlines saved to: output-outlines-2/t34/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/7_filtered_seg.npy
# Processing 11 in folder t34...
# Finished processing 11 in folder t34.
#  - Overlay saved to: output-images-2/t34/11_overlay.png
#  - Outlines saved to: output-outlines-2/t34/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/11_filtered_seg.npy
# Processing 13 in folder t22...
# Finished processing 13 in folder t22.
#  - Overlay saved to: output-images-2/t22/13_overlay.png
#  - Outlines saved to: output-outlines-2/t22/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/13_filtered_seg.npy
# Processing 9 in folder t22...
# Finished processing 9 in folder t22.
#  - Overlay saved to: output-images-2/t22/9_overlay.png
#  - Outlines saved to: output-outlines-2/t22/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/9_filtered_seg.npy
# Processing 1 in folder t22...
# Finished processing 1 in folder t22.
#  - Overlay saved to: output-images-2/t22/1_overlay.png
#  - Outlines saved to: output-outlines-2/t22/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/1_filtered_seg.npy
# Processing 12 in folder t22...
# Finished processing 12 in folder t22.
#  - Overlay saved to: output-images-2/t22/12_overlay.png
#  - Outlines saved to: output-outlines-2/t22/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/12_filtered_seg.npy
# Processing 15 in folder t22...
# Finished processing 15 in folder t22.
#  - Overlay saved to: output-images-2/t22/15_overlay.png
#  - Outlines saved to: output-outlines-2/t22/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/15_filtered_seg.npy
# Processing 5 in folder t22...
# Finished processing 5 in folder t22.
#  - Overlay saved to: output-images-2/t22/5_overlay.png
#  - Outlines saved to: output-outlines-2/t22/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/5_filtered_seg.npy
# Processing 10 in folder t22...
# Finished processing 10 in folder t22.
#  - Overlay saved to: output-images-2/t22/10_overlay.png
#  - Outlines saved to: output-outlines-2/t22/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/10_filtered_seg.npy
# Processing 2 in folder t22...
# Finished processing 2 in folder t22.
#  - Overlay saved to: output-images-2/t22/2_overlay.png
#  - Outlines saved to: output-outlines-2/t22/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/2_filtered_seg.npy
# Processing 4 in folder t22...
# Finished processing 4 in folder t22.
#  - Overlay saved to: output-images-2/t22/4_overlay.png
#  - Outlines saved to: output-outlines-2/t22/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/4_filtered_seg.npy
# Processing 8 in folder t22...
# Finished processing 8 in folder t22.
#  - Overlay saved to: output-images-2/t22/8_overlay.png
#  - Outlines saved to: output-outlines-2/t22/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/8_filtered_seg.npy
# Processing 6 in folder t22...
# Finished processing 6 in folder t22.
#  - Overlay saved to: output-images-2/t22/6_overlay.png
#  - Outlines saved to: output-outlines-2/t22/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/6_filtered_seg.npy
# Processing 14 in folder t22...
# Finished processing 14 in folder t22.
#  - Overlay saved to: output-images-2/t22/14_overlay.png
#  - Outlines saved to: output-outlines-2/t22/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/14_filtered_seg.npy
# Processing 3 in folder t22...
# Finished processing 3 in folder t22.
#  - Overlay saved to: output-images-2/t22/3_overlay.png
#  - Outlines saved to: output-outlines-2/t22/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/3_filtered_seg.npy
# Processing 7 in folder t22...
# Finished processing 7 in folder t22.
#  - Overlay saved to: output-images-2/t22/7_overlay.png
#  - Outlines saved to: output-outlines-2/t22/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/7_filtered_seg.npy
# Processing 11 in folder t22...
# Finished processing 11 in folder t22.
#  - Overlay saved to: output-images-2/t22/11_overlay.png
#  - Outlines saved to: output-outlines-2/t22/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/11_filtered_seg.npy
# Processing 13 in folder t20...
# Finished processing 13 in folder t20.
#  - Overlay saved to: output-images-2/t20/13_overlay.png
#  - Outlines saved to: output-outlines-2/t20/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/13_filtered_seg.npy
# Processing 9 in folder t20...
# Finished processing 9 in folder t20.
#  - Overlay saved to: output-images-2/t20/9_overlay.png
#  - Outlines saved to: output-outlines-2/t20/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/9_filtered_seg.npy
# Processing 1 in folder t20...
# Finished processing 1 in folder t20.
#  - Overlay saved to: output-images-2/t20/1_overlay.png
#  - Outlines saved to: output-outlines-2/t20/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/1_filtered_seg.npy
# Processing 12 in folder t20...
# Finished processing 12 in folder t20.
#  - Overlay saved to: output-images-2/t20/12_overlay.png
#  - Outlines saved to: output-outlines-2/t20/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/12_filtered_seg.npy
# Processing 15 in folder t20...
# Finished processing 15 in folder t20.
#  - Overlay saved to: output-images-2/t20/15_overlay.png
#  - Outlines saved to: output-outlines-2/t20/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/15_filtered_seg.npy
# Processing 5 in folder t20...
# Finished processing 5 in folder t20.
#  - Overlay saved to: output-images-2/t20/5_overlay.png
#  - Outlines saved to: output-outlines-2/t20/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/5_filtered_seg.npy
# Processing 10 in folder t20...
# Finished processing 10 in folder t20.
#  - Overlay saved to: output-images-2/t20/10_overlay.png
#  - Outlines saved to: output-outlines-2/t20/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/10_filtered_seg.npy
# Processing 2 in folder t20...
# Finished processing 2 in folder t20.
#  - Overlay saved to: output-images-2/t20/2_overlay.png
#  - Outlines saved to: output-outlines-2/t20/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/2_filtered_seg.npy
# Processing 4 in folder t20...
# Finished processing 4 in folder t20.
#  - Overlay saved to: output-images-2/t20/4_overlay.png
#  - Outlines saved to: output-outlines-2/t20/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/4_filtered_seg.npy
# Processing 8 in folder t20...
# Finished processing 8 in folder t20.
#  - Overlay saved to: output-images-2/t20/8_overlay.png
#  - Outlines saved to: output-outlines-2/t20/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/8_filtered_seg.npy
# Processing 6 in folder t20...
# Finished processing 6 in folder t20.
#  - Overlay saved to: output-images-2/t20/6_overlay.png
#  - Outlines saved to: output-outlines-2/t20/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/6_filtered_seg.npy
# Processing 14 in folder t20...
# Finished processing 14 in folder t20.
#  - Overlay saved to: output-images-2/t20/14_overlay.png
#  - Outlines saved to: output-outlines-2/t20/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/14_filtered_seg.npy
# Processing 3 in folder t20...
# Finished processing 3 in folder t20.
#  - Overlay saved to: output-images-2/t20/3_overlay.png
#  - Outlines saved to: output-outlines-2/t20/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/3_filtered_seg.npy
# Processing 7 in folder t20...
# Finished processing 7 in folder t20.
#  - Overlay saved to: output-images-2/t20/7_overlay.png
#  - Outlines saved to: output-outlines-2/t20/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/7_filtered_seg.npy
# Processing 11 in folder t20...
# Finished processing 11 in folder t20.
#  - Overlay saved to: output-images-2/t20/11_overlay.png
#  - Outlines saved to: output-outlines-2/t20/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/11_filtered_seg.npy
# Processing 13 in folder t43...
# Finished processing 13 in folder t43.
#  - Overlay saved to: output-images-2/t43/13_overlay.png
#  - Outlines saved to: output-outlines-2/t43/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/13_filtered_seg.npy
# Processing 9 in folder t43...
# Finished processing 9 in folder t43.
#  - Overlay saved to: output-images-2/t43/9_overlay.png
#  - Outlines saved to: output-outlines-2/t43/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/9_filtered_seg.npy
# Processing 1 in folder t43...
# Finished processing 1 in folder t43.
#  - Overlay saved to: output-images-2/t43/1_overlay.png
#  - Outlines saved to: output-outlines-2/t43/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/1_filtered_seg.npy
# Processing 12 in folder t43...
# Finished processing 12 in folder t43.
#  - Overlay saved to: output-images-2/t43/12_overlay.png
#  - Outlines saved to: output-outlines-2/t43/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/12_filtered_seg.npy
# Processing 15 in folder t43...
# Finished processing 15 in folder t43.
#  - Overlay saved to: output-images-2/t43/15_overlay.png
#  - Outlines saved to: output-outlines-2/t43/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/15_filtered_seg.npy
# Processing 5 in folder t43...
# Finished processing 5 in folder t43.
#  - Overlay saved to: output-images-2/t43/5_overlay.png
#  - Outlines saved to: output-outlines-2/t43/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/5_filtered_seg.npy
# Processing 10 in folder t43...
# Finished processing 10 in folder t43.
#  - Overlay saved to: output-images-2/t43/10_overlay.png
#  - Outlines saved to: output-outlines-2/t43/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/10_filtered_seg.npy
# Processing 2 in folder t43...
# Finished processing 2 in folder t43.
#  - Overlay saved to: output-images-2/t43/2_overlay.png
#  - Outlines saved to: output-outlines-2/t43/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/2_filtered_seg.npy
# Processing 4 in folder t43...
# Finished processing 4 in folder t43.
#  - Overlay saved to: output-images-2/t43/4_overlay.png
#  - Outlines saved to: output-outlines-2/t43/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/4_filtered_seg.npy
# Processing 8 in folder t43...
# Finished processing 8 in folder t43.
#  - Overlay saved to: output-images-2/t43/8_overlay.png
#  - Outlines saved to: output-outlines-2/t43/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/8_filtered_seg.npy
# Processing 6 in folder t43...
# Finished processing 6 in folder t43.
#  - Overlay saved to: output-images-2/t43/6_overlay.png
#  - Outlines saved to: output-outlines-2/t43/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/6_filtered_seg.npy
# Processing 14 in folder t43...
# Finished processing 14 in folder t43.
#  - Overlay saved to: output-images-2/t43/14_overlay.png
#  - Outlines saved to: output-outlines-2/t43/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/14_filtered_seg.npy
# Processing 3 in folder t43...
# Finished processing 3 in folder t43.
#  - Overlay saved to: output-images-2/t43/3_overlay.png
#  - Outlines saved to: output-outlines-2/t43/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/3_filtered_seg.npy
# Processing 7 in folder t43...
# Finished processing 7 in folder t43.
#  - Overlay saved to: output-images-2/t43/7_overlay.png
#  - Outlines saved to: output-outlines-2/t43/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/7_filtered_seg.npy
# Processing 11 in folder t43...
# Finished processing 11 in folder t43.
#  - Overlay saved to: output-images-2/t43/11_overlay.png
#  - Outlines saved to: output-outlines-2/t43/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/11_filtered_seg.npy
# Processing 13 in folder t33...
# Finished processing 13 in folder t33.
#  - Overlay saved to: output-images-2/t33/13_overlay.png
#  - Outlines saved to: output-outlines-2/t33/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/13_filtered_seg.npy
# Processing 9 in folder t33...
# Finished processing 9 in folder t33.
#  - Overlay saved to: output-images-2/t33/9_overlay.png
#  - Outlines saved to: output-outlines-2/t33/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/9_filtered_seg.npy
# Processing 1 in folder t33...
# Finished processing 1 in folder t33.
#  - Overlay saved to: output-images-2/t33/1_overlay.png
#  - Outlines saved to: output-outlines-2/t33/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/1_filtered_seg.npy
# Processing 12 in folder t33...
# Finished processing 12 in folder t33.
#  - Overlay saved to: output-images-2/t33/12_overlay.png
#  - Outlines saved to: output-outlines-2/t33/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/12_filtered_seg.npy
# Processing 15 in folder t33...
# Finished processing 15 in folder t33.
#  - Overlay saved to: output-images-2/t33/15_overlay.png
#  - Outlines saved to: output-outlines-2/t33/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/15_filtered_seg.npy
# Processing 5 in folder t33...
# Finished processing 5 in folder t33.
#  - Overlay saved to: output-images-2/t33/5_overlay.png
#  - Outlines saved to: output-outlines-2/t33/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/5_filtered_seg.npy
# Processing 10 in folder t33...
# Finished processing 10 in folder t33.
#  - Overlay saved to: output-images-2/t33/10_overlay.png
#  - Outlines saved to: output-outlines-2/t33/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/10_filtered_seg.npy
# Processing 2 in folder t33...
# Finished processing 2 in folder t33.
#  - Overlay saved to: output-images-2/t33/2_overlay.png
#  - Outlines saved to: output-outlines-2/t33/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/2_filtered_seg.npy
# Processing 4 in folder t33...
# Finished processing 4 in folder t33.
#  - Overlay saved to: output-images-2/t33/4_overlay.png
#  - Outlines saved to: output-outlines-2/t33/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/4_filtered_seg.npy
# Processing 8 in folder t33...
# Finished processing 8 in folder t33.
#  - Overlay saved to: output-images-2/t33/8_overlay.png
#  - Outlines saved to: output-outlines-2/t33/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/8_filtered_seg.npy
# Processing 6 in folder t33...
# Finished processing 6 in folder t33.
#  - Overlay saved to: output-images-2/t33/6_overlay.png
#  - Outlines saved to: output-outlines-2/t33/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/6_filtered_seg.npy
# Processing 14 in folder t33...
# Finished processing 14 in folder t33.
#  - Overlay saved to: output-images-2/t33/14_overlay.png
#  - Outlines saved to: output-outlines-2/t33/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/14_filtered_seg.npy
# Processing 3 in folder t33...
# Finished processing 3 in folder t33.
#  - Overlay saved to: output-images-2/t33/3_overlay.png
#  - Outlines saved to: output-outlines-2/t33/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/3_filtered_seg.npy
# Processing 7 in folder t33...
# Finished processing 7 in folder t33.
#  - Overlay saved to: output-images-2/t33/7_overlay.png
#  - Outlines saved to: output-outlines-2/t33/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/7_filtered_seg.npy
# Processing 11 in folder t33...
# Finished processing 11 in folder t33.
#  - Overlay saved to: output-images-2/t33/11_overlay.png
#  - Outlines saved to: output-outlines-2/t33/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/11_filtered_seg.npy
# Processing 13 in folder t42...
# Finished processing 13 in folder t42.
#  - Overlay saved to: output-images-2/t42/13_overlay.png
#  - Outlines saved to: output-outlines-2/t42/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/13_filtered_seg.npy
# Processing 9 in folder t42...
# Finished processing 9 in folder t42.
#  - Overlay saved to: output-images-2/t42/9_overlay.png
#  - Outlines saved to: output-outlines-2/t42/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/9_filtered_seg.npy
# Processing 1 in folder t42...
# Finished processing 1 in folder t42.
#  - Overlay saved to: output-images-2/t42/1_overlay.png
#  - Outlines saved to: output-outlines-2/t42/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/1_filtered_seg.npy
# Processing 12 in folder t42...
# Finished processing 12 in folder t42.
#  - Overlay saved to: output-images-2/t42/12_overlay.png
#  - Outlines saved to: output-outlines-2/t42/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/12_filtered_seg.npy
# Processing 15 in folder t42...
# Finished processing 15 in folder t42.
#  - Overlay saved to: output-images-2/t42/15_overlay.png
#  - Outlines saved to: output-outlines-2/t42/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/15_filtered_seg.npy
# Processing 5 in folder t42...
# Finished processing 5 in folder t42.
#  - Overlay saved to: output-images-2/t42/5_overlay.png
#  - Outlines saved to: output-outlines-2/t42/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/5_filtered_seg.npy
# Processing 10 in folder t42...
# Finished processing 10 in folder t42.
#  - Overlay saved to: output-images-2/t42/10_overlay.png
#  - Outlines saved to: output-outlines-2/t42/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/10_filtered_seg.npy
# Processing 2 in folder t42...
# Finished processing 2 in folder t42.
#  - Overlay saved to: output-images-2/t42/2_overlay.png
#  - Outlines saved to: output-outlines-2/t42/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/2_filtered_seg.npy
# Processing 4 in folder t42...
# Finished processing 4 in folder t42.
#  - Overlay saved to: output-images-2/t42/4_overlay.png
#  - Outlines saved to: output-outlines-2/t42/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/4_filtered_seg.npy
# Processing 8 in folder t42...
# Finished processing 8 in folder t42.
#  - Overlay saved to: output-images-2/t42/8_overlay.png
#  - Outlines saved to: output-outlines-2/t42/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/8_filtered_seg.npy
# Processing 6 in folder t42...
# Finished processing 6 in folder t42.
#  - Overlay saved to: output-images-2/t42/6_overlay.png
#  - Outlines saved to: output-outlines-2/t42/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/6_filtered_seg.npy
# Processing 14 in folder t42...
# Finished processing 14 in folder t42.
#  - Overlay saved to: output-images-2/t42/14_overlay.png
#  - Outlines saved to: output-outlines-2/t42/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/14_filtered_seg.npy
# Processing 3 in folder t42...
# Finished processing 3 in folder t42.
#  - Overlay saved to: output-images-2/t42/3_overlay.png
#  - Outlines saved to: output-outlines-2/t42/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/3_filtered_seg.npy
# Processing 7 in folder t42...
# Finished processing 7 in folder t42.
#  - Overlay saved to: output-images-2/t42/7_overlay.png
#  - Outlines saved to: output-outlines-2/t42/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/7_filtered_seg.npy
# Processing 11 in folder t42...
# Finished processing 11 in folder t42.
#  - Overlay saved to: output-images-2/t42/11_overlay.png
#  - Outlines saved to: output-outlines-2/t42/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/11_filtered_seg.npy
# Processing 13 in folder t27...
# Finished processing 13 in folder t27.
#  - Overlay saved to: output-images-2/t27/13_overlay.png
#  - Outlines saved to: output-outlines-2/t27/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/13_filtered_seg.npy
# Processing 9 in folder t27...
# Finished processing 9 in folder t27.
#  - Overlay saved to: output-images-2/t27/9_overlay.png
#  - Outlines saved to: output-outlines-2/t27/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/9_filtered_seg.npy
# Processing 1 in folder t27...
# Finished processing 1 in folder t27.
#  - Overlay saved to: output-images-2/t27/1_overlay.png
#  - Outlines saved to: output-outlines-2/t27/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/1_filtered_seg.npy
# Processing 12 in folder t27...
# Finished processing 12 in folder t27.
#  - Overlay saved to: output-images-2/t27/12_overlay.png
#  - Outlines saved to: output-outlines-2/t27/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/12_filtered_seg.npy
# Processing 15 in folder t27...
# Finished processing 15 in folder t27.
#  - Overlay saved to: output-images-2/t27/15_overlay.png
#  - Outlines saved to: output-outlines-2/t27/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/15_filtered_seg.npy
# Processing 5 in folder t27...
# Finished processing 5 in folder t27.
#  - Overlay saved to: output-images-2/t27/5_overlay.png
#  - Outlines saved to: output-outlines-2/t27/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/5_filtered_seg.npy
# Processing 10 in folder t27...
# Finished processing 10 in folder t27.
#  - Overlay saved to: output-images-2/t27/10_overlay.png
#  - Outlines saved to: output-outlines-2/t27/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/10_filtered_seg.npy
# Processing 2 in folder t27...
# Finished processing 2 in folder t27.
#  - Overlay saved to: output-images-2/t27/2_overlay.png
#  - Outlines saved to: output-outlines-2/t27/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/2_filtered_seg.npy
# Processing 4 in folder t27...
# Finished processing 4 in folder t27.
#  - Overlay saved to: output-images-2/t27/4_overlay.png
#  - Outlines saved to: output-outlines-2/t27/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/4_filtered_seg.npy
# Processing 8 in folder t27...
# Finished processing 8 in folder t27.
#  - Overlay saved to: output-images-2/t27/8_overlay.png
#  - Outlines saved to: output-outlines-2/t27/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/8_filtered_seg.npy
# Processing 6 in folder t27...
# Finished processing 6 in folder t27.
#  - Overlay saved to: output-images-2/t27/6_overlay.png
#  - Outlines saved to: output-outlines-2/t27/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/6_filtered_seg.npy
# Processing 14 in folder t27...
# Finished processing 14 in folder t27.
#  - Overlay saved to: output-images-2/t27/14_overlay.png
#  - Outlines saved to: output-outlines-2/t27/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/14_filtered_seg.npy
# Processing 3 in folder t27...
# Finished processing 3 in folder t27.
#  - Overlay saved to: output-images-2/t27/3_overlay.png
#  - Outlines saved to: output-outlines-2/t27/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/3_filtered_seg.npy
# Processing 7 in folder t27...
# Finished processing 7 in folder t27.
#  - Overlay saved to: output-images-2/t27/7_overlay.png
#  - Outlines saved to: output-outlines-2/t27/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/7_filtered_seg.npy
# Processing 11 in folder t27...
# Finished processing 11 in folder t27.
#  - Overlay saved to: output-images-2/t27/11_overlay.png
#  - Outlines saved to: output-outlines-2/t27/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/11_filtered_seg.npy
# Processing 13 in folder t13...
# Finished processing 13 in folder t13.
#  - Overlay saved to: output-images-2/t13/13_overlay.png
#  - Outlines saved to: output-outlines-2/t13/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/13_filtered_seg.npy
# Processing 9 in folder t13...
# Finished processing 9 in folder t13.
#  - Overlay saved to: output-images-2/t13/9_overlay.png
#  - Outlines saved to: output-outlines-2/t13/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/9_filtered_seg.npy
# Processing 1 in folder t13...
# Finished processing 1 in folder t13.
#  - Overlay saved to: output-images-2/t13/1_overlay.png
#  - Outlines saved to: output-outlines-2/t13/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/1_filtered_seg.npy
# Processing 12 in folder t13...
# Finished processing 12 in folder t13.
#  - Overlay saved to: output-images-2/t13/12_overlay.png
#  - Outlines saved to: output-outlines-2/t13/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/12_filtered_seg.npy
# Processing 15 in folder t13...
# Finished processing 15 in folder t13.
#  - Overlay saved to: output-images-2/t13/15_overlay.png
#  - Outlines saved to: output-outlines-2/t13/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/15_filtered_seg.npy
# Processing 5 in folder t13...
# Finished processing 5 in folder t13.
#  - Overlay saved to: output-images-2/t13/5_overlay.png
#  - Outlines saved to: output-outlines-2/t13/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/5_filtered_seg.npy
# Processing 10 in folder t13...
# Finished processing 10 in folder t13.
#  - Overlay saved to: output-images-2/t13/10_overlay.png
#  - Outlines saved to: output-outlines-2/t13/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/10_filtered_seg.npy
# Processing 2 in folder t13...
# Finished processing 2 in folder t13.
#  - Overlay saved to: output-images-2/t13/2_overlay.png
#  - Outlines saved to: output-outlines-2/t13/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/2_filtered_seg.npy
# Processing 4 in folder t13...
# Finished processing 4 in folder t13.
#  - Overlay saved to: output-images-2/t13/4_overlay.png
#  - Outlines saved to: output-outlines-2/t13/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/4_filtered_seg.npy
# Processing 8 in folder t13...
# Finished processing 8 in folder t13.
#  - Overlay saved to: output-images-2/t13/8_overlay.png
#  - Outlines saved to: output-outlines-2/t13/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/8_filtered_seg.npy
# Processing 6 in folder t13...
# Finished processing 6 in folder t13.
#  - Overlay saved to: output-images-2/t13/6_overlay.png
#  - Outlines saved to: output-outlines-2/t13/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/6_filtered_seg.npy
# Processing 14 in folder t13...
# Finished processing 14 in folder t13.
#  - Overlay saved to: output-images-2/t13/14_overlay.png
#  - Outlines saved to: output-outlines-2/t13/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/14_filtered_seg.npy
# Processing 3 in folder t13...
# Finished processing 3 in folder t13.
#  - Overlay saved to: output-images-2/t13/3_overlay.png
#  - Outlines saved to: output-outlines-2/t13/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/3_filtered_seg.npy
# Processing 7 in folder t13...
# Finished processing 7 in folder t13.
#  - Overlay saved to: output-images-2/t13/7_overlay.png
#  - Outlines saved to: output-outlines-2/t13/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/7_filtered_seg.npy
# Processing 11 in folder t13...
# Finished processing 11 in folder t13.
#  - Overlay saved to: output-images-2/t13/11_overlay.png
#  - Outlines saved to: output-outlines-2/t13/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/11_filtered_seg.npy
# Processing 13 in folder t25...
# Finished processing 13 in folder t25.
#  - Overlay saved to: output-images-2/t25/13_overlay.png
#  - Outlines saved to: output-outlines-2/t25/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/13_filtered_seg.npy
# Processing 9 in folder t25...
# Finished processing 9 in folder t25.
#  - Overlay saved to: output-images-2/t25/9_overlay.png
#  - Outlines saved to: output-outlines-2/t25/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/9_filtered_seg.npy
# Processing 1 in folder t25...
# Finished processing 1 in folder t25.
#  - Overlay saved to: output-images-2/t25/1_overlay.png
#  - Outlines saved to: output-outlines-2/t25/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/1_filtered_seg.npy
# Processing 12 in folder t25...
# Finished processing 12 in folder t25.
#  - Overlay saved to: output-images-2/t25/12_overlay.png
#  - Outlines saved to: output-outlines-2/t25/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/12_filtered_seg.npy
# Processing 15 in folder t25...
# Finished processing 15 in folder t25.
#  - Overlay saved to: output-images-2/t25/15_overlay.png
#  - Outlines saved to: output-outlines-2/t25/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/15_filtered_seg.npy
# Processing 5 in folder t25...
# Finished processing 5 in folder t25.
#  - Overlay saved to: output-images-2/t25/5_overlay.png
#  - Outlines saved to: output-outlines-2/t25/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/5_filtered_seg.npy
# Processing 10 in folder t25...
# Finished processing 10 in folder t25.
#  - Overlay saved to: output-images-2/t25/10_overlay.png
#  - Outlines saved to: output-outlines-2/t25/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/10_filtered_seg.npy
# Processing 2 in folder t25...
# Finished processing 2 in folder t25.
#  - Overlay saved to: output-images-2/t25/2_overlay.png
#  - Outlines saved to: output-outlines-2/t25/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/2_filtered_seg.npy
# Processing 4 in folder t25...
# Finished processing 4 in folder t25.
#  - Overlay saved to: output-images-2/t25/4_overlay.png
#  - Outlines saved to: output-outlines-2/t25/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/4_filtered_seg.npy
# Processing 8 in folder t25...
# Finished processing 8 in folder t25.
#  - Overlay saved to: output-images-2/t25/8_overlay.png
#  - Outlines saved to: output-outlines-2/t25/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/8_filtered_seg.npy
# Processing 6 in folder t25...
# Finished processing 6 in folder t25.
#  - Overlay saved to: output-images-2/t25/6_overlay.png
#  - Outlines saved to: output-outlines-2/t25/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/6_filtered_seg.npy
# Processing 14 in folder t25...
# Finished processing 14 in folder t25.
#  - Overlay saved to: output-images-2/t25/14_overlay.png
#  - Outlines saved to: output-outlines-2/t25/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/14_filtered_seg.npy
# Processing 3 in folder t25...
# Finished processing 3 in folder t25.
#  - Overlay saved to: output-images-2/t25/3_overlay.png
#  - Outlines saved to: output-outlines-2/t25/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/3_filtered_seg.npy
# Processing 7 in folder t25...
# Finished processing 7 in folder t25.
#  - Overlay saved to: output-images-2/t25/7_overlay.png
#  - Outlines saved to: output-outlines-2/t25/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/7_filtered_seg.npy
# Processing 11 in folder t25...
# Finished processing 11 in folder t25.
#  - Overlay saved to: output-images-2/t25/11_overlay.png
#  - Outlines saved to: output-outlines-2/t25/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/11_filtered_seg.npy
# Processing 13 in folder t29...
# Finished processing 13 in folder t29.
#  - Overlay saved to: output-images-2/t29/13_overlay.png
#  - Outlines saved to: output-outlines-2/t29/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/13_filtered_seg.npy
# Processing 9 in folder t29...
# Finished processing 9 in folder t29.
#  - Overlay saved to: output-images-2/t29/9_overlay.png
#  - Outlines saved to: output-outlines-2/t29/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/9_filtered_seg.npy
# Processing 1 in folder t29...
# Finished processing 1 in folder t29.
#  - Overlay saved to: output-images-2/t29/1_overlay.png
#  - Outlines saved to: output-outlines-2/t29/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/1_filtered_seg.npy
# Processing 12 in folder t29...
# Finished processing 12 in folder t29.
#  - Overlay saved to: output-images-2/t29/12_overlay.png
#  - Outlines saved to: output-outlines-2/t29/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/12_filtered_seg.npy
# Processing 15 in folder t29...
# Finished processing 15 in folder t29.
#  - Overlay saved to: output-images-2/t29/15_overlay.png
#  - Outlines saved to: output-outlines-2/t29/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/15_filtered_seg.npy
# Processing 5 in folder t29...
# Finished processing 5 in folder t29.
#  - Overlay saved to: output-images-2/t29/5_overlay.png
#  - Outlines saved to: output-outlines-2/t29/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/5_filtered_seg.npy
# Processing 10 in folder t29...
# Finished processing 10 in folder t29.
#  - Overlay saved to: output-images-2/t29/10_overlay.png
#  - Outlines saved to: output-outlines-2/t29/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/10_filtered_seg.npy
# Processing 2 in folder t29...
# Finished processing 2 in folder t29.
#  - Overlay saved to: output-images-2/t29/2_overlay.png
#  - Outlines saved to: output-outlines-2/t29/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/2_filtered_seg.npy
# Processing 4 in folder t29...
# Finished processing 4 in folder t29.
#  - Overlay saved to: output-images-2/t29/4_overlay.png
#  - Outlines saved to: output-outlines-2/t29/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/4_filtered_seg.npy
# Processing 8 in folder t29...
# Finished processing 8 in folder t29.
#  - Overlay saved to: output-images-2/t29/8_overlay.png
#  - Outlines saved to: output-outlines-2/t29/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/8_filtered_seg.npy
# Processing 6 in folder t29...
# Finished processing 6 in folder t29.
#  - Overlay saved to: output-images-2/t29/6_overlay.png
#  - Outlines saved to: output-outlines-2/t29/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/6_filtered_seg.npy
# Processing 14 in folder t29...
# Finished processing 14 in folder t29.
#  - Overlay saved to: output-images-2/t29/14_overlay.png
#  - Outlines saved to: output-outlines-2/t29/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/14_filtered_seg.npy
# Processing 3 in folder t29...
# Finished processing 3 in folder t29.
#  - Overlay saved to: output-images-2/t29/3_overlay.png
#  - Outlines saved to: output-outlines-2/t29/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/3_filtered_seg.npy
# Processing 7 in folder t29...
# Finished processing 7 in folder t29.
#  - Overlay saved to: output-images-2/t29/7_overlay.png
#  - Outlines saved to: output-outlines-2/t29/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/7_filtered_seg.npy
# Processing 11 in folder t29...
# Finished processing 11 in folder t29.
#  - Overlay saved to: output-images-2/t29/11_overlay.png
#  - Outlines saved to: output-outlines-2/t29/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/11_filtered_seg.npy
# Processing 13 in folder t17...
# Finished processing 13 in folder t17.
#  - Overlay saved to: output-images-2/t17/13_overlay.png
#  - Outlines saved to: output-outlines-2/t17/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/13_filtered_seg.npy
# Processing 9 in folder t17...
# Finished processing 9 in folder t17.
#  - Overlay saved to: output-images-2/t17/9_overlay.png
#  - Outlines saved to: output-outlines-2/t17/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/9_filtered_seg.npy
# Processing 1 in folder t17...
# Finished processing 1 in folder t17.
#  - Overlay saved to: output-images-2/t17/1_overlay.png
#  - Outlines saved to: output-outlines-2/t17/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/1_filtered_seg.npy
# Processing 12 in folder t17...
# Finished processing 12 in folder t17.
#  - Overlay saved to: output-images-2/t17/12_overlay.png
#  - Outlines saved to: output-outlines-2/t17/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/12_filtered_seg.npy
# Processing 15 in folder t17...
# Finished processing 15 in folder t17.
#  - Overlay saved to: output-images-2/t17/15_overlay.png
#  - Outlines saved to: output-outlines-2/t17/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/15_filtered_seg.npy
# Processing 5 in folder t17...
# Finished processing 5 in folder t17.
#  - Overlay saved to: output-images-2/t17/5_overlay.png
#  - Outlines saved to: output-outlines-2/t17/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/5_filtered_seg.npy
# Processing 10 in folder t17...
# Finished processing 10 in folder t17.
#  - Overlay saved to: output-images-2/t17/10_overlay.png
#  - Outlines saved to: output-outlines-2/t17/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/10_filtered_seg.npy
# Processing 2 in folder t17...
# Finished processing 2 in folder t17.
#  - Overlay saved to: output-images-2/t17/2_overlay.png
#  - Outlines saved to: output-outlines-2/t17/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/2_filtered_seg.npy
# Processing 4 in folder t17...
# Finished processing 4 in folder t17.
#  - Overlay saved to: output-images-2/t17/4_overlay.png
#  - Outlines saved to: output-outlines-2/t17/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/4_filtered_seg.npy
# Processing 8 in folder t17...
# Finished processing 8 in folder t17.
#  - Overlay saved to: output-images-2/t17/8_overlay.png
#  - Outlines saved to: output-outlines-2/t17/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/8_filtered_seg.npy
# Processing 6 in folder t17...
# Finished processing 6 in folder t17.
#  - Overlay saved to: output-images-2/t17/6_overlay.png
#  - Outlines saved to: output-outlines-2/t17/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/6_filtered_seg.npy
# Processing 14 in folder t17...
# Finished processing 14 in folder t17.
#  - Overlay saved to: output-images-2/t17/14_overlay.png
#  - Outlines saved to: output-outlines-2/t17/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/14_filtered_seg.npy
# Processing 3 in folder t17...
# Finished processing 3 in folder t17.
#  - Overlay saved to: output-images-2/t17/3_overlay.png
#  - Outlines saved to: output-outlines-2/t17/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/3_filtered_seg.npy
# Processing 7 in folder t17...
# Finished processing 7 in folder t17.
#  - Overlay saved to: output-images-2/t17/7_overlay.png
#  - Outlines saved to: output-outlines-2/t17/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/7_filtered_seg.npy
# Processing 11 in folder t17...
# Finished processing 11 in folder t17.
#  - Overlay saved to: output-images-2/t17/11_overlay.png
#  - Outlines saved to: output-outlines-2/t17/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/11_filtered_seg.npy
# Processing 13 in folder t3...
# Finished processing 13 in folder t3.
#  - Overlay saved to: output-images-2/t3/13_overlay.png
#  - Outlines saved to: output-outlines-2/t3/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/13_filtered_seg.npy
# Processing 9 in folder t3...
# Finished processing 9 in folder t3.
#  - Overlay saved to: output-images-2/t3/9_overlay.png
#  - Outlines saved to: output-outlines-2/t3/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/9_filtered_seg.npy
# Processing 1 in folder t3...
# Finished processing 1 in folder t3.
#  - Overlay saved to: output-images-2/t3/1_overlay.png
#  - Outlines saved to: output-outlines-2/t3/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/1_filtered_seg.npy
# Processing 12 in folder t3...
# Finished processing 12 in folder t3.
#  - Overlay saved to: output-images-2/t3/12_overlay.png
#  - Outlines saved to: output-outlines-2/t3/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/12_filtered_seg.npy
# Processing 15 in folder t3...
# Finished processing 15 in folder t3.
#  - Overlay saved to: output-images-2/t3/15_overlay.png
#  - Outlines saved to: output-outlines-2/t3/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/15_filtered_seg.npy
# Processing 5 in folder t3...
# Finished processing 5 in folder t3.
#  - Overlay saved to: output-images-2/t3/5_overlay.png
#  - Outlines saved to: output-outlines-2/t3/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/5_filtered_seg.npy
# Processing 10 in folder t3...
# Finished processing 10 in folder t3.
#  - Overlay saved to: output-images-2/t3/10_overlay.png
#  - Outlines saved to: output-outlines-2/t3/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/10_filtered_seg.npy
# Processing 2 in folder t3...
# Finished processing 2 in folder t3.
#  - Overlay saved to: output-images-2/t3/2_overlay.png
#  - Outlines saved to: output-outlines-2/t3/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/2_filtered_seg.npy
# Processing 4 in folder t3...
# Finished processing 4 in folder t3.
#  - Overlay saved to: output-images-2/t3/4_overlay.png
#  - Outlines saved to: output-outlines-2/t3/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/4_filtered_seg.npy
# Processing 8 in folder t3...
# Finished processing 8 in folder t3.
#  - Overlay saved to: output-images-2/t3/8_overlay.png
#  - Outlines saved to: output-outlines-2/t3/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/8_filtered_seg.npy
# Processing 6 in folder t3...
# Finished processing 6 in folder t3.
#  - Overlay saved to: output-images-2/t3/6_overlay.png
#  - Outlines saved to: output-outlines-2/t3/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/6_filtered_seg.npy
# Processing 14 in folder t3...
# Finished processing 14 in folder t3.
#  - Overlay saved to: output-images-2/t3/14_overlay.png
#  - Outlines saved to: output-outlines-2/t3/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/14_filtered_seg.npy
# Processing 3 in folder t3...
# Finished processing 3 in folder t3.
#  - Overlay saved to: output-images-2/t3/3_overlay.png
#  - Outlines saved to: output-outlines-2/t3/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/3_filtered_seg.npy
# ...
#  - Outlines saved to: output-outlines-2/t41/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/6_filtered_seg.npy
# Processing 14 in folder t41...
# Finished processing 14 in folder t41.
#  - Overlay saved to: output-images-2/t41/14_overlay.png
#  - Outlines saved to: output-outlines-2/t41/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/14_filtered_seg.npy
# Processing 3 in folder t41...
# Finished processing 3 in folder t41.
#  - Overlay saved to: output-images-2/t41/3_overlay.png
#  - Outlines saved to: output-outlines-2/t41/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/3_filtered_seg.npy
# Processing 7 in folder t41...
# Finished processing 7 in folder t41.
#  - Overlay saved to: output-images-2/t41/7_overlay.png
#  - Outlines saved to: output-outlines-2/t41/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/7_filtered_seg.npy
# Processing 11 in folder t41...
# Finished processing 11 in folder t41.
#  - Overlay saved to: output-images-2/t41/11_overlay.png
#  - Outlines saved to: output-outlines-2/t41/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/11_filtered_seg.npy
# Processing 13 in folder t40...
# Finished processing 13 in folder t40.
#  - Overlay saved to: output-images-2/t40/13_overlay.png
#  - Outlines saved to: output-outlines-2/t40/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/13_filtered_seg.npy
# Processing 9 in folder t40...
# Finished processing 9 in folder t40.
#  - Overlay saved to: output-images-2/t40/9_overlay.png
#  - Outlines saved to: output-outlines-2/t40/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/9_filtered_seg.npy
# Processing 1 in folder t40...
# Finished processing 1 in folder t40.
#  - Overlay saved to: output-images-2/t40/1_overlay.png
#  - Outlines saved to: output-outlines-2/t40/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/1_filtered_seg.npy
# Processing 12 in folder t40...
# Finished processing 12 in folder t40.
#  - Overlay saved to: output-images-2/t40/12_overlay.png
#  - Outlines saved to: output-outlines-2/t40/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/12_filtered_seg.npy
# Processing 15 in folder t40...
# Finished processing 15 in folder t40.
#  - Overlay saved to: output-images-2/t40/15_overlay.png
#  - Outlines saved to: output-outlines-2/t40/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/15_filtered_seg.npy
# Processing 5 in folder t40...
# Finished processing 5 in folder t40.
#  - Overlay saved to: output-images-2/t40/5_overlay.png
#  - Outlines saved to: output-outlines-2/t40/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/5_filtered_seg.npy
# Processing 10 in folder t40...
# Finished processing 10 in folder t40.
#  - Overlay saved to: output-images-2/t40/10_overlay.png
#  - Outlines saved to: output-outlines-2/t40/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/10_filtered_seg.npy
# Processing 2 in folder t40...
# Finished processing 2 in folder t40.
#  - Overlay saved to: output-images-2/t40/2_overlay.png
#  - Outlines saved to: output-outlines-2/t40/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/2_filtered_seg.npy
# Processing 4 in folder t40...
# Finished processing 4 in folder t40.
#  - Overlay saved to: output-images-2/t40/4_overlay.png
#  - Outlines saved to: output-outlines-2/t40/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/4_filtered_seg.npy
# Processing 8 in folder t40...
# Finished processing 8 in folder t40.
#  - Overlay saved to: output-images-2/t40/8_overlay.png
#  - Outlines saved to: output-outlines-2/t40/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/8_filtered_seg.npy
# Processing 6 in folder t40...
# Finished processing 6 in folder t40.
#  - Overlay saved to: output-images-2/t40/6_overlay.png
#  - Outlines saved to: output-outlines-2/t40/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/6_filtered_seg.npy
# Processing 14 in folder t40...
# Finished processing 14 in folder t40.
#  - Overlay saved to: output-images-2/t40/14_overlay.png
#  - Outlines saved to: output-outlines-2/t40/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/14_filtered_seg.npy
# Processing 3 in folder t40...
# Finished processing 3 in folder t40.
#  - Overlay saved to: output-images-2/t40/3_overlay.png
#  - Outlines saved to: output-outlines-2/t40/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/3_filtered_seg.npy
# Processing 7 in folder t40...
# Finished processing 7 in folder t40.
#  - Overlay saved to: output-images-2/t40/7_overlay.png
#  - Outlines saved to: output-outlines-2/t40/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/7_filtered_seg.npy
# Processing 11 in folder t40...
# Finished processing 11 in folder t40.
#  - Overlay saved to: output-images-2/t40/11_overlay.png
#  - Outlines saved to: output-outlines-2/t40/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/11_filtered_seg.npy
# Processing 13 in folder t31...
# Finished processing 13 in folder t31.
#  - Overlay saved to: output-images-2/t31/13_overlay.png
#  - Outlines saved to: output-outlines-2/t31/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/13_filtered_seg.npy
# Processing 9 in folder t31...
# Finished processing 9 in folder t31.
#  - Overlay saved to: output-images-2/t31/9_overlay.png
#  - Outlines saved to: output-outlines-2/t31/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/9_filtered_seg.npy
# Processing 1 in folder t31...
# Finished processing 1 in folder t31.
#  - Overlay saved to: output-images-2/t31/1_overlay.png
#  - Outlines saved to: output-outlines-2/t31/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/1_filtered_seg.npy
# Processing 12 in folder t31...
# Finished processing 12 in folder t31.
#  - Overlay saved to: output-images-2/t31/12_overlay.png
#  - Outlines saved to: output-outlines-2/t31/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/12_filtered_seg.npy
# Processing 15 in folder t31...
# Finished processing 15 in folder t31.
#  - Overlay saved to: output-images-2/t31/15_overlay.png
#  - Outlines saved to: output-outlines-2/t31/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/15_filtered_seg.npy
# Processing 5 in folder t31...
# Finished processing 5 in folder t31.
#  - Overlay saved to: output-images-2/t31/5_overlay.png
#  - Outlines saved to: output-outlines-2/t31/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/5_filtered_seg.npy
# Processing 10 in folder t31...
# Finished processing 10 in folder t31.
#  - Overlay saved to: output-images-2/t31/10_overlay.png
#  - Outlines saved to: output-outlines-2/t31/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/10_filtered_seg.npy
# Processing 2 in folder t31...
# Finished processing 2 in folder t31.
#  - Overlay saved to: output-images-2/t31/2_overlay.png
#  - Outlines saved to: output-outlines-2/t31/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/2_filtered_seg.npy
# Processing 4 in folder t31...
# Finished processing 4 in folder t31.
#  - Overlay saved to: output-images-2/t31/4_overlay.png
#  - Outlines saved to: output-outlines-2/t31/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/4_filtered_seg.npy
# Processing 8 in folder t31...
# Finished processing 8 in folder t31.
#  - Overlay saved to: output-images-2/t31/8_overlay.png
#  - Outlines saved to: output-outlines-2/t31/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/8_filtered_seg.npy
# Processing 6 in folder t31...
# Finished processing 6 in folder t31.
#  - Overlay saved to: output-images-2/t31/6_overlay.png
#  - Outlines saved to: output-outlines-2/t31/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/6_filtered_seg.npy
# Processing 14 in folder t31...
# Finished processing 14 in folder t31.
#  - Overlay saved to: output-images-2/t31/14_overlay.png
#  - Outlines saved to: output-outlines-2/t31/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/14_filtered_seg.npy
# Processing 3 in folder t31...
# Finished processing 3 in folder t31.
#  - Overlay saved to: output-images-2/t31/3_overlay.png
#  - Outlines saved to: output-outlines-2/t31/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/3_filtered_seg.npy
# Processing 7 in folder t31...
# Finished processing 7 in folder t31.
#  - Overlay saved to: output-images-2/t31/7_overlay.png
#  - Outlines saved to: output-outlines-2/t31/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/7_filtered_seg.npy
# Processing 11 in folder t31...
# Finished processing 11 in folder t31.
#  - Overlay saved to: output-images-2/t31/11_overlay.png
#  - Outlines saved to: output-outlines-2/t31/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/11_filtered_seg.npy
# Processing 13 in folder t37...
# Finished processing 13 in folder t37.
#  - Overlay saved to: output-images-2/t37/13_overlay.png
#  - Outlines saved to: output-outlines-2/t37/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/13_filtered_seg.npy
# Processing 9 in folder t37...
# Finished processing 9 in folder t37.
#  - Overlay saved to: output-images-2/t37/9_overlay.png
#  - Outlines saved to: output-outlines-2/t37/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/9_filtered_seg.npy
# Processing 1 in folder t37...
# Finished processing 1 in folder t37.
#  - Overlay saved to: output-images-2/t37/1_overlay.png
#  - Outlines saved to: output-outlines-2/t37/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/1_filtered_seg.npy
# Processing 12 in folder t37...
# Finished processing 12 in folder t37.
#  - Overlay saved to: output-images-2/t37/12_overlay.png
#  - Outlines saved to: output-outlines-2/t37/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/12_filtered_seg.npy
# Processing 15 in folder t37...
# Finished processing 15 in folder t37.
#  - Overlay saved to: output-images-2/t37/15_overlay.png
#  - Outlines saved to: output-outlines-2/t37/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/15_filtered_seg.npy
# Processing 5 in folder t37...
# Finished processing 5 in folder t37.
#  - Overlay saved to: output-images-2/t37/5_overlay.png
#  - Outlines saved to: output-outlines-2/t37/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/5_filtered_seg.npy
# Processing 10 in folder t37...
# Finished processing 10 in folder t37.
#  - Overlay saved to: output-images-2/t37/10_overlay.png
#  - Outlines saved to: output-outlines-2/t37/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/10_filtered_seg.npy
# Processing 2 in folder t37...
# Finished processing 2 in folder t37.
#  - Overlay saved to: output-images-2/t37/2_overlay.png
#  - Outlines saved to: output-outlines-2/t37/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/2_filtered_seg.npy
# Processing 4 in folder t37...
# Finished processing 4 in folder t37.
#  - Overlay saved to: output-images-2/t37/4_overlay.png
#  - Outlines saved to: output-outlines-2/t37/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/4_filtered_seg.npy
# Processing 8 in folder t37...
# Finished processing 8 in folder t37.
#  - Overlay saved to: output-images-2/t37/8_overlay.png
#  - Outlines saved to: output-outlines-2/t37/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/8_filtered_seg.npy
# Processing 6 in folder t37...
# Finished processing 6 in folder t37.
#  - Overlay saved to: output-images-2/t37/6_overlay.png
#  - Outlines saved to: output-outlines-2/t37/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/6_filtered_seg.npy
# Processing 14 in folder t37...
# Finished processing 14 in folder t37.
#  - Overlay saved to: output-images-2/t37/14_overlay.png
#  - Outlines saved to: output-outlines-2/t37/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/14_filtered_seg.npy
# Processing 3 in folder t37...
# Finished processing 3 in folder t37.
#  - Overlay saved to: output-images-2/t37/3_overlay.png
#  - Outlines saved to: output-outlines-2/t37/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/3_filtered_seg.npy
# Processing 7 in folder t37...
# Finished processing 7 in folder t37.
#  - Overlay saved to: output-images-2/t37/7_overlay.png
#  - Outlines saved to: output-outlines-2/t37/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/7_filtered_seg.npy
# Processing 11 in folder t37...
# Finished processing 11 in folder t37.
#  - Overlay saved to: output-images-2/t37/11_overlay.png
#  - Outlines saved to: output-outlines-2/t37/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/11_filtered_seg.npy
# Processing 13 in folder t9...
# Finished processing 13 in folder t9.
#  - Overlay saved to: output-images-2/t9/13_overlay.png
#  - Outlines saved to: output-outlines-2/t9/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/13_filtered_seg.npy
# Processing 9 in folder t9...
# Finished processing 9 in folder t9.
#  - Overlay saved to: output-images-2/t9/9_overlay.png
#  - Outlines saved to: output-outlines-2/t9/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/9_filtered_seg.npy
# Processing 1 in folder t9...
# Finished processing 1 in folder t9.
#  - Overlay saved to: output-images-2/t9/1_overlay.png
#  - Outlines saved to: output-outlines-2/t9/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/1_filtered_seg.npy
# Processing 12 in folder t9...
# Finished processing 12 in folder t9.
#  - Overlay saved to: output-images-2/t9/12_overlay.png
#  - Outlines saved to: output-outlines-2/t9/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/12_filtered_seg.npy
# Processing 15 in folder t9...
# Finished processing 15 in folder t9.
#  - Overlay saved to: output-images-2/t9/15_overlay.png
#  - Outlines saved to: output-outlines-2/t9/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/15_filtered_seg.npy
# Processing 5 in folder t9...
# Finished processing 5 in folder t9.
#  - Overlay saved to: output-images-2/t9/5_overlay.png
#  - Outlines saved to: output-outlines-2/t9/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/5_filtered_seg.npy
# Processing 10 in folder t9...
# Finished processing 10 in folder t9.
#  - Overlay saved to: output-images-2/t9/10_overlay.png
#  - Outlines saved to: output-outlines-2/t9/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/10_filtered_seg.npy
# Processing 2 in folder t9...
# Finished processing 2 in folder t9.
#  - Overlay saved to: output-images-2/t9/2_overlay.png
#  - Outlines saved to: output-outlines-2/t9/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/2_filtered_seg.npy
# Processing 4 in folder t9...
# Finished processing 4 in folder t9.
#  - Overlay saved to: output-images-2/t9/4_overlay.png
#  - Outlines saved to: output-outlines-2/t9/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/4_filtered_seg.npy
# Processing 8 in folder t9...
# Finished processing 8 in folder t9.
#  - Overlay saved to: output-images-2/t9/8_overlay.png
#  - Outlines saved to: output-outlines-2/t9/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/8_filtered_seg.npy
# Processing 6 in folder t9...
# Finished processing 6 in folder t9.
#  - Overlay saved to: output-images-2/t9/6_overlay.png
#  - Outlines saved to: output-outlines-2/t9/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/6_filtered_seg.npy
# Processing 14 in folder t9...
# Finished processing 14 in folder t9.
#  - Overlay saved to: output-images-2/t9/14_overlay.png
#  - Outlines saved to: output-outlines-2/t9/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/14_filtered_seg.npy
# Processing 3 in folder t9...
# Finished processing 3 in folder t9.
#  - Overlay saved to: output-images-2/t9/3_overlay.png
#  - Outlines saved to: output-outlines-2/t9/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/3_filtered_seg.npy
# Processing 7 in folder t9...
# Finished processing 7 in folder t9.
#  - Overlay saved to: output-images-2/t9/7_overlay.png
#  - Outlines saved to: output-outlines-2/t9/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/7_filtered_seg.npy
# Processing 11 in folder t9...
# Finished processing 11 in folder t9.
#  - Overlay saved to: output-images-2/t9/11_overlay.png
#  - Outlines saved to: output-outlines-2/t9/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/11_filtered_seg.npy

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import os

# Path to your filtered segmentation file
file_path = "output-masks-2/t1/7_filtered_seg.npy"

# Load the numpy file 
data = np.load(file_path, allow_pickle=True).item()

# Print what's inside the dictionary
print("Keys in the NPY file:", data.keys())

# Display the masks with a random colormap for better visualization
masks = data['masks']
print(f"Mask shape: {masks.shape}")
print(f"Number of unique cell IDs: {len(np.unique(masks)) - 1}")  # -1 to exclude background (0)

# Create a custom colormap for better visualization
# Make a random colormap with a black background (for ID=0)
n_labels = len(np.unique(masks))
cmap = plt.cm.get_cmap('jet')
# Create a colormap that has a black color for label 0 and random colors for others
colors_list = cmap(np.arange(n_labels))
colors_list[0] = [0, 0, 0, 1]  # black for background
custom_cmap = colors.ListedColormap(colors_list)

# Create the visualization
plt.figure(figsize=(12, 10))
plt.imshow(masks, cmap=custom_cmap)
plt.colorbar(ticks=np.unique(masks), label='Cell ID')
plt.title('Filtered Cell Segmentation Masks')
plt.axis('off')
plt.savefig(os.path.splitext(file_path)[0] + "_visualization.png", dpi=300, bbox_inches='tight')
plt.show()

# Optional: If you have the original image and want to create an overlay
# (assuming you have the original image in the same directory)
try:
    from cellpose import io
    original_img_path = file_path.replace('_filtered_seg.npy', '.tif')
    if os.path.exists(original_img_path):
        img = io.imread(original_img_path)
        
        # Create an overlay visualization
        plt.figure(figsize=(12, 10))
        plt.imshow(img)
        
        # Create a mask for overlay visualization
        mask_boundaries = np.zeros_like(masks, dtype=bool)
        for i in range(1, np.max(masks)+1):
            if i in np.unique(masks):
                cell = masks == i
                eroded = binary_erosion(cell, iterations=1)
                mask_boundaries[cell & ~eroded] = True
        
        masked_overlay = np.ma.masked_where(~mask_boundaries, mask_boundaries)
        plt.imshow(masked_overlay, cmap='spring', alpha=0.8)
        plt.title('Original Image with Cell Boundaries')
        plt.axis('off')
        plt.savefig(os.path.splitext(file_path)[0] + "_overlay.png", dpi=300, bbox_inches='tight')
        plt.show()
except:
    print("Could not create overlay. Make sure original image exists and cellpose is installed.")
# Out:
# Keys in the NPY file: dict_keys(['masks', 'flows', 'styles', 'diams'])
# Mask shape: (512, 512)
# Number of unique cell IDs: 2
# /tmp/ipykernel_15853/233889890.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('jet')

# %%
import os
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
from cellpose import io, utils
import shutil

# -------------------------------
# Configuration and Setup
# -------------------------------
base_input_folder = 'A1-raw-data-2'  # Base folder containing subfolders with images and segmentation files
output_folder_images = 'output-images-2'       # For saving overlay images
output_folder_outlines = 'output-outlines-2'    # For saving cell outlines
output_folder_masks = 'output-masks-2'          # For saving filtered mask files

# Create output directories if they don't exist
os.makedirs(output_folder_images, exist_ok=True)
os.makedirs(output_folder_outlines, exist_ok=True)
os.makedirs(output_folder_masks, exist_ok=True)

# Recursively find all segmentation files (assumed to end with '_seg.npy')
segmentation_files = glob.glob(os.path.join(base_input_folder, '**', '*_seg.npy'), recursive=True)

# Define HSV thresholds and green pixel ratio threshold
lower_green = np.array([40, 45, 45])
upper_green = np.array([80, 255, 255])
green_pixel_ratio_threshold = 0.50  # 50% or more pixels must be green

# -------------------------------
# Process each file pair in the folder tree
# -------------------------------
for seg_file in segmentation_files:
    # Determine the base name (e.g., "image_seg.npy" -> "image")
    base_name = os.path.basename(seg_file).replace('_seg.npy', '')
    
    # The corresponding image is assumed to be in the same folder with a .tif extension
    img_file = os.path.join(os.path.dirname(seg_file), base_name + '.tif')
    
    # Check if the corresponding image file exists
    if not os.path.exists(img_file):
        print(f"Image file {img_file} not found for segmentation file {seg_file}. Skipping.")
        continue

    # Determine subfolder relative to the base_input_folder for output organization
    subfolder = os.path.relpath(os.path.dirname(seg_file), base_input_folder)
    out_img_folder = os.path.join(output_folder_images, subfolder)
    out_outline_folder = os.path.join(output_folder_outlines, subfolder)
    out_mask_folder = os.path.join(output_folder_masks, subfolder)
    os.makedirs(out_img_folder, exist_ok=True)
    os.makedirs(out_outline_folder, exist_ok=True)
    os.makedirs(out_mask_folder, exist_ok=True)
    
    print(f"Processing {base_name} in folder {subfolder}...")

    # -------------------------------
    # Part 1: Load data and build the mask dictionary
    # -------------------------------
    # First, create a copy of the original file to preserve all metadata and format
    output_mask_file = os.path.join(out_mask_folder, base_name + '_filtered_seg.npy')
    shutil.copy2(seg_file, output_mask_file)
    
    # Now load the original data
    dat = np.load(seg_file, allow_pickle=True).item()
    img = io.imread(img_file)

    # Ensure the image is in RGB (if grayscale, convert it)
    if img.ndim == 2 or (img.ndim == 3 and img.shape[2] == 1):
        img = np.stack([img.squeeze()] * 3, axis=-1)

    masks = dat['masks']

    # Create a dictionary: key -> tuple of (y,x) coordinates for the mask pixels,
    # value -> average RGB value (for visualization if desired)
    mask_dict = {}
    labels = np.unique(masks)
    for label in labels:
        if label == 0:  # Skip background
            continue
        cell_mask = masks == label
        coords = np.argwhere(cell_mask)
        coords_tuple = tuple(map(tuple, coords))
        avg_rgb = np.mean(img[cell_mask], axis=0)
        mask_dict[coords_tuple] = avg_rgb

    # -------------------------------
    # Part 2: Filter cells using HSV thresholds
    # -------------------------------
    # Convert the image from RGB to HSV
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    # Create a binary mask for green regions
    hsv_green_mask = cv2.inRange(hsv, lower_green, upper_green)

    filtered_dict = {}
    filtered_labels = []  # Keep track of which cell labels pass the filter
    
    for coords, avg_rgb in mask_dict.items():
        coords_array = np.array(coords)  # shape (N, 2)
        # Extract the green mask values for the cell's pixels
        green_vals = hsv_green_mask[coords_array[:, 0], coords_array[:, 1]]
        ratio_green = np.sum(green_vals == 255) / len(green_vals)
        
        # Find the original label for this cell
        y, x = coords_array[0]  # Get coordinates of first pixel
        label = masks[y, x]
        
        if ratio_green >= green_pixel_ratio_threshold:
            filtered_dict[coords] = avg_rgb
            filtered_labels.append(label)

    # -------------------------------
    # Part 3: Create an overlay mask and save the overlay image
    # -------------------------------
    overlay_mask = np.zeros(masks.shape, dtype=bool)
    for coords in filtered_dict.keys():
        for (y, x) in coords:
            overlay_mask[y, x] = True

    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    masked_overlay = np.ma.masked_where(~overlay_mask, overlay_mask)
    plt.imshow(masked_overlay, cmap='Reds', alpha=0.5)
    plt.title(f'Cells with ≥ {int(green_pixel_ratio_threshold*100)}% Green Pixels')
    plt.axis('off')

    # Save the overlay image to the output folder (preserving subfolder structure)
    output_overlay_file = os.path.join(out_img_folder, base_name + '_overlay.png')
    plt.savefig(output_overlay_file, bbox_inches='tight')
    plt.close()

    # -------------------------------
    # Part 4: Extract cell outlines and write to file
    # -------------------------------
    outline_file = os.path.join(out_outline_folder, base_name + '_outlines.txt')
    with open(outline_file, "w") as f:
        for coords in filtered_dict.keys():
            # Create a binary image for this cell mask
            cell_mask_img = np.zeros(masks.shape, dtype=np.uint8)
            coords_np = np.array(coords)
            cell_mask_img[coords_np[:, 0], coords_np[:, 1]] = 255

            # Find contours; using RETR_EXTERNAL to get only the outer boundary
            contours, _ = cv2.findContours(cell_mask_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            if len(contours) == 0:
                continue

            # Choose the largest contour (in case there are multiple)
            largest_contour = max(contours, key=cv2.contourArea)
            largest_contour = largest_contour.squeeze()
            # Ensure the contour is 2D (in case it's only a single point)
            if largest_contour.ndim == 1:
                largest_contour = np.expand_dims(largest_contour, axis=0)

            # Format the contour as "x,y,x,y,..." (note: OpenCV contours are in (x,y) order)
            coord_pairs = [f"{pt[0]},{pt[1]}" for pt in largest_contour]
            outline_str = ",".join(coord_pairs)
            f.write(outline_str + "\n")
    
    # -------------------------------
    # Part 5: Create and save filtered masks file in Cellpose-compatible format
    # -------------------------------
    # Create a new masks array with only the filtered cells
    filtered_masks = np.zeros_like(masks)
    for label in filtered_labels:
        filtered_masks[masks == label] = label
    
    # Load the copied original file, modify it, and save it back
    # This preserves the exact format that Cellpose command-line creates
    filtered_dat = np.load(output_mask_file, allow_pickle=True).item()
    filtered_dat['masks'] = filtered_masks
    
    # Recalculate outlines using Cellpose's built-in function
    if 'outlines' in filtered_dat:
        # Try to use Cellpose's own function to generate outlines to ensure compatibility
        try:
            filtered_dat['outlines'] = utils.outlines_list(filtered_masks)
        except:
            # If that fails, keep the original outlines
            pass
    
    # Save in the exact format Cellpose expects
    np.save(output_mask_file, filtered_dat)

    # Create a backup copy in case we need the original version
    backup_file = os.path.join(out_mask_folder, base_name + '_filtered_backup_seg.npy')
    with open(output_mask_file, 'rb') as f_in, open(backup_file, 'wb') as f_out:
        f_out.write(f_in.read())

    print(f"Finished processing {base_name} in folder {subfolder}.")
    print(f" - Overlay saved to: {output_overlay_file}")
    print(f" - Outlines saved to: {outline_file}")
    print(f" - Filtered masks saved to: {output_mask_file}")
# Out:
# Processing 13 in folder t16...
# Finished processing 13 in folder t16.
#  - Overlay saved to: output-images-2/t16/13_overlay.png
#  - Outlines saved to: output-outlines-2/t16/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/13_filtered_seg.npy
# Processing 9 in folder t16...
# Finished processing 9 in folder t16.
#  - Overlay saved to: output-images-2/t16/9_overlay.png
#  - Outlines saved to: output-outlines-2/t16/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/9_filtered_seg.npy
# Processing 1 in folder t16...
# Finished processing 1 in folder t16.
#  - Overlay saved to: output-images-2/t16/1_overlay.png
#  - Outlines saved to: output-outlines-2/t16/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/1_filtered_seg.npy
# Processing 12 in folder t16...
# Finished processing 12 in folder t16.
#  - Overlay saved to: output-images-2/t16/12_overlay.png
#  - Outlines saved to: output-outlines-2/t16/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/12_filtered_seg.npy
# Processing 15 in folder t16...
# Finished processing 15 in folder t16.
#  - Overlay saved to: output-images-2/t16/15_overlay.png
#  - Outlines saved to: output-outlines-2/t16/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/15_filtered_seg.npy
# Processing 5 in folder t16...
# Finished processing 5 in folder t16.
#  - Overlay saved to: output-images-2/t16/5_overlay.png
#  - Outlines saved to: output-outlines-2/t16/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/5_filtered_seg.npy
# Processing 10 in folder t16...
# Finished processing 10 in folder t16.
#  - Overlay saved to: output-images-2/t16/10_overlay.png
#  - Outlines saved to: output-outlines-2/t16/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/10_filtered_seg.npy
# Processing 2 in folder t16...
# Finished processing 2 in folder t16.
#  - Overlay saved to: output-images-2/t16/2_overlay.png
#  - Outlines saved to: output-outlines-2/t16/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/2_filtered_seg.npy
# Processing 4 in folder t16...
# Finished processing 4 in folder t16.
#  - Overlay saved to: output-images-2/t16/4_overlay.png
#  - Outlines saved to: output-outlines-2/t16/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/4_filtered_seg.npy
# Processing 8 in folder t16...
# Finished processing 8 in folder t16.
#  - Overlay saved to: output-images-2/t16/8_overlay.png
#  - Outlines saved to: output-outlines-2/t16/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/8_filtered_seg.npy
# Processing 6 in folder t16...
# Finished processing 6 in folder t16.
#  - Overlay saved to: output-images-2/t16/6_overlay.png
#  - Outlines saved to: output-outlines-2/t16/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/6_filtered_seg.npy
# Processing 14 in folder t16...
# Finished processing 14 in folder t16.
#  - Overlay saved to: output-images-2/t16/14_overlay.png
#  - Outlines saved to: output-outlines-2/t16/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/14_filtered_seg.npy
# Processing 3 in folder t16...
# Finished processing 3 in folder t16.
#  - Overlay saved to: output-images-2/t16/3_overlay.png
#  - Outlines saved to: output-outlines-2/t16/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/3_filtered_seg.npy
# Processing 7 in folder t16...
# Finished processing 7 in folder t16.
#  - Overlay saved to: output-images-2/t16/7_overlay.png
#  - Outlines saved to: output-outlines-2/t16/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/7_filtered_seg.npy
# Processing 11 in folder t16...
# Finished processing 11 in folder t16.
#  - Overlay saved to: output-images-2/t16/11_overlay.png
#  - Outlines saved to: output-outlines-2/t16/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t16/11_filtered_seg.npy
# Processing 13 in folder t34...
# Finished processing 13 in folder t34.
#  - Overlay saved to: output-images-2/t34/13_overlay.png
#  - Outlines saved to: output-outlines-2/t34/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/13_filtered_seg.npy
# Processing 9 in folder t34...
# Finished processing 9 in folder t34.
#  - Overlay saved to: output-images-2/t34/9_overlay.png
#  - Outlines saved to: output-outlines-2/t34/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/9_filtered_seg.npy
# Processing 1 in folder t34...
# Finished processing 1 in folder t34.
#  - Overlay saved to: output-images-2/t34/1_overlay.png
#  - Outlines saved to: output-outlines-2/t34/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/1_filtered_seg.npy
# Processing 12 in folder t34...
# Finished processing 12 in folder t34.
#  - Overlay saved to: output-images-2/t34/12_overlay.png
#  - Outlines saved to: output-outlines-2/t34/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/12_filtered_seg.npy
# Processing 15 in folder t34...
# Finished processing 15 in folder t34.
#  - Overlay saved to: output-images-2/t34/15_overlay.png
#  - Outlines saved to: output-outlines-2/t34/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/15_filtered_seg.npy
# Processing 5 in folder t34...
# Finished processing 5 in folder t34.
#  - Overlay saved to: output-images-2/t34/5_overlay.png
#  - Outlines saved to: output-outlines-2/t34/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/5_filtered_seg.npy
# Processing 10 in folder t34...
# Finished processing 10 in folder t34.
#  - Overlay saved to: output-images-2/t34/10_overlay.png
#  - Outlines saved to: output-outlines-2/t34/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/10_filtered_seg.npy
# Processing 2 in folder t34...
# Finished processing 2 in folder t34.
#  - Overlay saved to: output-images-2/t34/2_overlay.png
#  - Outlines saved to: output-outlines-2/t34/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/2_filtered_seg.npy
# Processing 4 in folder t34...
# Finished processing 4 in folder t34.
#  - Overlay saved to: output-images-2/t34/4_overlay.png
#  - Outlines saved to: output-outlines-2/t34/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/4_filtered_seg.npy
# Processing 8 in folder t34...
# Finished processing 8 in folder t34.
#  - Overlay saved to: output-images-2/t34/8_overlay.png
#  - Outlines saved to: output-outlines-2/t34/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/8_filtered_seg.npy
# Processing 6 in folder t34...
# Finished processing 6 in folder t34.
#  - Overlay saved to: output-images-2/t34/6_overlay.png
#  - Outlines saved to: output-outlines-2/t34/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/6_filtered_seg.npy
# Processing 14 in folder t34...
# Finished processing 14 in folder t34.
#  - Overlay saved to: output-images-2/t34/14_overlay.png
#  - Outlines saved to: output-outlines-2/t34/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/14_filtered_seg.npy
# Processing 3 in folder t34...
# Finished processing 3 in folder t34.
#  - Overlay saved to: output-images-2/t34/3_overlay.png
#  - Outlines saved to: output-outlines-2/t34/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/3_filtered_seg.npy
# Processing 7 in folder t34...
# Finished processing 7 in folder t34.
#  - Overlay saved to: output-images-2/t34/7_overlay.png
#  - Outlines saved to: output-outlines-2/t34/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/7_filtered_seg.npy
# Processing 11 in folder t34...
# Finished processing 11 in folder t34.
#  - Overlay saved to: output-images-2/t34/11_overlay.png
#  - Outlines saved to: output-outlines-2/t34/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t34/11_filtered_seg.npy
# Processing 13 in folder t22...
# Finished processing 13 in folder t22.
#  - Overlay saved to: output-images-2/t22/13_overlay.png
#  - Outlines saved to: output-outlines-2/t22/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/13_filtered_seg.npy
# Processing 9 in folder t22...
# Finished processing 9 in folder t22.
#  - Overlay saved to: output-images-2/t22/9_overlay.png
#  - Outlines saved to: output-outlines-2/t22/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/9_filtered_seg.npy
# Processing 1 in folder t22...
# Finished processing 1 in folder t22.
#  - Overlay saved to: output-images-2/t22/1_overlay.png
#  - Outlines saved to: output-outlines-2/t22/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/1_filtered_seg.npy
# Processing 12 in folder t22...
# Finished processing 12 in folder t22.
#  - Overlay saved to: output-images-2/t22/12_overlay.png
#  - Outlines saved to: output-outlines-2/t22/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/12_filtered_seg.npy
# Processing 15 in folder t22...
# Finished processing 15 in folder t22.
#  - Overlay saved to: output-images-2/t22/15_overlay.png
#  - Outlines saved to: output-outlines-2/t22/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/15_filtered_seg.npy
# Processing 5 in folder t22...
# Finished processing 5 in folder t22.
#  - Overlay saved to: output-images-2/t22/5_overlay.png
#  - Outlines saved to: output-outlines-2/t22/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/5_filtered_seg.npy
# Processing 10 in folder t22...
# Finished processing 10 in folder t22.
#  - Overlay saved to: output-images-2/t22/10_overlay.png
#  - Outlines saved to: output-outlines-2/t22/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/10_filtered_seg.npy
# Processing 2 in folder t22...
# Finished processing 2 in folder t22.
#  - Overlay saved to: output-images-2/t22/2_overlay.png
#  - Outlines saved to: output-outlines-2/t22/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/2_filtered_seg.npy
# Processing 4 in folder t22...
# Finished processing 4 in folder t22.
#  - Overlay saved to: output-images-2/t22/4_overlay.png
#  - Outlines saved to: output-outlines-2/t22/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/4_filtered_seg.npy
# Processing 8 in folder t22...
# Finished processing 8 in folder t22.
#  - Overlay saved to: output-images-2/t22/8_overlay.png
#  - Outlines saved to: output-outlines-2/t22/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/8_filtered_seg.npy
# Processing 6 in folder t22...
# Finished processing 6 in folder t22.
#  - Overlay saved to: output-images-2/t22/6_overlay.png
#  - Outlines saved to: output-outlines-2/t22/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/6_filtered_seg.npy
# Processing 14 in folder t22...
# Finished processing 14 in folder t22.
#  - Overlay saved to: output-images-2/t22/14_overlay.png
#  - Outlines saved to: output-outlines-2/t22/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/14_filtered_seg.npy
# Processing 3 in folder t22...
# Finished processing 3 in folder t22.
#  - Overlay saved to: output-images-2/t22/3_overlay.png
#  - Outlines saved to: output-outlines-2/t22/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/3_filtered_seg.npy
# Processing 7 in folder t22...
# Finished processing 7 in folder t22.
#  - Overlay saved to: output-images-2/t22/7_overlay.png
#  - Outlines saved to: output-outlines-2/t22/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/7_filtered_seg.npy
# Processing 11 in folder t22...
# Finished processing 11 in folder t22.
#  - Overlay saved to: output-images-2/t22/11_overlay.png
#  - Outlines saved to: output-outlines-2/t22/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t22/11_filtered_seg.npy
# Processing 13 in folder t20...
# Finished processing 13 in folder t20.
#  - Overlay saved to: output-images-2/t20/13_overlay.png
#  - Outlines saved to: output-outlines-2/t20/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/13_filtered_seg.npy
# Processing 9 in folder t20...
# Finished processing 9 in folder t20.
#  - Overlay saved to: output-images-2/t20/9_overlay.png
#  - Outlines saved to: output-outlines-2/t20/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/9_filtered_seg.npy
# Processing 1 in folder t20...
# Finished processing 1 in folder t20.
#  - Overlay saved to: output-images-2/t20/1_overlay.png
#  - Outlines saved to: output-outlines-2/t20/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/1_filtered_seg.npy
# Processing 12 in folder t20...
# Finished processing 12 in folder t20.
#  - Overlay saved to: output-images-2/t20/12_overlay.png
#  - Outlines saved to: output-outlines-2/t20/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/12_filtered_seg.npy
# Processing 15 in folder t20...
# Finished processing 15 in folder t20.
#  - Overlay saved to: output-images-2/t20/15_overlay.png
#  - Outlines saved to: output-outlines-2/t20/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/15_filtered_seg.npy
# Processing 5 in folder t20...
# Finished processing 5 in folder t20.
#  - Overlay saved to: output-images-2/t20/5_overlay.png
#  - Outlines saved to: output-outlines-2/t20/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/5_filtered_seg.npy
# Processing 10 in folder t20...
# Finished processing 10 in folder t20.
#  - Overlay saved to: output-images-2/t20/10_overlay.png
#  - Outlines saved to: output-outlines-2/t20/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/10_filtered_seg.npy
# Processing 2 in folder t20...
# Finished processing 2 in folder t20.
#  - Overlay saved to: output-images-2/t20/2_overlay.png
#  - Outlines saved to: output-outlines-2/t20/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/2_filtered_seg.npy
# Processing 4 in folder t20...
# Finished processing 4 in folder t20.
#  - Overlay saved to: output-images-2/t20/4_overlay.png
#  - Outlines saved to: output-outlines-2/t20/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/4_filtered_seg.npy
# Processing 8 in folder t20...
# Finished processing 8 in folder t20.
#  - Overlay saved to: output-images-2/t20/8_overlay.png
#  - Outlines saved to: output-outlines-2/t20/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/8_filtered_seg.npy
# Processing 6 in folder t20...
# Finished processing 6 in folder t20.
#  - Overlay saved to: output-images-2/t20/6_overlay.png
#  - Outlines saved to: output-outlines-2/t20/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/6_filtered_seg.npy
# Processing 14 in folder t20...
# Finished processing 14 in folder t20.
#  - Overlay saved to: output-images-2/t20/14_overlay.png
#  - Outlines saved to: output-outlines-2/t20/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/14_filtered_seg.npy
# Processing 3 in folder t20...
# Finished processing 3 in folder t20.
#  - Overlay saved to: output-images-2/t20/3_overlay.png
#  - Outlines saved to: output-outlines-2/t20/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/3_filtered_seg.npy
# Processing 7 in folder t20...
# Finished processing 7 in folder t20.
#  - Overlay saved to: output-images-2/t20/7_overlay.png
#  - Outlines saved to: output-outlines-2/t20/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/7_filtered_seg.npy
# Processing 11 in folder t20...
# Finished processing 11 in folder t20.
#  - Overlay saved to: output-images-2/t20/11_overlay.png
#  - Outlines saved to: output-outlines-2/t20/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t20/11_filtered_seg.npy
# Processing 13 in folder t43...
# Finished processing 13 in folder t43.
#  - Overlay saved to: output-images-2/t43/13_overlay.png
#  - Outlines saved to: output-outlines-2/t43/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/13_filtered_seg.npy
# Processing 9 in folder t43...
# Finished processing 9 in folder t43.
#  - Overlay saved to: output-images-2/t43/9_overlay.png
#  - Outlines saved to: output-outlines-2/t43/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/9_filtered_seg.npy
# Processing 1 in folder t43...
# Finished processing 1 in folder t43.
#  - Overlay saved to: output-images-2/t43/1_overlay.png
#  - Outlines saved to: output-outlines-2/t43/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/1_filtered_seg.npy
# Processing 12 in folder t43...
# Finished processing 12 in folder t43.
#  - Overlay saved to: output-images-2/t43/12_overlay.png
#  - Outlines saved to: output-outlines-2/t43/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/12_filtered_seg.npy
# Processing 15 in folder t43...
# Finished processing 15 in folder t43.
#  - Overlay saved to: output-images-2/t43/15_overlay.png
#  - Outlines saved to: output-outlines-2/t43/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/15_filtered_seg.npy
# Processing 5 in folder t43...
# Finished processing 5 in folder t43.
#  - Overlay saved to: output-images-2/t43/5_overlay.png
#  - Outlines saved to: output-outlines-2/t43/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/5_filtered_seg.npy
# Processing 10 in folder t43...
# Finished processing 10 in folder t43.
#  - Overlay saved to: output-images-2/t43/10_overlay.png
#  - Outlines saved to: output-outlines-2/t43/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/10_filtered_seg.npy
# Processing 2 in folder t43...
# Finished processing 2 in folder t43.
#  - Overlay saved to: output-images-2/t43/2_overlay.png
#  - Outlines saved to: output-outlines-2/t43/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/2_filtered_seg.npy
# Processing 4 in folder t43...
# Finished processing 4 in folder t43.
#  - Overlay saved to: output-images-2/t43/4_overlay.png
#  - Outlines saved to: output-outlines-2/t43/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/4_filtered_seg.npy
# Processing 8 in folder t43...
# Finished processing 8 in folder t43.
#  - Overlay saved to: output-images-2/t43/8_overlay.png
#  - Outlines saved to: output-outlines-2/t43/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/8_filtered_seg.npy
# Processing 6 in folder t43...
# Finished processing 6 in folder t43.
#  - Overlay saved to: output-images-2/t43/6_overlay.png
#  - Outlines saved to: output-outlines-2/t43/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/6_filtered_seg.npy
# Processing 14 in folder t43...
# Finished processing 14 in folder t43.
#  - Overlay saved to: output-images-2/t43/14_overlay.png
#  - Outlines saved to: output-outlines-2/t43/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/14_filtered_seg.npy
# Processing 3 in folder t43...
# Finished processing 3 in folder t43.
#  - Overlay saved to: output-images-2/t43/3_overlay.png
#  - Outlines saved to: output-outlines-2/t43/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/3_filtered_seg.npy
# Processing 7 in folder t43...
# Finished processing 7 in folder t43.
#  - Overlay saved to: output-images-2/t43/7_overlay.png
#  - Outlines saved to: output-outlines-2/t43/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/7_filtered_seg.npy
# Processing 11 in folder t43...
# Finished processing 11 in folder t43.
#  - Overlay saved to: output-images-2/t43/11_overlay.png
#  - Outlines saved to: output-outlines-2/t43/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t43/11_filtered_seg.npy
# Processing 13 in folder t33...
# Finished processing 13 in folder t33.
#  - Overlay saved to: output-images-2/t33/13_overlay.png
#  - Outlines saved to: output-outlines-2/t33/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/13_filtered_seg.npy
# Processing 9 in folder t33...
# Finished processing 9 in folder t33.
#  - Overlay saved to: output-images-2/t33/9_overlay.png
#  - Outlines saved to: output-outlines-2/t33/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/9_filtered_seg.npy
# Processing 1 in folder t33...
# Finished processing 1 in folder t33.
#  - Overlay saved to: output-images-2/t33/1_overlay.png
#  - Outlines saved to: output-outlines-2/t33/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/1_filtered_seg.npy
# Processing 12 in folder t33...
# Finished processing 12 in folder t33.
#  - Overlay saved to: output-images-2/t33/12_overlay.png
#  - Outlines saved to: output-outlines-2/t33/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/12_filtered_seg.npy
# Processing 15 in folder t33...
# Finished processing 15 in folder t33.
#  - Overlay saved to: output-images-2/t33/15_overlay.png
#  - Outlines saved to: output-outlines-2/t33/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/15_filtered_seg.npy
# Processing 5 in folder t33...
# Finished processing 5 in folder t33.
#  - Overlay saved to: output-images-2/t33/5_overlay.png
#  - Outlines saved to: output-outlines-2/t33/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/5_filtered_seg.npy
# Processing 10 in folder t33...
# Finished processing 10 in folder t33.
#  - Overlay saved to: output-images-2/t33/10_overlay.png
#  - Outlines saved to: output-outlines-2/t33/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/10_filtered_seg.npy
# Processing 2 in folder t33...
# Finished processing 2 in folder t33.
#  - Overlay saved to: output-images-2/t33/2_overlay.png
#  - Outlines saved to: output-outlines-2/t33/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/2_filtered_seg.npy
# Processing 4 in folder t33...
# Finished processing 4 in folder t33.
#  - Overlay saved to: output-images-2/t33/4_overlay.png
#  - Outlines saved to: output-outlines-2/t33/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/4_filtered_seg.npy
# Processing 8 in folder t33...
# Finished processing 8 in folder t33.
#  - Overlay saved to: output-images-2/t33/8_overlay.png
#  - Outlines saved to: output-outlines-2/t33/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/8_filtered_seg.npy
# Processing 6 in folder t33...
# Finished processing 6 in folder t33.
#  - Overlay saved to: output-images-2/t33/6_overlay.png
#  - Outlines saved to: output-outlines-2/t33/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/6_filtered_seg.npy
# Processing 14 in folder t33...
# Finished processing 14 in folder t33.
#  - Overlay saved to: output-images-2/t33/14_overlay.png
#  - Outlines saved to: output-outlines-2/t33/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/14_filtered_seg.npy
# Processing 3 in folder t33...
# Finished processing 3 in folder t33.
#  - Overlay saved to: output-images-2/t33/3_overlay.png
#  - Outlines saved to: output-outlines-2/t33/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/3_filtered_seg.npy
# Processing 7 in folder t33...
# Finished processing 7 in folder t33.
#  - Overlay saved to: output-images-2/t33/7_overlay.png
#  - Outlines saved to: output-outlines-2/t33/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/7_filtered_seg.npy
# Processing 11 in folder t33...
# Finished processing 11 in folder t33.
#  - Overlay saved to: output-images-2/t33/11_overlay.png
#  - Outlines saved to: output-outlines-2/t33/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t33/11_filtered_seg.npy
# Processing 13 in folder t42...
# Finished processing 13 in folder t42.
#  - Overlay saved to: output-images-2/t42/13_overlay.png
#  - Outlines saved to: output-outlines-2/t42/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/13_filtered_seg.npy
# Processing 9 in folder t42...
# Finished processing 9 in folder t42.
#  - Overlay saved to: output-images-2/t42/9_overlay.png
#  - Outlines saved to: output-outlines-2/t42/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/9_filtered_seg.npy
# Processing 1 in folder t42...
# Finished processing 1 in folder t42.
#  - Overlay saved to: output-images-2/t42/1_overlay.png
#  - Outlines saved to: output-outlines-2/t42/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/1_filtered_seg.npy
# Processing 12 in folder t42...
# Finished processing 12 in folder t42.
#  - Overlay saved to: output-images-2/t42/12_overlay.png
#  - Outlines saved to: output-outlines-2/t42/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/12_filtered_seg.npy
# Processing 15 in folder t42...
# Finished processing 15 in folder t42.
#  - Overlay saved to: output-images-2/t42/15_overlay.png
#  - Outlines saved to: output-outlines-2/t42/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/15_filtered_seg.npy
# Processing 5 in folder t42...
# Finished processing 5 in folder t42.
#  - Overlay saved to: output-images-2/t42/5_overlay.png
#  - Outlines saved to: output-outlines-2/t42/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/5_filtered_seg.npy
# Processing 10 in folder t42...
# Finished processing 10 in folder t42.
#  - Overlay saved to: output-images-2/t42/10_overlay.png
#  - Outlines saved to: output-outlines-2/t42/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/10_filtered_seg.npy
# Processing 2 in folder t42...
# Finished processing 2 in folder t42.
#  - Overlay saved to: output-images-2/t42/2_overlay.png
#  - Outlines saved to: output-outlines-2/t42/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/2_filtered_seg.npy
# Processing 4 in folder t42...
# Finished processing 4 in folder t42.
#  - Overlay saved to: output-images-2/t42/4_overlay.png
#  - Outlines saved to: output-outlines-2/t42/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/4_filtered_seg.npy
# Processing 8 in folder t42...
# Finished processing 8 in folder t42.
#  - Overlay saved to: output-images-2/t42/8_overlay.png
#  - Outlines saved to: output-outlines-2/t42/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/8_filtered_seg.npy
# Processing 6 in folder t42...
# Finished processing 6 in folder t42.
#  - Overlay saved to: output-images-2/t42/6_overlay.png
#  - Outlines saved to: output-outlines-2/t42/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/6_filtered_seg.npy
# Processing 14 in folder t42...
# Finished processing 14 in folder t42.
#  - Overlay saved to: output-images-2/t42/14_overlay.png
#  - Outlines saved to: output-outlines-2/t42/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/14_filtered_seg.npy
# Processing 3 in folder t42...
# Finished processing 3 in folder t42.
#  - Overlay saved to: output-images-2/t42/3_overlay.png
#  - Outlines saved to: output-outlines-2/t42/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/3_filtered_seg.npy
# Processing 7 in folder t42...
# Finished processing 7 in folder t42.
#  - Overlay saved to: output-images-2/t42/7_overlay.png
#  - Outlines saved to: output-outlines-2/t42/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/7_filtered_seg.npy
# Processing 11 in folder t42...
# Finished processing 11 in folder t42.
#  - Overlay saved to: output-images-2/t42/11_overlay.png
#  - Outlines saved to: output-outlines-2/t42/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t42/11_filtered_seg.npy
# Processing 13 in folder t27...
# Finished processing 13 in folder t27.
#  - Overlay saved to: output-images-2/t27/13_overlay.png
#  - Outlines saved to: output-outlines-2/t27/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/13_filtered_seg.npy
# Processing 9 in folder t27...
# Finished processing 9 in folder t27.
#  - Overlay saved to: output-images-2/t27/9_overlay.png
#  - Outlines saved to: output-outlines-2/t27/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/9_filtered_seg.npy
# Processing 1 in folder t27...
# Finished processing 1 in folder t27.
#  - Overlay saved to: output-images-2/t27/1_overlay.png
#  - Outlines saved to: output-outlines-2/t27/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/1_filtered_seg.npy
# Processing 12 in folder t27...
# Finished processing 12 in folder t27.
#  - Overlay saved to: output-images-2/t27/12_overlay.png
#  - Outlines saved to: output-outlines-2/t27/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/12_filtered_seg.npy
# Processing 15 in folder t27...
# Finished processing 15 in folder t27.
#  - Overlay saved to: output-images-2/t27/15_overlay.png
#  - Outlines saved to: output-outlines-2/t27/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/15_filtered_seg.npy
# Processing 5 in folder t27...
# Finished processing 5 in folder t27.
#  - Overlay saved to: output-images-2/t27/5_overlay.png
#  - Outlines saved to: output-outlines-2/t27/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/5_filtered_seg.npy
# Processing 10 in folder t27...
# Finished processing 10 in folder t27.
#  - Overlay saved to: output-images-2/t27/10_overlay.png
#  - Outlines saved to: output-outlines-2/t27/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/10_filtered_seg.npy
# Processing 2 in folder t27...
# Finished processing 2 in folder t27.
#  - Overlay saved to: output-images-2/t27/2_overlay.png
#  - Outlines saved to: output-outlines-2/t27/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/2_filtered_seg.npy
# Processing 4 in folder t27...
# Finished processing 4 in folder t27.
#  - Overlay saved to: output-images-2/t27/4_overlay.png
#  - Outlines saved to: output-outlines-2/t27/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/4_filtered_seg.npy
# Processing 8 in folder t27...
# Finished processing 8 in folder t27.
#  - Overlay saved to: output-images-2/t27/8_overlay.png
#  - Outlines saved to: output-outlines-2/t27/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/8_filtered_seg.npy
# Processing 6 in folder t27...
# Finished processing 6 in folder t27.
#  - Overlay saved to: output-images-2/t27/6_overlay.png
#  - Outlines saved to: output-outlines-2/t27/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/6_filtered_seg.npy
# Processing 14 in folder t27...
# Finished processing 14 in folder t27.
#  - Overlay saved to: output-images-2/t27/14_overlay.png
#  - Outlines saved to: output-outlines-2/t27/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/14_filtered_seg.npy
# Processing 3 in folder t27...
# Finished processing 3 in folder t27.
#  - Overlay saved to: output-images-2/t27/3_overlay.png
#  - Outlines saved to: output-outlines-2/t27/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/3_filtered_seg.npy
# Processing 7 in folder t27...
# Finished processing 7 in folder t27.
#  - Overlay saved to: output-images-2/t27/7_overlay.png
#  - Outlines saved to: output-outlines-2/t27/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/7_filtered_seg.npy
# Processing 11 in folder t27...
# Finished processing 11 in folder t27.
#  - Overlay saved to: output-images-2/t27/11_overlay.png
#  - Outlines saved to: output-outlines-2/t27/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t27/11_filtered_seg.npy
# Processing 13 in folder t13...
# Finished processing 13 in folder t13.
#  - Overlay saved to: output-images-2/t13/13_overlay.png
#  - Outlines saved to: output-outlines-2/t13/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/13_filtered_seg.npy
# Processing 9 in folder t13...
# Finished processing 9 in folder t13.
#  - Overlay saved to: output-images-2/t13/9_overlay.png
#  - Outlines saved to: output-outlines-2/t13/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/9_filtered_seg.npy
# Processing 1 in folder t13...
# Finished processing 1 in folder t13.
#  - Overlay saved to: output-images-2/t13/1_overlay.png
#  - Outlines saved to: output-outlines-2/t13/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/1_filtered_seg.npy
# Processing 12 in folder t13...
# Finished processing 12 in folder t13.
#  - Overlay saved to: output-images-2/t13/12_overlay.png
#  - Outlines saved to: output-outlines-2/t13/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/12_filtered_seg.npy
# Processing 15 in folder t13...
# Finished processing 15 in folder t13.
#  - Overlay saved to: output-images-2/t13/15_overlay.png
#  - Outlines saved to: output-outlines-2/t13/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/15_filtered_seg.npy
# Processing 5 in folder t13...
# Finished processing 5 in folder t13.
#  - Overlay saved to: output-images-2/t13/5_overlay.png
#  - Outlines saved to: output-outlines-2/t13/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/5_filtered_seg.npy
# Processing 10 in folder t13...
# Finished processing 10 in folder t13.
#  - Overlay saved to: output-images-2/t13/10_overlay.png
#  - Outlines saved to: output-outlines-2/t13/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/10_filtered_seg.npy
# Processing 2 in folder t13...
# Finished processing 2 in folder t13.
#  - Overlay saved to: output-images-2/t13/2_overlay.png
#  - Outlines saved to: output-outlines-2/t13/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/2_filtered_seg.npy
# Processing 4 in folder t13...
# Finished processing 4 in folder t13.
#  - Overlay saved to: output-images-2/t13/4_overlay.png
#  - Outlines saved to: output-outlines-2/t13/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/4_filtered_seg.npy
# Processing 8 in folder t13...
# Finished processing 8 in folder t13.
#  - Overlay saved to: output-images-2/t13/8_overlay.png
#  - Outlines saved to: output-outlines-2/t13/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/8_filtered_seg.npy
# Processing 6 in folder t13...
# Finished processing 6 in folder t13.
#  - Overlay saved to: output-images-2/t13/6_overlay.png
#  - Outlines saved to: output-outlines-2/t13/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/6_filtered_seg.npy
# Processing 14 in folder t13...
# Finished processing 14 in folder t13.
#  - Overlay saved to: output-images-2/t13/14_overlay.png
#  - Outlines saved to: output-outlines-2/t13/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/14_filtered_seg.npy
# Processing 3 in folder t13...
# Finished processing 3 in folder t13.
#  - Overlay saved to: output-images-2/t13/3_overlay.png
#  - Outlines saved to: output-outlines-2/t13/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/3_filtered_seg.npy
# Processing 7 in folder t13...
# Finished processing 7 in folder t13.
#  - Overlay saved to: output-images-2/t13/7_overlay.png
#  - Outlines saved to: output-outlines-2/t13/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/7_filtered_seg.npy
# Processing 11 in folder t13...
# Finished processing 11 in folder t13.
#  - Overlay saved to: output-images-2/t13/11_overlay.png
#  - Outlines saved to: output-outlines-2/t13/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t13/11_filtered_seg.npy
# Processing 13 in folder t25...
# Finished processing 13 in folder t25.
#  - Overlay saved to: output-images-2/t25/13_overlay.png
#  - Outlines saved to: output-outlines-2/t25/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/13_filtered_seg.npy
# Processing 9 in folder t25...
# Finished processing 9 in folder t25.
#  - Overlay saved to: output-images-2/t25/9_overlay.png
#  - Outlines saved to: output-outlines-2/t25/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/9_filtered_seg.npy
# Processing 1 in folder t25...
# Finished processing 1 in folder t25.
#  - Overlay saved to: output-images-2/t25/1_overlay.png
#  - Outlines saved to: output-outlines-2/t25/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/1_filtered_seg.npy
# Processing 12 in folder t25...
# Finished processing 12 in folder t25.
#  - Overlay saved to: output-images-2/t25/12_overlay.png
#  - Outlines saved to: output-outlines-2/t25/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/12_filtered_seg.npy
# Processing 15 in folder t25...
# Finished processing 15 in folder t25.
#  - Overlay saved to: output-images-2/t25/15_overlay.png
#  - Outlines saved to: output-outlines-2/t25/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/15_filtered_seg.npy
# Processing 5 in folder t25...
# Finished processing 5 in folder t25.
#  - Overlay saved to: output-images-2/t25/5_overlay.png
#  - Outlines saved to: output-outlines-2/t25/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/5_filtered_seg.npy
# Processing 10 in folder t25...
# Finished processing 10 in folder t25.
#  - Overlay saved to: output-images-2/t25/10_overlay.png
#  - Outlines saved to: output-outlines-2/t25/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/10_filtered_seg.npy
# Processing 2 in folder t25...
# Finished processing 2 in folder t25.
#  - Overlay saved to: output-images-2/t25/2_overlay.png
#  - Outlines saved to: output-outlines-2/t25/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/2_filtered_seg.npy
# Processing 4 in folder t25...
# Finished processing 4 in folder t25.
#  - Overlay saved to: output-images-2/t25/4_overlay.png
#  - Outlines saved to: output-outlines-2/t25/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/4_filtered_seg.npy
# Processing 8 in folder t25...
# Finished processing 8 in folder t25.
#  - Overlay saved to: output-images-2/t25/8_overlay.png
#  - Outlines saved to: output-outlines-2/t25/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/8_filtered_seg.npy
# Processing 6 in folder t25...
# Finished processing 6 in folder t25.
#  - Overlay saved to: output-images-2/t25/6_overlay.png
#  - Outlines saved to: output-outlines-2/t25/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/6_filtered_seg.npy
# Processing 14 in folder t25...
# Finished processing 14 in folder t25.
#  - Overlay saved to: output-images-2/t25/14_overlay.png
#  - Outlines saved to: output-outlines-2/t25/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/14_filtered_seg.npy
# Processing 3 in folder t25...
# Finished processing 3 in folder t25.
#  - Overlay saved to: output-images-2/t25/3_overlay.png
#  - Outlines saved to: output-outlines-2/t25/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/3_filtered_seg.npy
# Processing 7 in folder t25...
# Finished processing 7 in folder t25.
#  - Overlay saved to: output-images-2/t25/7_overlay.png
#  - Outlines saved to: output-outlines-2/t25/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/7_filtered_seg.npy
# Processing 11 in folder t25...
# Finished processing 11 in folder t25.
#  - Overlay saved to: output-images-2/t25/11_overlay.png
#  - Outlines saved to: output-outlines-2/t25/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t25/11_filtered_seg.npy
# Processing 13 in folder t29...
# Finished processing 13 in folder t29.
#  - Overlay saved to: output-images-2/t29/13_overlay.png
#  - Outlines saved to: output-outlines-2/t29/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/13_filtered_seg.npy
# Processing 9 in folder t29...
# Finished processing 9 in folder t29.
#  - Overlay saved to: output-images-2/t29/9_overlay.png
#  - Outlines saved to: output-outlines-2/t29/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/9_filtered_seg.npy
# Processing 1 in folder t29...
# Finished processing 1 in folder t29.
#  - Overlay saved to: output-images-2/t29/1_overlay.png
#  - Outlines saved to: output-outlines-2/t29/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/1_filtered_seg.npy
# Processing 12 in folder t29...
# Finished processing 12 in folder t29.
#  - Overlay saved to: output-images-2/t29/12_overlay.png
#  - Outlines saved to: output-outlines-2/t29/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/12_filtered_seg.npy
# Processing 15 in folder t29...
# Finished processing 15 in folder t29.
#  - Overlay saved to: output-images-2/t29/15_overlay.png
#  - Outlines saved to: output-outlines-2/t29/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/15_filtered_seg.npy
# Processing 5 in folder t29...
# Finished processing 5 in folder t29.
#  - Overlay saved to: output-images-2/t29/5_overlay.png
#  - Outlines saved to: output-outlines-2/t29/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/5_filtered_seg.npy
# Processing 10 in folder t29...
# Finished processing 10 in folder t29.
#  - Overlay saved to: output-images-2/t29/10_overlay.png
#  - Outlines saved to: output-outlines-2/t29/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/10_filtered_seg.npy
# Processing 2 in folder t29...
# Finished processing 2 in folder t29.
#  - Overlay saved to: output-images-2/t29/2_overlay.png
#  - Outlines saved to: output-outlines-2/t29/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/2_filtered_seg.npy
# Processing 4 in folder t29...
# Finished processing 4 in folder t29.
#  - Overlay saved to: output-images-2/t29/4_overlay.png
#  - Outlines saved to: output-outlines-2/t29/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/4_filtered_seg.npy
# Processing 8 in folder t29...
# Finished processing 8 in folder t29.
#  - Overlay saved to: output-images-2/t29/8_overlay.png
#  - Outlines saved to: output-outlines-2/t29/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/8_filtered_seg.npy
# Processing 6 in folder t29...
# Finished processing 6 in folder t29.
#  - Overlay saved to: output-images-2/t29/6_overlay.png
#  - Outlines saved to: output-outlines-2/t29/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/6_filtered_seg.npy
# Processing 14 in folder t29...
# Finished processing 14 in folder t29.
#  - Overlay saved to: output-images-2/t29/14_overlay.png
#  - Outlines saved to: output-outlines-2/t29/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/14_filtered_seg.npy
# Processing 3 in folder t29...
# Finished processing 3 in folder t29.
#  - Overlay saved to: output-images-2/t29/3_overlay.png
#  - Outlines saved to: output-outlines-2/t29/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/3_filtered_seg.npy
# Processing 7 in folder t29...
# Finished processing 7 in folder t29.
#  - Overlay saved to: output-images-2/t29/7_overlay.png
#  - Outlines saved to: output-outlines-2/t29/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/7_filtered_seg.npy
# Processing 11 in folder t29...
# Finished processing 11 in folder t29.
#  - Overlay saved to: output-images-2/t29/11_overlay.png
#  - Outlines saved to: output-outlines-2/t29/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t29/11_filtered_seg.npy
# Processing 13 in folder t17...
# Finished processing 13 in folder t17.
#  - Overlay saved to: output-images-2/t17/13_overlay.png
#  - Outlines saved to: output-outlines-2/t17/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/13_filtered_seg.npy
# Processing 9 in folder t17...
# Finished processing 9 in folder t17.
#  - Overlay saved to: output-images-2/t17/9_overlay.png
#  - Outlines saved to: output-outlines-2/t17/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/9_filtered_seg.npy
# Processing 1 in folder t17...
# Finished processing 1 in folder t17.
#  - Overlay saved to: output-images-2/t17/1_overlay.png
#  - Outlines saved to: output-outlines-2/t17/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/1_filtered_seg.npy
# Processing 12 in folder t17...
# Finished processing 12 in folder t17.
#  - Overlay saved to: output-images-2/t17/12_overlay.png
#  - Outlines saved to: output-outlines-2/t17/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/12_filtered_seg.npy
# Processing 15 in folder t17...
# Finished processing 15 in folder t17.
#  - Overlay saved to: output-images-2/t17/15_overlay.png
#  - Outlines saved to: output-outlines-2/t17/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/15_filtered_seg.npy
# Processing 5 in folder t17...
# Finished processing 5 in folder t17.
#  - Overlay saved to: output-images-2/t17/5_overlay.png
#  - Outlines saved to: output-outlines-2/t17/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/5_filtered_seg.npy
# Processing 10 in folder t17...
# Finished processing 10 in folder t17.
#  - Overlay saved to: output-images-2/t17/10_overlay.png
#  - Outlines saved to: output-outlines-2/t17/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/10_filtered_seg.npy
# Processing 2 in folder t17...
# Finished processing 2 in folder t17.
#  - Overlay saved to: output-images-2/t17/2_overlay.png
#  - Outlines saved to: output-outlines-2/t17/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/2_filtered_seg.npy
# Processing 4 in folder t17...
# Finished processing 4 in folder t17.
#  - Overlay saved to: output-images-2/t17/4_overlay.png
#  - Outlines saved to: output-outlines-2/t17/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/4_filtered_seg.npy
# Processing 8 in folder t17...
# Finished processing 8 in folder t17.
#  - Overlay saved to: output-images-2/t17/8_overlay.png
#  - Outlines saved to: output-outlines-2/t17/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/8_filtered_seg.npy
# Processing 6 in folder t17...
# Finished processing 6 in folder t17.
#  - Overlay saved to: output-images-2/t17/6_overlay.png
#  - Outlines saved to: output-outlines-2/t17/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/6_filtered_seg.npy
# Processing 14 in folder t17...
# Finished processing 14 in folder t17.
#  - Overlay saved to: output-images-2/t17/14_overlay.png
#  - Outlines saved to: output-outlines-2/t17/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/14_filtered_seg.npy
# Processing 3 in folder t17...
# Finished processing 3 in folder t17.
#  - Overlay saved to: output-images-2/t17/3_overlay.png
#  - Outlines saved to: output-outlines-2/t17/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/3_filtered_seg.npy
# Processing 7 in folder t17...
# Finished processing 7 in folder t17.
#  - Overlay saved to: output-images-2/t17/7_overlay.png
#  - Outlines saved to: output-outlines-2/t17/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/7_filtered_seg.npy
# Processing 11 in folder t17...
# Finished processing 11 in folder t17.
#  - Overlay saved to: output-images-2/t17/11_overlay.png
#  - Outlines saved to: output-outlines-2/t17/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t17/11_filtered_seg.npy
# Processing 13 in folder t3...
# Finished processing 13 in folder t3.
#  - Overlay saved to: output-images-2/t3/13_overlay.png
#  - Outlines saved to: output-outlines-2/t3/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/13_filtered_seg.npy
# Processing 9 in folder t3...
# Finished processing 9 in folder t3.
#  - Overlay saved to: output-images-2/t3/9_overlay.png
#  - Outlines saved to: output-outlines-2/t3/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/9_filtered_seg.npy
# Processing 1 in folder t3...
# Finished processing 1 in folder t3.
#  - Overlay saved to: output-images-2/t3/1_overlay.png
#  - Outlines saved to: output-outlines-2/t3/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/1_filtered_seg.npy
# Processing 12 in folder t3...
# Finished processing 12 in folder t3.
#  - Overlay saved to: output-images-2/t3/12_overlay.png
#  - Outlines saved to: output-outlines-2/t3/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/12_filtered_seg.npy
# Processing 15 in folder t3...
# Finished processing 15 in folder t3.
#  - Overlay saved to: output-images-2/t3/15_overlay.png
#  - Outlines saved to: output-outlines-2/t3/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/15_filtered_seg.npy
# Processing 5 in folder t3...
# Finished processing 5 in folder t3.
#  - Overlay saved to: output-images-2/t3/5_overlay.png
#  - Outlines saved to: output-outlines-2/t3/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/5_filtered_seg.npy
# Processing 10 in folder t3...
# Finished processing 10 in folder t3.
#  - Overlay saved to: output-images-2/t3/10_overlay.png
#  - Outlines saved to: output-outlines-2/t3/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/10_filtered_seg.npy
# Processing 2 in folder t3...
# Finished processing 2 in folder t3.
#  - Overlay saved to: output-images-2/t3/2_overlay.png
#  - Outlines saved to: output-outlines-2/t3/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/2_filtered_seg.npy
# Processing 4 in folder t3...
# Finished processing 4 in folder t3.
#  - Overlay saved to: output-images-2/t3/4_overlay.png
#  - Outlines saved to: output-outlines-2/t3/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/4_filtered_seg.npy
# Processing 8 in folder t3...
# Finished processing 8 in folder t3.
#  - Overlay saved to: output-images-2/t3/8_overlay.png
#  - Outlines saved to: output-outlines-2/t3/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/8_filtered_seg.npy
# Processing 6 in folder t3...
# Finished processing 6 in folder t3.
#  - Overlay saved to: output-images-2/t3/6_overlay.png
#  - Outlines saved to: output-outlines-2/t3/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/6_filtered_seg.npy
# Processing 14 in folder t3...
# Finished processing 14 in folder t3.
#  - Overlay saved to: output-images-2/t3/14_overlay.png
#  - Outlines saved to: output-outlines-2/t3/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/14_filtered_seg.npy
# Processing 3 in folder t3...
# Finished processing 3 in folder t3.
#  - Overlay saved to: output-images-2/t3/3_overlay.png
#  - Outlines saved to: output-outlines-2/t3/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t3/3_filtered_seg.npy
# ...
#  - Outlines saved to: output-outlines-2/t41/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/6_filtered_seg.npy
# Processing 14 in folder t41...
# Finished processing 14 in folder t41.
#  - Overlay saved to: output-images-2/t41/14_overlay.png
#  - Outlines saved to: output-outlines-2/t41/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/14_filtered_seg.npy
# Processing 3 in folder t41...
# Finished processing 3 in folder t41.
#  - Overlay saved to: output-images-2/t41/3_overlay.png
#  - Outlines saved to: output-outlines-2/t41/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/3_filtered_seg.npy
# Processing 7 in folder t41...
# Finished processing 7 in folder t41.
#  - Overlay saved to: output-images-2/t41/7_overlay.png
#  - Outlines saved to: output-outlines-2/t41/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/7_filtered_seg.npy
# Processing 11 in folder t41...
# Finished processing 11 in folder t41.
#  - Overlay saved to: output-images-2/t41/11_overlay.png
#  - Outlines saved to: output-outlines-2/t41/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t41/11_filtered_seg.npy
# Processing 13 in folder t40...
# Finished processing 13 in folder t40.
#  - Overlay saved to: output-images-2/t40/13_overlay.png
#  - Outlines saved to: output-outlines-2/t40/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/13_filtered_seg.npy
# Processing 9 in folder t40...
# Finished processing 9 in folder t40.
#  - Overlay saved to: output-images-2/t40/9_overlay.png
#  - Outlines saved to: output-outlines-2/t40/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/9_filtered_seg.npy
# Processing 1 in folder t40...
# Finished processing 1 in folder t40.
#  - Overlay saved to: output-images-2/t40/1_overlay.png
#  - Outlines saved to: output-outlines-2/t40/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/1_filtered_seg.npy
# Processing 12 in folder t40...
# Finished processing 12 in folder t40.
#  - Overlay saved to: output-images-2/t40/12_overlay.png
#  - Outlines saved to: output-outlines-2/t40/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/12_filtered_seg.npy
# Processing 15 in folder t40...
# Finished processing 15 in folder t40.
#  - Overlay saved to: output-images-2/t40/15_overlay.png
#  - Outlines saved to: output-outlines-2/t40/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/15_filtered_seg.npy
# Processing 5 in folder t40...
# Finished processing 5 in folder t40.
#  - Overlay saved to: output-images-2/t40/5_overlay.png
#  - Outlines saved to: output-outlines-2/t40/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/5_filtered_seg.npy
# Processing 10 in folder t40...
# Finished processing 10 in folder t40.
#  - Overlay saved to: output-images-2/t40/10_overlay.png
#  - Outlines saved to: output-outlines-2/t40/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/10_filtered_seg.npy
# Processing 2 in folder t40...
# Finished processing 2 in folder t40.
#  - Overlay saved to: output-images-2/t40/2_overlay.png
#  - Outlines saved to: output-outlines-2/t40/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/2_filtered_seg.npy
# Processing 4 in folder t40...
# Finished processing 4 in folder t40.
#  - Overlay saved to: output-images-2/t40/4_overlay.png
#  - Outlines saved to: output-outlines-2/t40/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/4_filtered_seg.npy
# Processing 8 in folder t40...
# Finished processing 8 in folder t40.
#  - Overlay saved to: output-images-2/t40/8_overlay.png
#  - Outlines saved to: output-outlines-2/t40/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/8_filtered_seg.npy
# Processing 6 in folder t40...
# Finished processing 6 in folder t40.
#  - Overlay saved to: output-images-2/t40/6_overlay.png
#  - Outlines saved to: output-outlines-2/t40/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/6_filtered_seg.npy
# Processing 14 in folder t40...
# Finished processing 14 in folder t40.
#  - Overlay saved to: output-images-2/t40/14_overlay.png
#  - Outlines saved to: output-outlines-2/t40/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/14_filtered_seg.npy
# Processing 3 in folder t40...
# Finished processing 3 in folder t40.
#  - Overlay saved to: output-images-2/t40/3_overlay.png
#  - Outlines saved to: output-outlines-2/t40/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/3_filtered_seg.npy
# Processing 7 in folder t40...
# Finished processing 7 in folder t40.
#  - Overlay saved to: output-images-2/t40/7_overlay.png
#  - Outlines saved to: output-outlines-2/t40/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/7_filtered_seg.npy
# Processing 11 in folder t40...
# Finished processing 11 in folder t40.
#  - Overlay saved to: output-images-2/t40/11_overlay.png
#  - Outlines saved to: output-outlines-2/t40/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t40/11_filtered_seg.npy
# Processing 13 in folder t31...
# Finished processing 13 in folder t31.
#  - Overlay saved to: output-images-2/t31/13_overlay.png
#  - Outlines saved to: output-outlines-2/t31/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/13_filtered_seg.npy
# Processing 9 in folder t31...
# Finished processing 9 in folder t31.
#  - Overlay saved to: output-images-2/t31/9_overlay.png
#  - Outlines saved to: output-outlines-2/t31/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/9_filtered_seg.npy
# Processing 1 in folder t31...
# Finished processing 1 in folder t31.
#  - Overlay saved to: output-images-2/t31/1_overlay.png
#  - Outlines saved to: output-outlines-2/t31/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/1_filtered_seg.npy
# Processing 12 in folder t31...
# Finished processing 12 in folder t31.
#  - Overlay saved to: output-images-2/t31/12_overlay.png
#  - Outlines saved to: output-outlines-2/t31/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/12_filtered_seg.npy
# Processing 15 in folder t31...
# Finished processing 15 in folder t31.
#  - Overlay saved to: output-images-2/t31/15_overlay.png
#  - Outlines saved to: output-outlines-2/t31/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/15_filtered_seg.npy
# Processing 5 in folder t31...
# Finished processing 5 in folder t31.
#  - Overlay saved to: output-images-2/t31/5_overlay.png
#  - Outlines saved to: output-outlines-2/t31/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/5_filtered_seg.npy
# Processing 10 in folder t31...
# Finished processing 10 in folder t31.
#  - Overlay saved to: output-images-2/t31/10_overlay.png
#  - Outlines saved to: output-outlines-2/t31/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/10_filtered_seg.npy
# Processing 2 in folder t31...
# Finished processing 2 in folder t31.
#  - Overlay saved to: output-images-2/t31/2_overlay.png
#  - Outlines saved to: output-outlines-2/t31/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/2_filtered_seg.npy
# Processing 4 in folder t31...
# Finished processing 4 in folder t31.
#  - Overlay saved to: output-images-2/t31/4_overlay.png
#  - Outlines saved to: output-outlines-2/t31/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/4_filtered_seg.npy
# Processing 8 in folder t31...
# Finished processing 8 in folder t31.
#  - Overlay saved to: output-images-2/t31/8_overlay.png
#  - Outlines saved to: output-outlines-2/t31/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/8_filtered_seg.npy
# Processing 6 in folder t31...
# Finished processing 6 in folder t31.
#  - Overlay saved to: output-images-2/t31/6_overlay.png
#  - Outlines saved to: output-outlines-2/t31/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/6_filtered_seg.npy
# Processing 14 in folder t31...
# Finished processing 14 in folder t31.
#  - Overlay saved to: output-images-2/t31/14_overlay.png
#  - Outlines saved to: output-outlines-2/t31/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/14_filtered_seg.npy
# Processing 3 in folder t31...
# Finished processing 3 in folder t31.
#  - Overlay saved to: output-images-2/t31/3_overlay.png
#  - Outlines saved to: output-outlines-2/t31/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/3_filtered_seg.npy
# Processing 7 in folder t31...
# Finished processing 7 in folder t31.
#  - Overlay saved to: output-images-2/t31/7_overlay.png
#  - Outlines saved to: output-outlines-2/t31/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/7_filtered_seg.npy
# Processing 11 in folder t31...
# Finished processing 11 in folder t31.
#  - Overlay saved to: output-images-2/t31/11_overlay.png
#  - Outlines saved to: output-outlines-2/t31/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t31/11_filtered_seg.npy
# Processing 13 in folder t37...
# Finished processing 13 in folder t37.
#  - Overlay saved to: output-images-2/t37/13_overlay.png
#  - Outlines saved to: output-outlines-2/t37/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/13_filtered_seg.npy
# Processing 9 in folder t37...
# Finished processing 9 in folder t37.
#  - Overlay saved to: output-images-2/t37/9_overlay.png
#  - Outlines saved to: output-outlines-2/t37/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/9_filtered_seg.npy
# Processing 1 in folder t37...
# Finished processing 1 in folder t37.
#  - Overlay saved to: output-images-2/t37/1_overlay.png
#  - Outlines saved to: output-outlines-2/t37/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/1_filtered_seg.npy
# Processing 12 in folder t37...
# Finished processing 12 in folder t37.
#  - Overlay saved to: output-images-2/t37/12_overlay.png
#  - Outlines saved to: output-outlines-2/t37/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/12_filtered_seg.npy
# Processing 15 in folder t37...
# Finished processing 15 in folder t37.
#  - Overlay saved to: output-images-2/t37/15_overlay.png
#  - Outlines saved to: output-outlines-2/t37/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/15_filtered_seg.npy
# Processing 5 in folder t37...
# Finished processing 5 in folder t37.
#  - Overlay saved to: output-images-2/t37/5_overlay.png
#  - Outlines saved to: output-outlines-2/t37/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/5_filtered_seg.npy
# Processing 10 in folder t37...
# Finished processing 10 in folder t37.
#  - Overlay saved to: output-images-2/t37/10_overlay.png
#  - Outlines saved to: output-outlines-2/t37/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/10_filtered_seg.npy
# Processing 2 in folder t37...
# Finished processing 2 in folder t37.
#  - Overlay saved to: output-images-2/t37/2_overlay.png
#  - Outlines saved to: output-outlines-2/t37/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/2_filtered_seg.npy
# Processing 4 in folder t37...
# Finished processing 4 in folder t37.
#  - Overlay saved to: output-images-2/t37/4_overlay.png
#  - Outlines saved to: output-outlines-2/t37/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/4_filtered_seg.npy
# Processing 8 in folder t37...
# Finished processing 8 in folder t37.
#  - Overlay saved to: output-images-2/t37/8_overlay.png
#  - Outlines saved to: output-outlines-2/t37/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/8_filtered_seg.npy
# Processing 6 in folder t37...
# Finished processing 6 in folder t37.
#  - Overlay saved to: output-images-2/t37/6_overlay.png
#  - Outlines saved to: output-outlines-2/t37/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/6_filtered_seg.npy
# Processing 14 in folder t37...
# Finished processing 14 in folder t37.
#  - Overlay saved to: output-images-2/t37/14_overlay.png
#  - Outlines saved to: output-outlines-2/t37/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/14_filtered_seg.npy
# Processing 3 in folder t37...
# Finished processing 3 in folder t37.
#  - Overlay saved to: output-images-2/t37/3_overlay.png
#  - Outlines saved to: output-outlines-2/t37/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/3_filtered_seg.npy
# Processing 7 in folder t37...
# Finished processing 7 in folder t37.
#  - Overlay saved to: output-images-2/t37/7_overlay.png
#  - Outlines saved to: output-outlines-2/t37/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/7_filtered_seg.npy
# Processing 11 in folder t37...
# Finished processing 11 in folder t37.
#  - Overlay saved to: output-images-2/t37/11_overlay.png
#  - Outlines saved to: output-outlines-2/t37/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t37/11_filtered_seg.npy
# Processing 13 in folder t9...
# Finished processing 13 in folder t9.
#  - Overlay saved to: output-images-2/t9/13_overlay.png
#  - Outlines saved to: output-outlines-2/t9/13_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/13_filtered_seg.npy
# Processing 9 in folder t9...
# Finished processing 9 in folder t9.
#  - Overlay saved to: output-images-2/t9/9_overlay.png
#  - Outlines saved to: output-outlines-2/t9/9_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/9_filtered_seg.npy
# Processing 1 in folder t9...
# Finished processing 1 in folder t9.
#  - Overlay saved to: output-images-2/t9/1_overlay.png
#  - Outlines saved to: output-outlines-2/t9/1_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/1_filtered_seg.npy
# Processing 12 in folder t9...
# Finished processing 12 in folder t9.
#  - Overlay saved to: output-images-2/t9/12_overlay.png
#  - Outlines saved to: output-outlines-2/t9/12_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/12_filtered_seg.npy
# Processing 15 in folder t9...
# Finished processing 15 in folder t9.
#  - Overlay saved to: output-images-2/t9/15_overlay.png
#  - Outlines saved to: output-outlines-2/t9/15_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/15_filtered_seg.npy
# Processing 5 in folder t9...
# Finished processing 5 in folder t9.
#  - Overlay saved to: output-images-2/t9/5_overlay.png
#  - Outlines saved to: output-outlines-2/t9/5_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/5_filtered_seg.npy
# Processing 10 in folder t9...
# Finished processing 10 in folder t9.
#  - Overlay saved to: output-images-2/t9/10_overlay.png
#  - Outlines saved to: output-outlines-2/t9/10_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/10_filtered_seg.npy
# Processing 2 in folder t9...
# Finished processing 2 in folder t9.
#  - Overlay saved to: output-images-2/t9/2_overlay.png
#  - Outlines saved to: output-outlines-2/t9/2_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/2_filtered_seg.npy
# Processing 4 in folder t9...
# Finished processing 4 in folder t9.
#  - Overlay saved to: output-images-2/t9/4_overlay.png
#  - Outlines saved to: output-outlines-2/t9/4_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/4_filtered_seg.npy
# Processing 8 in folder t9...
# Finished processing 8 in folder t9.
#  - Overlay saved to: output-images-2/t9/8_overlay.png
#  - Outlines saved to: output-outlines-2/t9/8_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/8_filtered_seg.npy
# Processing 6 in folder t9...
# Finished processing 6 in folder t9.
#  - Overlay saved to: output-images-2/t9/6_overlay.png
#  - Outlines saved to: output-outlines-2/t9/6_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/6_filtered_seg.npy
# Processing 14 in folder t9...
# Finished processing 14 in folder t9.
#  - Overlay saved to: output-images-2/t9/14_overlay.png
#  - Outlines saved to: output-outlines-2/t9/14_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/14_filtered_seg.npy
# Processing 3 in folder t9...
# Finished processing 3 in folder t9.
#  - Overlay saved to: output-images-2/t9/3_overlay.png
#  - Outlines saved to: output-outlines-2/t9/3_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/3_filtered_seg.npy
# Processing 7 in folder t9...
# Finished processing 7 in folder t9.
#  - Overlay saved to: output-images-2/t9/7_overlay.png
#  - Outlines saved to: output-outlines-2/t9/7_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/7_filtered_seg.npy
# Processing 11 in folder t9...
# Finished processing 11 in folder t9.
#  - Overlay saved to: output-images-2/t9/11_overlay.png
#  - Outlines saved to: output-outlines-2/t9/11_outlines.txt
#  - Filtered masks saved to: output-masks-2/t9/11_filtered_seg.npy

# %%
all_outlines = utils.outlines_list(masks)

# %%
all_outlines[0][0]
# Out:
# array([52, 76])

# %%
list(filtered_dict.keys())
# Out:
# [((np.int64(468), np.int64(277)),
#   (np.int64(468), np.int64(278)),
#   (np.int64(468), np.int64(279)),
#   (np.int64(468), np.int64(280)),
#   (np.int64(468), np.int64(281)),
#   (np.int64(469), np.int64(276)),
#   (np.int64(469), np.int64(277)),
#   (np.int64(469), np.int64(278)),
#   (np.int64(469), np.int64(279)),
#   (np.int64(469), np.int64(280)),
#   (np.int64(469), np.int64(281)),
#   (np.int64(469), np.int64(282)),
#   (np.int64(469), np.int64(283)),
#   (np.int64(470), np.int64(275)),
#   (np.int64(470), np.int64(276)),
#   (np.int64(470), np.int64(277)),
#   (np.int64(470), np.int64(278)),
#   (np.int64(470), np.int64(279)),
#   (np.int64(470), np.int64(280)),
#   (np.int64(470), np.int64(281)),
#   (np.int64(470), np.int64(282)),
#   (np.int64(470), np.int64(283)),
#   (np.int64(470), np.int64(284)),
#   (np.int64(470), np.int64(285)),
#   (np.int64(471), np.int64(274)),
#   (np.int64(471), np.int64(275)),
#   (np.int64(471), np.int64(276)),
#   (np.int64(471), np.int64(277)),
#   (np.int64(471), np.int64(278)),
#   (np.int64(471), np.int64(279)),
#   (np.int64(471), np.int64(280)),
#   (np.int64(471), np.int64(281)),
#   (np.int64(471), np.int64(282)),
#   (np.int64(471), np.int64(283)),
#   (np.int64(471), np.int64(284)),
#   (np.int64(471), np.int64(285)),
#   (np.int64(471), np.int64(286)),
#   (np.int64(471), np.int64(287)),
#   (np.int64(472), np.int64(274)),
#   (np.int64(472), np.int64(275)),
#   (np.int64(472), np.int64(276)),
#   (np.int64(472), np.int64(277)),
#   (np.int64(472), np.int64(278)),
#   (np.int64(472), np.int64(279)),
#   (np.int64(472), np.int64(280)),
#   (np.int64(472), np.int64(281)),
#   (np.int64(472), np.int64(282)),
#   (np.int64(472), np.int64(283)),
#   (np.int64(472), np.int64(284)),
#   (np.int64(472), np.int64(285)),
#   (np.int64(472), np.int64(286)),
#   (np.int64(472), np.int64(287)),
#   (np.int64(472), np.int64(288)),
#   (np.int64(472), np.int64(289)),
#   (np.int64(473), np.int64(274)),
#   (np.int64(473), np.int64(275)),
#   (np.int64(473), np.int64(276)),
#   (np.int64(473), np.int64(277)),
#   (np.int64(473), np.int64(278)),
#   (np.int64(473), np.int64(279)),
#   (np.int64(473), np.int64(280)),
#   (np.int64(473), np.int64(281)),
#   (np.int64(473), np.int64(282)),
#   (np.int64(473), np.int64(283)),
#   (np.int64(473), np.int64(284)),
#   (np.int64(473), np.int64(285)),
#   (np.int64(473), np.int64(286)),
#   (np.int64(473), np.int64(287)),
#   (np.int64(473), np.int64(288)),
#   (np.int64(473), np.int64(289)),
#   (np.int64(473), np.int64(290)),
#   (np.int64(474), np.int64(273)),
#   (np.int64(474), np.int64(274)),
#   (np.int64(474), np.int64(275)),
#   (np.int64(474), np.int64(276)),
#   (np.int64(474), np.int64(277)),
#   (np.int64(474), np.int64(278)),
#   (np.int64(474), np.int64(279)),
#   (np.int64(474), np.int64(280)),
#   (np.int64(474), np.int64(281)),
#   (np.int64(474), np.int64(282)),
#   (np.int64(474), np.int64(283)),
#   (np.int64(474), np.int64(284)),
#   (np.int64(474), np.int64(285)),
#   (np.int64(474), np.int64(286)),
#   (np.int64(474), np.int64(287)),
#   (np.int64(474), np.int64(288)),
#   (np.int64(474), np.int64(289)),
#   (np.int64(474), np.int64(290)),
#   (np.int64(474), np.int64(291)),
#   (np.int64(475), np.int64(273)),
#   (np.int64(475), np.int64(274)),
#   (np.int64(475), np.int64(275)),
#   (np.int64(475), np.int64(276)),
#   (np.int64(475), np.int64(277)),
#   (np.int64(475), np.int64(278)),
#   (np.int64(475), np.int64(279)),
#   (np.int64(475), np.int64(280)),
#   (np.int64(475), np.int64(281)),
#   (np.int64(475), np.int64(282)),
#   (np.int64(475), np.int64(283)),
#   (np.int64(475), np.int64(284)),
#   (np.int64(475), np.int64(285)),
#   (np.int64(475), np.int64(286)),
#   (np.int64(475), np.int64(287)),
#   (np.int64(475), np.int64(288)),
#   (np.int64(475), np.int64(289)),
#   (np.int64(475), np.int64(290)),
#   (np.int64(475), np.int64(291)),
#   (np.int64(475), np.int64(292)),
#   (np.int64(476), np.int64(273)),
#   (np.int64(476), np.int64(274)),
#   (np.int64(476), np.int64(275)),
#   (np.int64(476), np.int64(276)),
#   (np.int64(476), np.int64(277)),
#   (np.int64(476), np.int64(278)),
#   (np.int64(476), np.int64(279)),
#   (np.int64(476), np.int64(280)),
#   (np.int64(476), np.int64(281)),
#   (np.int64(476), np.int64(282)),
#   (np.int64(476), np.int64(283)),
#   (np.int64(476), np.int64(284)),
#   (np.int64(476), np.int64(285)),
#   (np.int64(476), np.int64(286)),
#   (np.int64(476), np.int64(287)),
#   (np.int64(476), np.int64(288)),
#   (np.int64(476), np.int64(289)),
#   (np.int64(476), np.int64(290)),
#   (np.int64(476), np.int64(291)),
#   (np.int64(476), np.int64(292)),
#   (np.int64(476), np.int64(293)),
#   (np.int64(477), np.int64(273)),
#   (np.int64(477), np.int64(274)),
#   (np.int64(477), np.int64(275)),
#   (np.int64(477), np.int64(276)),
#   (np.int64(477), np.int64(277)),
#   (np.int64(477), np.int64(278)),
#   (np.int64(477), np.int64(279)),
#   (np.int64(477), np.int64(280)),
#   (np.int64(477), np.int64(281)),
#   (np.int64(477), np.int64(282)),
#   (np.int64(477), np.int64(283)),
#   (np.int64(477), np.int64(284)),
#   (np.int64(477), np.int64(285)),
#   (np.int64(477), np.int64(286)),
#   (np.int64(477), np.int64(287)),
#   (np.int64(477), np.int64(288)),
#   (np.int64(477), np.int64(289)),
#   (np.int64(477), np.int64(290)),
#   (np.int64(477), np.int64(291)),
#   (np.int64(477), np.int64(292)),
#   (np.int64(477), np.int64(293)),
#   (np.int64(477), np.int64(294)),
#   (np.int64(478), np.int64(273)),
#   (np.int64(478), np.int64(274)),
#   (np.int64(478), np.int64(275)),
#   (np.int64(478), np.int64(276)),
#   (np.int64(478), np.int64(277)),
#   (np.int64(478), np.int64(278)),
#   (np.int64(478), np.int64(279)),
#   (np.int64(478), np.int64(280)),
#   (np.int64(478), np.int64(281)),
#   (np.int64(478), np.int64(282)),
#   (np.int64(478), np.int64(283)),
#   (np.int64(478), np.int64(284)),
#   (np.int64(478), np.int64(285)),
#   (np.int64(478), np.int64(286)),
#   (np.int64(478), np.int64(287)),
#   (np.int64(478), np.int64(288)),
#   (np.int64(478), np.int64(289)),
#   (np.int64(478), np.int64(290)),
#   (np.int64(478), np.int64(291)),
#   (np.int64(478), np.int64(292)),
#   (np.int64(478), np.int64(293)),
#   (np.int64(478), np.int64(294)),
#   (np.int64(478), np.int64(295)),
#   (np.int64(479), np.int64(273)),
#   (np.int64(479), np.int64(274)),
#   (np.int64(479), np.int64(275)),
#   (np.int64(479), np.int64(276)),
#   (np.int64(479), np.int64(277)),
#   (np.int64(479), np.int64(278)),
#   (np.int64(479), np.int64(279)),
#   (np.int64(479), np.int64(280)),
#   (np.int64(479), np.int64(281)),
#   (np.int64(479), np.int64(282)),
#   (np.int64(479), np.int64(283)),
#   (np.int64(479), np.int64(284)),
#   (np.int64(479), np.int64(285)),
#   (np.int64(479), np.int64(286)),
#   (np.int64(479), np.int64(287)),
#   (np.int64(479), np.int64(288)),
#   (np.int64(479), np.int64(289)),
#   (np.int64(479), np.int64(290)),
#   (np.int64(479), np.int64(291)),
#   (np.int64(479), np.int64(292)),
#   (np.int64(479), np.int64(293)),
#   (np.int64(479), np.int64(294)),
#   (np.int64(479), np.int64(295)),
#   (np.int64(480), np.int64(273)),
#   (np.int64(480), np.int64(274)),
#   (np.int64(480), np.int64(275)),
#   (np.int64(480), np.int64(276)),
#   (np.int64(480), np.int64(277)),
#   (np.int64(480), np.int64(278)),
#   (np.int64(480), np.int64(279)),
#   (np.int64(480), np.int64(280)),
#   (np.int64(480), np.int64(281)),
#   (np.int64(480), np.int64(282)),
#   (np.int64(480), np.int64(283)),
#   (np.int64(480), np.int64(284)),
#   (np.int64(480), np.int64(285)),
#   (np.int64(480), np.int64(286)),
#   (np.int64(480), np.int64(287)),
#   (np.int64(480), np.int64(288)),
#   (np.int64(480), np.int64(289)),
#   (np.int64(480), np.int64(290)),
#   (np.int64(480), np.int64(291)),
#   (np.int64(480), np.int64(292)),
#   (np.int64(480), np.int64(293)),
#   (np.int64(480), np.int64(294)),
#   (np.int64(480), np.int64(295)),
#   (np.int64(480), np.int64(296)),
#   (np.int64(481), np.int64(274)),
#   (np.int64(481), np.int64(275)),
#   (np.int64(481), np.int64(276)),
#   (np.int64(481), np.int64(277)),
#   (np.int64(481), np.int64(278)),
#   (np.int64(481), np.int64(279)),
#   (np.int64(481), np.int64(280)),
#   (np.int64(481), np.int64(281)),
#   (np.int64(481), np.int64(282)),
#   (np.int64(481), np.int64(283)),
#   (np.int64(481), np.int64(284)),
#   (np.int64(481), np.int64(285)),
#   (np.int64(481), np.int64(286)),
#   (np.int64(481), np.int64(287)),
#   (np.int64(481), np.int64(288)),
#   (np.int64(481), np.int64(289)),
#   (np.int64(481), np.int64(290)),
#   (np.int64(481), np.int64(291)),
#   (np.int64(481), np.int64(292)),
#   (np.int64(481), np.int64(293)),
#   (np.int64(481), np.int64(294)),
#   (np.int64(481), np.int64(295)),
#   (np.int64(481), np.int64(296)),
#   (np.int64(482), np.int64(274)),
#   (np.int64(482), np.int64(275)),
#   (np.int64(482), np.int64(276)),
#   (np.int64(482), np.int64(277)),
#   (np.int64(482), np.int64(278)),
#   (np.int64(482), np.int64(279)),
#   (np.int64(482), np.int64(280)),
#   (np.int64(482), np.int64(281)),
#   (np.int64(482), np.int64(282)),
#   (np.int64(482), np.int64(283)),
#   (np.int64(482), np.int64(284)),
#   (np.int64(482), np.int64(285)),
#   (np.int64(482), np.int64(286)),
#   (np.int64(482), np.int64(287)),
#   (np.int64(482), np.int64(288)),
#   (np.int64(482), np.int64(289)),
#   (np.int64(482), np.int64(290)),
#   (np.int64(482), np.int64(291)),
#   (np.int64(482), np.int64(292)),
#   (np.int64(482), np.int64(293)),
#   (np.int64(482), np.int64(294)),
#   (np.int64(482), np.int64(295)),
#   (np.int64(482), np.int64(296)),
#   (np.int64(483), np.int64(275)),
#   (np.int64(483), np.int64(276)),
#   (np.int64(483), np.int64(277)),
#   (np.int64(483), np.int64(278)),
#   (np.int64(483), np.int64(279)),
#   (np.int64(483), np.int64(280)),
#   (np.int64(483), np.int64(281)),
#   (np.int64(483), np.int64(282)),
#   (np.int64(483), np.int64(283)),
#   (np.int64(483), np.int64(284)),
#   (np.int64(483), np.int64(285)),
#   (np.int64(483), np.int64(286)),
#   (np.int64(483), np.int64(287)),
#   (np.int64(483), np.int64(288)),
#   (np.int64(483), np.int64(289)),
#   (np.int64(483), np.int64(290)),
#   (np.int64(483), np.int64(291)),
#   (np.int64(483), np.int64(292)),
#   (np.int64(483), np.int64(293)),
#   (np.int64(483), np.int64(294)),
#   (np.int64(483), np.int64(295)),
#   (np.int64(483), np.int64(296)),
#   (np.int64(484), np.int64(276)),
#   (np.int64(484), np.int64(277)),
#   (np.int64(484), np.int64(278)),
#   (np.int64(484), np.int64(279)),
#   (np.int64(484), np.int64(280)),
#   (np.int64(484), np.int64(281)),
#   (np.int64(484), np.int64(282)),
#   (np.int64(484), np.int64(283)),
#   (np.int64(484), np.int64(284)),
#   (np.int64(484), np.int64(285)),
#   (np.int64(484), np.int64(286)),
#   (np.int64(484), np.int64(287)),
#   (np.int64(484), np.int64(288)),
#   (np.int64(484), np.int64(289)),
#   (np.int64(484), np.int64(290)),
#   (np.int64(484), np.int64(291)),
#   (np.int64(484), np.int64(292)),
#   (np.int64(484), np.int64(293)),
#   (np.int64(484), np.int64(294)),
#   (np.int64(484), np.int64(295)),
#   (np.int64(484), np.int64(296)),
#   (np.int64(485), np.int64(277)),
#   (np.int64(485), np.int64(278)),
#   (np.int64(485), np.int64(279)),
#   (np.int64(485), np.int64(280)),
#   (np.int64(485), np.int64(281)),
#   (np.int64(485), np.int64(282)),
#   (np.int64(485), np.int64(283)),
#   (np.int64(485), np.int64(284)),
#   (np.int64(485), np.int64(285)),
#   (np.int64(485), np.int64(286)),
#   (np.int64(485), np.int64(287)),
#   (np.int64(485), np.int64(288)),
#   (np.int64(485), np.int64(289)),
#   (np.int64(485), np.int64(290)),
#   (np.int64(485), np.int64(291)),
#   (np.int64(485), np.int64(292)),
#   (np.int64(485), np.int64(293)),
#   (np.int64(485), np.int64(294)),
#   (np.int64(485), np.int64(295)),
#   (np.int64(486), np.int64(278)),
#   (np.int64(486), np.int64(279)),
#   (np.int64(486), np.int64(280)),
#   (np.int64(486), np.int64(281)),
#   (np.int64(486), np.int64(282)),
#   (np.int64(486), np.int64(283)),
#   (np.int64(486), np.int64(284)),
#   (np.int64(486), np.int64(285)),
#   (np.int64(486), np.int64(286)),
#   (np.int64(486), np.int64(287)),
#   (np.int64(486), np.int64(288)),
#   (np.int64(486), np.int64(289)),
#   (np.int64(486), np.int64(290)),
#   (np.int64(486), np.int64(291)),
#   (np.int64(486), np.int64(292)),
#   (np.int64(486), np.int64(293)),
#   (np.int64(486), np.int64(294)),
#   (np.int64(486), np.int64(295)),
#   (np.int64(487), np.int64(279)),
#   (np.int64(487), np.int64(280)),
#   (np.int64(487), np.int64(281)),
#   (np.int64(487), np.int64(282)),
#   (np.int64(487), np.int64(283)),
#   (np.int64(487), np.int64(284)),
#   (np.int64(487), np.int64(285)),
#   (np.int64(487), np.int64(286)),
#   (np.int64(487), np.int64(287)),
#   (np.int64(487), np.int64(288)),
#   (np.int64(487), np.int64(289)),
#   (np.int64(487), np.int64(290)),
#   (np.int64(487), np.int64(291)),
#   (np.int64(487), np.int64(292)),
#   (np.int64(487), np.int64(293)),
#   (np.int64(487), np.int64(294)),
#   (np.int64(488), np.int64(280)),
#   (np.int64(488), np.int64(281)),
#   (np.int64(488), np.int64(282)),
#   (np.int64(488), np.int64(283)),
#   (np.int64(488), np.int64(284)),
#   (np.int64(488), np.int64(285)),
#   (np.int64(488), np.int64(286)),
#   (np.int64(488), np.int64(287)),
#   (np.int64(488), np.int64(288)),
#   (np.int64(488), np.int64(289)),
#   (np.int64(488), np.int64(290)),
#   (np.int64(488), np.int64(291)),
#   (np.int64(488), np.int64(292)),
#   (np.int64(488), np.int64(293)),
#   (np.int64(489), np.int64(281)),
#   (np.int64(489), np.int64(282)),
#   (np.int64(489), np.int64(283)),
#   (np.int64(489), np.int64(284)),
#   (np.int64(489), np.int64(285)),
#   (np.int64(489), np.int64(286)),
#   (np.int64(489), np.int64(287)),
#   (np.int64(489), np.int64(288)),
#   (np.int64(489), np.int64(289)),
#   (np.int64(489), np.int64(290)),
#   (np.int64(489), np.int64(291)),
#   (np.int64(489), np.int64(292)),
#   (np.int64(490), np.int64(283)),
#   (np.int64(490), np.int64(284)),
#   (np.int64(490), np.int64(285)),
#   (np.int64(490), np.int64(286)),
#   (np.int64(490), np.int64(287)),
#   (np.int64(490), np.int64(288)),
#   (np.int64(490), np.int64(289)),
#   (np.int64(490), np.int64(290)))]

# %%
outlines = utils.outlines_list(list(filtered_dict.keys()))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 outlines = utils.outlines_list(list(filtered_dict.keys()))
#
# File ~/miniconda3/envs/cellpose/lib/python3.10/site-packages/cellpose/utils.py:249, in outlines_list(masks, multiprocessing_threshold, multiprocessing)
#     247     return outlines_list_multi(masks)
#     248 else:
# --> 249     return outlines_list_single(masks)
#
# File ~/miniconda3/envs/cellpose/lib/python3.10/site-packages/cellpose/utils.py:266, in outlines_list_single(masks)
#     264 mn = masks == n
#     265 if mn.sum() > 0:
# --> 266     contours = cv2.findContours(mn.astype(np.uint8), mode=cv2.RETR_EXTERNAL,
#     267                                 method=cv2.CHAIN_APPROX_NONE)
#     268     contours = contours[-2]
#     269     cmax = np.argmax([c.shape[0] for c in contours])
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/contours_new.cpp:327: error: (-2:Unspecified error) in function 'static std::shared_ptr<ContourScanner_> ContourScanner_::create(cv::Mat, int, int, cv::Point)'
# > Modes other than RETR_FLOODFILL and RETR_CCOMP support only CV_8UC1 images (expected: 'img.type() == CV_8UC1'), where
# >     'img.type()' is 8 (CV_8UC2)
# > must be equal to
# >     'CV_8UC1' is 0 (CV_8UC1)

# %%
# -------------------------------
# Part 4: Create and Save the Filtered Image
# -------------------------------

# Create a new black image with the same dimensions and channels as the original image
filtered_img = np.zeros_like(img)

# For each color channel, copy the original pixel values where overlay_mask is True
for c in range(3):
    filtered_img[..., c][overlay_mask] = img[..., c][overlay_mask]

# Save the resulting image to a file.
# Here we explicitly specify the format as 'TIFF' to avoid the KeyError.
plt.imsave('cells_above_green_threshold.tif', filtered_img, format='TIFF')

print("Filtered image saved as 'cells_above_green_threshold.tif'.")
# Out:
# Filtered image saved as 'cells_above_green_threshold.tif'.

# %%
import cv2  # Ensure OpenCV is imported

# -------------------------------
# Part 4: Write outlines of filtered (green) cells to file
# -------------------------------

output_filename = 'filtered_cells_outlines.txt'

with open(output_filename, 'w') as f:
    # Iterate through each filtered cell (each key is a tuple of (y, x) coordinates)
    for coords in filtered_dict.keys():
        # Create a blank binary image (same shape as the segmentation mask)
        cell_mask_img = np.zeros(masks.shape, dtype=np.uint8)
        # Mark the cell's pixels in the binary image
        for (y, x) in coords:
            cell_mask_img[y, x] = 255

        # Find external contours in the cell mask image
        # Note: cv2.findContours returns contours as a list of numpy arrays.
        contours, _ = cv2.findContours(cell_mask_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        if contours:
            # If there are multiple contours, choose the largest by area.
            contour = max(contours, key=cv2.contourArea)
            # Reshape contour array to (N, 2) where each row is [x, y]
            contour_points = contour.reshape(-1, 2)
            # Flatten the array into a 1D list: [x, y, x, y, ...]
            outline_list = contour_points.flatten().tolist()
            # Create a comma-separated string from the list
            outline_str = ','.join(map(str, outline_list))
            # Write the outline to file on a new line
            f.write(outline_str + '\n')

print(f"Cell outlines for filtered cells have been saved to '{output_filename}'.")
# Out:
# Cell outlines for filtered cells have been saved to 'filtered_cells_outlines.txt'.

# %%
import numpy as np
from cellpose import io
import matplotlib.pyplot as plt

# Load segmentation data and image
dat = np.load('input_images/7_seg.npy', allow_pickle=True).item()
img = io.imread('input_images/7.tif')

# Ensure image is in RGB format (if grayscale, convert to RGB)
if img.ndim == 2 or (img.ndim == 3 and img.shape[2] == 1):
    img = np.stack([img.squeeze()] * 3, axis=-1)

masks = dat['masks']

# Create a dictionary: key -> tuple of (y, x) coordinates for the mask pixels, value -> average RGB value.
mask_dict = {}
labels = np.unique(masks)
for label in labels:
    if label == 0:  # skip background label
        continue
    # Boolean mask for the current label
    mask = masks == label
    # Get coordinates (returns an array of [row, col] pairs)
    coords = np.argwhere(mask)
    # Convert the numpy array to a tuple of tuples (so it can be used as a dictionary key)
    coords_tuple = tuple(map(tuple, coords))
    # Calculate the average RGB value for the mask pixels
    avg_rgb = np.mean(img[mask], axis=0)
    # Save in the dictionary
    mask_dict[coords_tuple] = avg_rgb

# Optionally, print the dictionary
print("Dictionary of masks with average RGB values:")
for coords, avg_rgb in mask_dict.items():
    print(f"Mask with {len(coords)} pixels: Average RGB = {avg_rgb}")
# Out:
# Dictionary of masks with average RGB values:
# Mask with 111 pixels: Average RGB = [92.94594595 27.81981982  9.24324324]
# Mask with 263 pixels: Average RGB = [118.11026616  49.00760456  16.65019011]
# Mask with 345 pixels: Average RGB = [184.22318841 142.46956522  49.61449275]
# Mask with 224 pixels: Average RGB = [150.30357143  69.4375      23.73214286]
# Mask with 881 pixels: Average RGB = [120.09194098  71.51759364  24.61861521]
# Mask with 454 pixels: Average RGB = [181.91409692 146.28193833  50.9185022 ]
# Mask with 773 pixels: Average RGB = [196.35963777 168.3221216   58.81630013]
# Mask with 725 pixels: Average RGB = [201.16137931 127.42896552  44.03448276]
# Mask with 198 pixels: Average RGB = [66.96464646 34.38888889 11.80808081]
# Mask with 415 pixels: Average RGB = [183.81445783 142.5253012   49.59518072]
# Mask with 375 pixels: Average RGB = [193.12       125.06666667  43.29066667]
# Mask with 402 pixels: Average RGB = [193.54228856  76.65920398  26.02238806]
# Mask with 569 pixels: Average RGB = [193.79613357 151.58347979  52.78031634]
# Mask with 397 pixels: Average RGB = [188.85390428 143.68261965  50.02518892]
# Mask with 344 pixels: Average RGB = [199.95930233  75.49127907  25.56976744]
# Mask with 372 pixels: Average RGB = [210.09408602 164.46236559  57.43010753]
# Mask with 260 pixels: Average RGB = [211.95384615 143.45769231  49.72692308]
# Mask with 409 pixels: Average RGB = [193.06601467 145.29095355  50.50122249]
# Mask with 503 pixels: Average RGB = [211.29622266 130.94035785  45.28628231]
# Mask with 100 pixels: Average RGB = [90.41 24.96  8.33]
# Mask with 695 pixels: Average RGB = [194.56978417 100.2705036   34.39136691]
# Mask with 439 pixels: Average RGB = [229.38496583 169.44191344  59.04783599]
# Mask with 575 pixels: Average RGB = [197.39652174  90.69391304  30.95652174]
# Mask with 444 pixels: Average RGB = [212.25675676 186.28603604  65.20495495]
# Mask with 273 pixels: Average RGB = [158.95970696 117.17216117  40.64102564]
# Mask with 327 pixels: Average RGB = [223.55657492 149.00611621  51.66972477]
# Mask with 472 pixels: Average RGB = [222.61016949 158.33262712  55.05932203]
# Mask with 291 pixels: Average RGB = [144.79725086 114.75601375  39.84536082]
# Mask with 615 pixels: Average RGB = [184.32845528 123.85853659  42.88130081]
# Mask with 502 pixels: Average RGB = [214.92031873 187.41633466  65.61155378]
# Mask with 363 pixels: Average RGB = [206.52066116 126.38842975  43.70247934]
# Mask with 252 pixels: Average RGB = [167.48015873  91.66666667  31.5       ]
# Mask with 497 pixels: Average RGB = [228.57344064  90.53521127  30.76861167]
# Mask with 369 pixels: Average RGB = [125.17073171 110.47154472  38.51219512]
# Mask with 475 pixels: Average RGB = [208.17684211 175.37052632  61.29052632]
# Mask with 319 pixels: Average RGB = [205.17868339 174.66144201  61.05642633]
# Mask with 437 pixels: Average RGB = [192.23569794 153.80549199  53.59267735]
# Mask with 288 pixels: Average RGB = [194.55555556 156.16319444  54.39930556]
# Mask with 341 pixels: Average RGB = [186.86803519 169.53958944  59.24046921]
# Mask with 505 pixels: Average RGB = [217.28118812 187.72079208  65.73465347]
# Mask with 237 pixels: Average RGB = [163.37974684 156.88185654  54.85232068]
# Mask with 217 pixels: Average RGB = [156.18894009  78.89861751  27.01843318]
# Mask with 661 pixels: Average RGB = [190.08320726 154.9515885   53.94251135]
# Mask with 297 pixels: Average RGB = [161.28282828 141.93265993  49.50841751]
# Mask with 335 pixels: Average RGB = [180.1880597  162.12238806  56.62985075]
# Mask with 290 pixels: Average RGB = [171.84827586 153.97241379  53.64137931]
# Mask with 369 pixels: Average RGB = [187.99186992 163.11653117  56.90785908]
# Mask with 290 pixels: Average RGB = [161.16896552 113.15862069  39.1862069 ]
# Mask with 321 pixels: Average RGB = [168.17133956 153.47352025  53.63862928]
# Mask with 435 pixels: Average RGB = [164.56091954 163.62298851  57.24827586]
# Mask with 363 pixels: Average RGB = [163.55922865 149.27548209  52.09090909]
# Mask with 229 pixels: Average RGB = [114.31004367 104.71179039  36.44978166]
# Mask with 175 pixels: Average RGB = [129.93714286 111.67428571  38.84      ]
# Mask with 416 pixels: Average RGB = [176.94230769 163.89663462  57.26923077]
# Mask with 450 pixels: Average RGB = [183.04222222 153.06444444  53.29555556]
# Mask with 333 pixels: Average RGB = [166.33933934 162.10510511  56.68468468]
# Mask with 586 pixels: Average RGB = [181.81399317 163.37542662  57.05631399]
# Mask with 386 pixels: Average RGB = [149.29015544 158.44041451  55.47409326]
# Mask with 770 pixels: Average RGB = [209.06883117 184.91558442  64.72597403]
# Mask with 439 pixels: Average RGB = [147.70842825 152.74259681  53.42369021]
# Mask with 629 pixels: Average RGB = [161.97297297 131.99841017  45.91096979]
# Mask with 697 pixels: Average RGB = [176.14490674 177.44763271  62.24677188]
# Mask with 391 pixels: Average RGB = [181.51150895 183.67774936  64.32736573]
# Mask with 550 pixels: Average RGB = [171.35272727 163.28        57.12181818]
# Mask with 408 pixels: Average RGB = [172.23284314 152.28431373  53.18137255]
# Mask with 663 pixels: Average RGB = [208.00603318 206.74057315  72.63951735]
# Mask with 388 pixels: Average RGB = [157.95103093 149.05927835  52.03608247]
# Mask with 284 pixels: Average RGB = [185.17957746 187.1443662   65.64788732]
# Mask with 581 pixels: Average RGB = [151.12564544 144.56798623  50.4475043 ]
# Mask with 468 pixels: Average RGB = [93.04059829 88.55982906 30.87393162]
# Mask with 420 pixels: Average RGB = [173.29761905 140.0547619   48.76666667]
# Mask with 227 pixels: Average RGB = [58.99118943 60.21145374 21.05286344]
# Mask with 429 pixels: Average RGB = [171.86013986 172.18648019  60.26573427]
# Mask with 393 pixels: Average RGB = [173.03562341 178.01272265  62.45547074]
# Mask with 170 pixels: Average RGB = [145.68823529 102.47647059  35.48823529]

# %%
# Define the threshold for the green channel (the second element of the average RGB value)
green_threshold = 175  # Change this value as needed

# Create a filtered dictionary including only those masks with a green value >= the threshold
filtered_dict = {coords: rgb for coords, rgb in mask_dict.items() if rgb[1] >= green_threshold}

# Optionally, print the filtered dictionary
print(f"\nFiltered dictionary (green channel >= {green_threshold}):")
for coords, avg_rgb in filtered_dict.items():
    print(f"Mask with {len(coords)} pixels: Average RGB = {avg_rgb}")
# Out:
# Filtered dictionary (green channel >= 175):
# Mask with 444 pixels: Average RGB = [212.25675676 186.28603604  65.20495495]
# Mask with 502 pixels: Average RGB = [214.92031873 187.41633466  65.61155378]
# Mask with 475 pixels: Average RGB = [208.17684211 175.37052632  61.29052632]
# Mask with 505 pixels: Average RGB = [217.28118812 187.72079208  65.73465347]
# Mask with 770 pixels: Average RGB = [209.06883117 184.91558442  64.72597403]
# Mask with 697 pixels: Average RGB = [176.14490674 177.44763271  62.24677188]
# Mask with 391 pixels: Average RGB = [181.51150895 183.67774936  64.32736573]
# Mask with 663 pixels: Average RGB = [208.00603318 206.74057315  72.63951735]
# Mask with 284 pixels: Average RGB = [185.17957746 187.1443662   65.64788732]
# Mask with 393 pixels: Average RGB = [173.03562341 178.01272265  62.45547074]
